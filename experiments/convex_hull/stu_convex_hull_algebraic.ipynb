# %%
#in this notebook, I also attempt to find how each STU filter can be represented as a linear combination of LDSs
#however, to do this we will fit many STUs to LDSs and then use the learned weights to represent the STU as a linear combination of LDSs

# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
import torch
import torch.nn as nn
import torch.nn.functional  as  F
import math
import numpy as np

device = torch.device("cuda"  if torch.cuda.is_available() else "cpu")

# %%
def nearest_power_of_two(x: int, round_up: bool = False) -> int:
    return (
        1 << math.floor(math.log2(x)) if not round_up else 1 << math.ceil(math.log2(x))
    )

def convolve(u: torch.Tensor, v: torch.Tensor, n: int, use_approx: bool = True) -> tuple[torch.Tensor, torch.Tensor]:
    # print(u.shape, v.shape)
    bsz, seq_len, d_in = u.shape

    sgn = torch.full((1, seq_len, 1), 1, device=u.device)
    sgn[:, 1::2] *= -1

    _, K = v.shape
    sgn = sgn.unsqueeze(-1)
    v = v.view(1, -1, K, 1, 1).to(torch.float32) # (bsz, seq_len, K, d_in, stack)
    u = u.view(bsz, -1, 1, d_in).expand(bsz, -1, K, d_in)

    v = torch.fft.rfft(v, n=n, dim=1)
    U = torch.stack([u, u * sgn], dim=-1).to(torch.float32)
    U = torch.fft.rfft(U, n=n, dim=1)
    U_conv = torch.fft.irfft(v * U, n=n, dim=1)[:, :seq_len]
    U_plus, U_minus = torch.unbind(U_conv, dim=-1)
    U_minus = U_minus * sgn

    return U_plus, U_minus

# %%
def get_hankel(seq_len: int, use_hankel_L: bool = False) -> np.ndarray:
    entries = np.arange(1, seq_len + 1, dtype=np.float64)
    i_plus_j = entries[:, None] + entries[None, :]

    if use_hankel_L:
        sgn = (-1.0) ** (i_plus_j - 2.0) + 1.0
        denom = (i_plus_j + 3.0) * (i_plus_j - 1.0) * (i_plus_j + 1.0)
        Z = sgn * (8.0 / denom)
    elif not use_hankel_L:
        Z = 2.0 / (i_plus_j**3 - i_plus_j)
    else:
        raise ValueError("use_hankel_L must be a boolean")

    return Z

def get_spectral_filters(
    seq_len: int,
    K: int,
    use_hankel_L: bool = False,
    device: torch.device = None,
    dtype: torch.dtype = torch.bfloat16,
) -> torch.Tensor:
    # assert torch.cuda.is_available(), "CUDA is required."
    Z = get_hankel(seq_len, use_hankel_L)
    sigma, phi = np.linalg.eigh(Z)
    sigma_k, phi_k = sigma[-K:], phi[:, -K:]
    phi_k *= sigma_k ** 0.25
    filters = torch.from_numpy(phi_k)
    return filters.to(device=device, dtype=dtype)

# %%
class STU(nn.Module):
    def __init__(self, config, phi) -> None:
        super(STU, self).__init__()
        self.config = config
        self.phi = phi
        self.n = nearest_power_of_two(config['seq_len'] * 2 - 1, round_up=True)
        self.K = config['num_eigh']
        self.d_in = config['d_in']
        self.d_out = config['d_out']
        self.use_hankel_L = config['use_hankel_L']
        self.use_approx = False
        self.M_phi_plus = nn.Parameter(
            torch.randn(self.K, self.d_in, self.d_out, dtype=config['torch_dtype']) / 10
        )

        self.M_phi_minus = nn.Parameter(
            torch.randn(self.K, self.d_in, self.d_out, dtype=config['torch_dtype']) / 10
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:

        # Convolve inputs and filters,
        U_plus, U_minus = convolve(x, self.phi, self.n, False)
        # Then, contract over the K and d_in dimensions

        # print(U_plus.shape, U_minus.shape)
        spectral_plus = torch.tensordot(
            U_plus, self.M_phi_plus, dims=([2, 3], [0, 1])
        )

        spectral_minus = torch.tensordot(
            U_minus, self.M_phi_minus, dims=([2, 3], [0, 1])
        )

        # print(spectral_plus.shape)

        return spectral_plus if self.use_hankel_L else spectral_plus + spectral_minus

    def loss(self, inputs, targets):
        pred = self.forward(inputs)
        # print(pred, targets)
        loss = F.mse_loss(pred, targets)
        return  loss

# %%
class LDS:
  def __init__(self, A: torch.tensor, B: torch.tensor, C: torch.tensor, D: torch.tensor, h0: torch.tensor):
    self.d_h = A.shape
    _, self.d_u = B.shape
    self.d_o, _ = C.shape
    self.A = A  # hidden state dynamics
    self.B = B  # hidden state dynamics
    self.C = C  # observation projection
    self.D = D  # observation projection
    self.h0 = h0  # initial hidden state
    self.h = h0  # current hidden state
    self.dtype = float

  def step(self, u: torch.tensor) -> torch.tensor:
    assert u.shape == (self.d_u,)
    h_next = self.A * self.h + self.B @ u
    obs = self.C @ h_next + self.D @ u
    self.h = h_next
    assert obs.shape == (self.d_o,)
    return obs

  def reset(self):
    self.h = self.h0
    return self

  def generate_trajectory(self, us: torch.tensor, h0: torch.tensor = None) -> torch.tensor:
    if h0 is not None:
      self.h = h0
    _, d_u = us.shape
    assert d_u == self.d_u, (d_u, self.d_u)
    obs = []
    for u in us:
      obs.append(self.step(u))
    return torch.stack(obs, dim=0)

def random_LDS(d_h: int, d_o: int, d_u: int, lower_bound: float):
  """
  makes a random LDS with hidden state dimension d_h, observation dimension d_o, and control dimension d_u.
  `lower_bound` is a float in [0, 1] specifying the minimum absolute value for entries in A.
  Each entry in A will be in [lower_bound, 1] multiplied by +/-1 with equal probability.
  """
  # Generate random values in [lower_bound, 1]
  A = torch.rand(d_h) * (1 - lower_bound) + lower_bound
  signs = torch.randint(0, 2, (d_h,)) * 2 - 1
  A = A * signs.float()
  
  B = torch.randn(d_h, d_u)
  C = torch.randn(d_o, d_h)
  D = torch.zeros(d_o, d_u)
  h0 = torch.randn(d_h)
  return LDS(A, B, C, D, h0)

# %%
d_h = 1
d_in = 1
lds  =  random_LDS(d_h =  d_h, d_o =  d_out, d_u = d_in, lower_bound= 0.9)
print(lds.A)
# Out:
# tensor([-0.9719])

# %%
seq_len = 1024
num_eigh = 20
use_hankel_L  = True
phi= get_spectral_filters(seq_len = seq_len, K = num_eigh,  use_hankel_L= use_hankel_L,
                                device  = device,  dtype = torch.float32)

stu_config = {
    "num_eigh": num_eigh,
    "use_hankel_L": True,
    "torch_dtype": torch.float32,
    "d_in": 1,
    "d_out": 1,
    "seq_len": seq_len
}

# %%
def train_stu(lds, verbose = True):
    model = STU(stu_config, phi).to(device)
    lr = 1
    optimizer = torch.optim.Adagrad(model.parameters(), lr=lr)

    steps = 2_100 # @param
    model.train()

    bsz = 1

    for step in range(steps):
        inputs = torch.randn(bsz * seq_len, d_in)
        targets = lds.reset().generate_trajectory(inputs)

        inputs = inputs.reshape(bsz, seq_len, d_in).to(device)
        targets = targets.reshape(bsz, seq_len, d_out).to(device)
        loss = model.loss(inputs, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % 100 == 0 and verbose:
            print(f"Step {step}: Loss = {loss.item()}")

    model.eval()
    return model, loss

stu_model = train_stu(lds)
# Out:
# Step 0: Loss = 0.144703671336174
# Step 100: Loss = 6.497269350802526e-05
# Step 200: Loss = 7.001471385592595e-05
# Step 300: Loss = 6.369780749082565e-05
# Step 400: Loss = 6.566554657183588e-05
# Step 500: Loss = 7.142352842492983e-05
# Step 600: Loss = 6.533820123877376e-05
# Step 700: Loss = 6.405975000234321e-05
# Step 800: Loss = 8.514098590239882e-05
# Step 900: Loss = 6.431298970710486e-05
# Step 1000: Loss = 6.541221955558285e-05
# Step 1100: Loss = 6.28175912424922e-05
# Step 1200: Loss = 6.469985964940861e-05
# Step 1300: Loss = 6.939036393305287e-05
# Step 1400: Loss = 6.418003613362089e-05
# Step 1500: Loss = 6.366993329720572e-05
# Step 1600: Loss = 6.46294211037457e-05
# Step 1700: Loss = 7.147540600271896e-05
# Step 1800: Loss = 6.462792225647718e-05
# Step 1900: Loss = 7.007418025750667e-05
# Step 2000: Loss = 7.754490070510656e-05

# %%
lds_trajectory.shape
# Out:
# torch.Size([1024, 1])

# %%
import matplotlib.pyplot as plt

# Generate random input and get trajectories
test_input = torch.randn(seq_len, d_in).to(device)
test_input = test_input.unsqueeze(0) # Add batch dimension

# Get STU trajectory
with torch.no_grad():
    stu_trajectory = stu_model(test_input).squeeze()

# Get LDS trajectory 
lds_trajectory = lds.reset().generate_trajectory(test_input.squeeze(0)).to(device)

gap = stu_trajectory - lds_trajectory[:, 0]
# Plot both trajectories
plt.figure(figsize=(10, 6))
plt.plot(stu_trajectory.cpu().numpy(), label='STU Model')
plt.plot(lds_trajectory.cpu().numpy(), label='LDS Model', linestyle='--')
plt.plot(gap.cpu().numpy(), label='Gap')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title('Comparison of STU and LDS Trajectories')
plt.legend()
plt.grid(True)
plt.show()

# %%
stu_trajectory
# Out:
# tensor([ 0.2394, -0.2930,  0.1633,  ...,  0.4962, -0.4096,  0.4440])

# %%
lds_trajectory[0]
# Out:
# tensor([0.2130])

# %%
stu_model.M_phi_plus[:,0,0]
# Out:
# tensor([-0.1473,  0.1928,  0.0580, -0.2593, -0.0224,  0.1002, -0.0298, -0.1240,
#          0.0338,  0.0984, -0.0292, -0.0675, -0.0165, -0.0457,  0.0220, -0.0376,
#          0.0136, -0.0196, -0.0018, -0.0071, -0.0009, -0.0130, -0.0162,  0.0246,
#          0.0185, -0.0058,  0.0168, -0.0326, -0.0314, -0.0042, -0.0372,  0.0686,
#         -0.0595,  0.0021,  0.0769, -0.1201, -0.0820,  0.0348, -0.1691, -0.2337,
#         -0.1674,  0.0300, -0.2975, -0.5458, -0.7011,  0.7295,  0.6453,  0.4921,
#         -0.3203,  0.1667], grad_fn=<SelectBackward0>)

# %%
pos_weighted_filters.shape
# Out:
# torch.Size([1024])

# %%
# Get the STU filters and weights
filters = phi.T  # Shape: [num_filters, seq_len]
pos_weights = stu_model.M_phi_plus[:,0,0] # Shape: [1, num_filters]
neg_weights = stu_model.M_phi_minus[:,0,0] # Shape: [1, num_filters]
# Multiply each filter by its weight and sum
pos_weighted_filters = (filters.T @ pos_weights.T).squeeze()  # Shape: [seq_len]
neg_weighted_filters = (filters.T @ neg_weights.T).squeeze()  # Shape: [seq_len]

weighted_filters = pos_weighted_filters + neg_weighted_filters

# For LDS, compute the impulse response
lds_impulse = torch.zeros(seq_len)
for i in range(seq_len):
    a_power = lds.A ** i
    lds_impulse[i] = torch.sum(lds.C[:,0] * a_power * lds.B[0])

# Plot both
plt.figure(figsize=(10, 6))
plt.plot(weighted_filters.detach().cpu().numpy(), label='STU Combined Filters')
plt.plot(lds_impulse.cpu().numpy(), label='LDS Impulse Response', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title('Comparison of STU Filters and LDS Impulse Response')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import tqdm

num_LDSs = 300
ldss = []
pos_weights_matrix = []
neg_weights_matrix = []
losses = []

for i in tqdm.tqdm(range(num_LDSs)):
 
    new_lds = random_LDS(d_h = d_h, d_o = d_out, d_u = d_in, lower_bound= 0.95)  # Replace LDS with the actual class constructor if different
    
    # Fit STU to the LDS
    stu, loss = train_stu(new_lds, verbose = False)
    
    # Extract positive and negative weights
    pos_weights = stu.M_phi_plus[:, 0, 0].detach().cpu().numpy()  # Shape: [num_filters]
    neg_weights = stu.M_phi_minus[:, 0, 0].detach().cpu().numpy()  # Shape: [num_filters]
    
    pos_weights_matrix.append(pos_weights)
    neg_weights_matrix.append(neg_weights)
    losses.append(loss)

    ldss.append(new_lds)
# Out:
# 100%|██████████| 300/300 [1:27:14<00:00, 17.45s/it]

# %%
losses
# Out:
# [tensor(0.0046, grad_fn=<MseLossBackward0>),
#  tensor(0.0007, grad_fn=<MseLossBackward0>),
#  tensor(0.0125, grad_fn=<MseLossBackward0>),
#  tensor(5.2049e-06, grad_fn=<MseLossBackward0>),
#  tensor(0.0187, grad_fn=<MseLossBackward0>),
#  tensor(34.5436, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0027, grad_fn=<MseLossBackward0>),
#  tensor(0.0003, grad_fn=<MseLossBackward0>),
#  tensor(0.0001, grad_fn=<MseLossBackward0>),
#  tensor(7.3322e-05, grad_fn=<MseLossBackward0>),
#  tensor(10.3801, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0401, grad_fn=<MseLossBackward0>),
#  tensor(0.0153, grad_fn=<MseLossBackward0>),
#  tensor(0.0408, grad_fn=<MseLossBackward0>),
#  tensor(0.0008, grad_fn=<MseLossBackward0>),
#  tensor(0.0025, grad_fn=<MseLossBackward0>),
#  tensor(0.0016, grad_fn=<MseLossBackward0>),
#  tensor(0.0045, grad_fn=<MseLossBackward0>),
#  tensor(0.0607, grad_fn=<MseLossBackward0>),
#  tensor(0.0527, grad_fn=<MseLossBackward0>),
#  tensor(0.0011, grad_fn=<MseLossBackward0>),
#  tensor(0.0080, grad_fn=<MseLossBackward0>),
#  tensor(0.0062, grad_fn=<MseLossBackward0>),
#  tensor(0.0019, grad_fn=<MseLossBackward0>),
#  tensor(5.4444e-06, grad_fn=<MseLossBackward0>),
#  tensor(0.0021, grad_fn=<MseLossBackward0>),
#  tensor(0.0005, grad_fn=<MseLossBackward0>),
#  tensor(0.0063, grad_fn=<MseLossBackward0>),
#  tensor(0.0028, grad_fn=<MseLossBackward0>),
#  tensor(8.0030e-05, grad_fn=<MseLossBackward0>),
#  tensor(1.0922e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0229, grad_fn=<MseLossBackward0>),
#  tensor(0.0034, grad_fn=<MseLossBackward0>),
#  tensor(2.0698e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0022, grad_fn=<MseLossBackward0>),
#  tensor(0.0709, grad_fn=<MseLossBackward0>),
#  tensor(0.0010, grad_fn=<MseLossBackward0>),
#  tensor(0.0012, grad_fn=<MseLossBackward0>),
#  tensor(2.3601e-06, grad_fn=<MseLossBackward0>),
#  tensor(0.1781, grad_fn=<MseLossBackward0>),
#  tensor(0.0212, grad_fn=<MseLossBackward0>),
#  tensor(1.2166e-05, grad_fn=<MseLossBackward0>),
#  tensor(7.1819e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0165, grad_fn=<MseLossBackward0>),
#  tensor(0.0015, grad_fn=<MseLossBackward0>),
#  tensor(0.0011, grad_fn=<MseLossBackward0>),
#  tensor(0.0075, grad_fn=<MseLossBackward0>),
#  tensor(2.4267e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0190, grad_fn=<MseLossBackward0>),
#  tensor(0.0009, grad_fn=<MseLossBackward0>),
#  tensor(9.7159e-07, grad_fn=<MseLossBackward0>),
#  tensor(4.0303e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0068, grad_fn=<MseLossBackward0>),
#  tensor(0.0083, grad_fn=<MseLossBackward0>),
#  tensor(4.4325e-06, grad_fn=<MseLossBackward0>),
#  tensor(0.0016, grad_fn=<MseLossBackward0>),
#  tensor(1.8426e-06, grad_fn=<MseLossBackward0>),
#  tensor(0.0058, grad_fn=<MseLossBackward0>),
#  tensor(0.0064, grad_fn=<MseLossBackward0>),
#  tensor(0.0035, grad_fn=<MseLossBackward0>),
#  tensor(3.0668e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0279, grad_fn=<MseLossBackward0>),
#  tensor(0.0003, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(5.5829e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0280, grad_fn=<MseLossBackward0>),
#  tensor(0.0268, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0023, grad_fn=<MseLossBackward0>),
#  tensor(0.0022, grad_fn=<MseLossBackward0>),
#  tensor(0.0021, grad_fn=<MseLossBackward0>),
#  tensor(0.8404, grad_fn=<MseLossBackward0>),
#  tensor(0.0550, grad_fn=<MseLossBackward0>),
#  tensor(0.0070, grad_fn=<MseLossBackward0>),
#  tensor(0.0010, grad_fn=<MseLossBackward0>),
#  tensor(0.0179, grad_fn=<MseLossBackward0>),
#  tensor(0.0048, grad_fn=<MseLossBackward0>),
#  tensor(0.2110, grad_fn=<MseLossBackward0>),
#  tensor(5.7589e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0055, grad_fn=<MseLossBackward0>),
#  tensor(6.5424e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0134, grad_fn=<MseLossBackward0>),
#  tensor(0.0008, grad_fn=<MseLossBackward0>),
#  tensor(0.0081, grad_fn=<MseLossBackward0>),
#  tensor(0.0169, grad_fn=<MseLossBackward0>),
#  tensor(0.0232, grad_fn=<MseLossBackward0>),
#  tensor(2.4438e-05, grad_fn=<MseLossBackward0>),
#  tensor(9.6960e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0053, grad_fn=<MseLossBackward0>),
#  tensor(0.0539, grad_fn=<MseLossBackward0>),
#  tensor(0.6654, grad_fn=<MseLossBackward0>),
#  tensor(3.0109e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(5.2670e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0008, grad_fn=<MseLossBackward0>),
#  tensor(0.0017, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(1.0490e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0517, grad_fn=<MseLossBackward0>),
#  tensor(63.8900, grad_fn=<MseLossBackward0>),
#  tensor(2.2009e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0003, grad_fn=<MseLossBackward0>),
#  tensor(0.0128, grad_fn=<MseLossBackward0>),
#  tensor(0.0036, grad_fn=<MseLossBackward0>),
#  tensor(0.0011, grad_fn=<MseLossBackward0>),
#  tensor(0.0054, grad_fn=<MseLossBackward0>),
#  tensor(0.0077, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0008, grad_fn=<MseLossBackward0>),
#  tensor(0.0041, grad_fn=<MseLossBackward0>),
#  tensor(0.0090, grad_fn=<MseLossBackward0>),
#  tensor(0.0616, grad_fn=<MseLossBackward0>),
#  tensor(0.0008, grad_fn=<MseLossBackward0>),
#  tensor(0.0271, grad_fn=<MseLossBackward0>),
#  tensor(68.1192, grad_fn=<MseLossBackward0>),
#  tensor(0.0047, grad_fn=<MseLossBackward0>),
#  tensor(9.7432e-06, grad_fn=<MseLossBackward0>),
#  tensor(1.3906e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0018, grad_fn=<MseLossBackward0>),
#  tensor(0.0031, grad_fn=<MseLossBackward0>),
#  tensor(0.0372, grad_fn=<MseLossBackward0>),
#  tensor(0.0010, grad_fn=<MseLossBackward0>),
#  tensor(0.0013, grad_fn=<MseLossBackward0>),
#  tensor(4.7102e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0004, grad_fn=<MseLossBackward0>),
#  tensor(0.0116, grad_fn=<MseLossBackward0>),
#  tensor(0.0423, grad_fn=<MseLossBackward0>),
#  tensor(0.0041, grad_fn=<MseLossBackward0>),
#  tensor(0.3430, grad_fn=<MseLossBackward0>),
#  tensor(0.0892, grad_fn=<MseLossBackward0>),
#  tensor(0.0096, grad_fn=<MseLossBackward0>),
#  tensor(0.0010, grad_fn=<MseLossBackward0>),
#  tensor(0.0010, grad_fn=<MseLossBackward0>),
#  tensor(9.1713e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0010, grad_fn=<MseLossBackward0>),
#  tensor(0.0030, grad_fn=<MseLossBackward0>),
#  tensor(0.0005, grad_fn=<MseLossBackward0>),
#  tensor(202.5926, grad_fn=<MseLossBackward0>),
#  tensor(0.0199, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0006, grad_fn=<MseLossBackward0>),
#  tensor(0.0042, grad_fn=<MseLossBackward0>),
#  tensor(0.0017, grad_fn=<MseLossBackward0>),
#  tensor(0.0014, grad_fn=<MseLossBackward0>),
#  tensor(0.1146, grad_fn=<MseLossBackward0>),
#  tensor(0.0175, grad_fn=<MseLossBackward0>),
#  tensor(902.2809, grad_fn=<MseLossBackward0>),
#  tensor(0.0049, grad_fn=<MseLossBackward0>),
#  tensor(0.0035, grad_fn=<MseLossBackward0>),
#  tensor(0.0144, grad_fn=<MseLossBackward0>),
#  tensor(0.0049, grad_fn=<MseLossBackward0>),
#  tensor(0.1217, grad_fn=<MseLossBackward0>),
#  tensor(0.0119, grad_fn=<MseLossBackward0>),
#  tensor(0.0010, grad_fn=<MseLossBackward0>),
#  tensor(0.0009, grad_fn=<MseLossBackward0>),
#  tensor(0.0036, grad_fn=<MseLossBackward0>),
#  tensor(8.2933e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0008, grad_fn=<MseLossBackward0>),
#  tensor(6.3496e-06, grad_fn=<MseLossBackward0>),
#  tensor(0.0145, grad_fn=<MseLossBackward0>),
#  tensor(0.0061, grad_fn=<MseLossBackward0>),
#  tensor(0.0096, grad_fn=<MseLossBackward0>),
#  tensor(100.3440, grad_fn=<MseLossBackward0>),
#  tensor(0.0019, grad_fn=<MseLossBackward0>),
#  tensor(5.8342e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0031, grad_fn=<MseLossBackward0>),
#  tensor(0.4195, grad_fn=<MseLossBackward0>),
#  tensor(0.0030, grad_fn=<MseLossBackward0>),
#  tensor(0.3162, grad_fn=<MseLossBackward0>),
#  tensor(0.0211, grad_fn=<MseLossBackward0>),
#  tensor(0.0025, grad_fn=<MseLossBackward0>),
#  tensor(0.0051, grad_fn=<MseLossBackward0>),
#  tensor(0.0087, grad_fn=<MseLossBackward0>),
#  tensor(3.7871e-07, grad_fn=<MseLossBackward0>),
#  tensor(0.3762, grad_fn=<MseLossBackward0>),
#  tensor(0.0021, grad_fn=<MseLossBackward0>),
#  tensor(1.5624, grad_fn=<MseLossBackward0>),
#  tensor(0.0135, grad_fn=<MseLossBackward0>),
#  tensor(8.7643e-07, grad_fn=<MseLossBackward0>),
#  tensor(2.6700e-07, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0188, grad_fn=<MseLossBackward0>),
#  tensor(0.0091, grad_fn=<MseLossBackward0>),
#  tensor(0.1473, grad_fn=<MseLossBackward0>),
#  tensor(2.6801, grad_fn=<MseLossBackward0>),
#  tensor(0.0956, grad_fn=<MseLossBackward0>),
#  tensor(0.0313, grad_fn=<MseLossBackward0>),
#  tensor(0.0053, grad_fn=<MseLossBackward0>),
#  tensor(0.3585, grad_fn=<MseLossBackward0>),
#  tensor(0.0013, grad_fn=<MseLossBackward0>),
#  tensor(0.0027, grad_fn=<MseLossBackward0>),
#  tensor(0.0053, grad_fn=<MseLossBackward0>),
#  tensor(0.0061, grad_fn=<MseLossBackward0>),
#  tensor(0.2144, grad_fn=<MseLossBackward0>),
#  tensor(0.0037, grad_fn=<MseLossBackward0>),
#  tensor(0.1403, grad_fn=<MseLossBackward0>),
#  tensor(0.0862, grad_fn=<MseLossBackward0>),
#  tensor(0.0067, grad_fn=<MseLossBackward0>),
#  tensor(0.3188, grad_fn=<MseLossBackward0>),
#  tensor(0.0005, grad_fn=<MseLossBackward0>),
#  tensor(0.0174, grad_fn=<MseLossBackward0>),
#  tensor(1.3376, grad_fn=<MseLossBackward0>),
#  tensor(0.0001, grad_fn=<MseLossBackward0>),
#  tensor(0.0029, grad_fn=<MseLossBackward0>),
#  tensor(0.0014, grad_fn=<MseLossBackward0>),
#  tensor(0.0043, grad_fn=<MseLossBackward0>),
#  tensor(1.1637, grad_fn=<MseLossBackward0>),
#  tensor(0.0422, grad_fn=<MseLossBackward0>),
#  tensor(0.0775, grad_fn=<MseLossBackward0>),
#  tensor(0.0554, grad_fn=<MseLossBackward0>),
#  tensor(9.5259e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.1126, grad_fn=<MseLossBackward0>),
#  tensor(0.0008, grad_fn=<MseLossBackward0>),
#  tensor(0.0254, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(1.1974e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0810, grad_fn=<MseLossBackward0>),
#  tensor(0.0028, grad_fn=<MseLossBackward0>),
#  tensor(0.1104, grad_fn=<MseLossBackward0>),
#  tensor(0.0032, grad_fn=<MseLossBackward0>),
#  tensor(0.0067, grad_fn=<MseLossBackward0>),
#  tensor(0.0088, grad_fn=<MseLossBackward0>),
#  tensor(0.1200, grad_fn=<MseLossBackward0>),
#  tensor(0.0199, grad_fn=<MseLossBackward0>),
#  tensor(0.6089, grad_fn=<MseLossBackward0>),
#  tensor(0.0610, grad_fn=<MseLossBackward0>),
#  tensor(0.0249, grad_fn=<MseLossBackward0>),
#  tensor(2.6693e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0099, grad_fn=<MseLossBackward0>),
#  tensor(0.0161, grad_fn=<MseLossBackward0>),
#  tensor(0.3307, grad_fn=<MseLossBackward0>),
#  tensor(0.0001, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0025, grad_fn=<MseLossBackward0>),
#  tensor(0.0001, grad_fn=<MseLossBackward0>),
#  tensor(0.0171, grad_fn=<MseLossBackward0>),
#  tensor(0.8280, grad_fn=<MseLossBackward0>),
#  tensor(0.0005, grad_fn=<MseLossBackward0>),
#  tensor(0.0020, grad_fn=<MseLossBackward0>),
#  tensor(0.0487, grad_fn=<MseLossBackward0>),
#  tensor(0.0103, grad_fn=<MseLossBackward0>),
#  tensor(0.0141, grad_fn=<MseLossBackward0>),
#  tensor(0.1413, grad_fn=<MseLossBackward0>),
#  tensor(0.0082, grad_fn=<MseLossBackward0>),
#  tensor(0.0027, grad_fn=<MseLossBackward0>),
#  tensor(0.0003, grad_fn=<MseLossBackward0>),
#  tensor(0.0018, grad_fn=<MseLossBackward0>),
#  tensor(0.0004, grad_fn=<MseLossBackward0>),
#  tensor(0.0013, grad_fn=<MseLossBackward0>),
#  tensor(0.2795, grad_fn=<MseLossBackward0>),
#  tensor(0.0026, grad_fn=<MseLossBackward0>),
#  tensor(0.0008, grad_fn=<MseLossBackward0>),
#  tensor(0.0037, grad_fn=<MseLossBackward0>),
#  tensor(0.0001, grad_fn=<MseLossBackward0>),
#  tensor(0.0440, grad_fn=<MseLossBackward0>),
#  tensor(0.0052, grad_fn=<MseLossBackward0>),
#  tensor(0.0108, grad_fn=<MseLossBackward0>),
#  tensor(0.2807, grad_fn=<MseLossBackward0>),
#  tensor(0.0035, grad_fn=<MseLossBackward0>),
#  tensor(0.3099, grad_fn=<MseLossBackward0>),
#  tensor(0.0163, grad_fn=<MseLossBackward0>),
#  tensor(0.0389, grad_fn=<MseLossBackward0>),
#  tensor(0.0264, grad_fn=<MseLossBackward0>),
#  tensor(0.0627, grad_fn=<MseLossBackward0>),
#  tensor(0.0026, grad_fn=<MseLossBackward0>),
#  tensor(0.0039, grad_fn=<MseLossBackward0>),
#  tensor(0.1028, grad_fn=<MseLossBackward0>),
#  tensor(0.0002, grad_fn=<MseLossBackward0>),
#  tensor(0.0028, grad_fn=<MseLossBackward0>),
#  tensor(0.0240, grad_fn=<MseLossBackward0>),
#  tensor(0.0004, grad_fn=<MseLossBackward0>),
#  tensor(0.0032, grad_fn=<MseLossBackward0>),
#  tensor(0.0174, grad_fn=<MseLossBackward0>),
#  tensor(0.2293, grad_fn=<MseLossBackward0>),
#  tensor(0.0012, grad_fn=<MseLossBackward0>),
#  tensor(0.0104, grad_fn=<MseLossBackward0>),
#  tensor(0.0005, grad_fn=<MseLossBackward0>),
#  tensor(0.0848, grad_fn=<MseLossBackward0>),
#  tensor(0.0113, grad_fn=<MseLossBackward0>),
#  tensor(0.0006, grad_fn=<MseLossBackward0>),
#  tensor(0.0087, grad_fn=<MseLossBackward0>),
#  tensor(7.3295e-07, grad_fn=<MseLossBackward0>),
#  tensor(0.0136, grad_fn=<MseLossBackward0>),
#  tensor(0.0284, grad_fn=<MseLossBackward0>),
#  tensor(0.0055, grad_fn=<MseLossBackward0>),
#  tensor(0.0198, grad_fn=<MseLossBackward0>),
#  tensor(0.0007, grad_fn=<MseLossBackward0>),
#  tensor(0.0032, grad_fn=<MseLossBackward0>),
#  tensor(0.0021, grad_fn=<MseLossBackward0>),
#  tensor(0.0166, grad_fn=<MseLossBackward0>),
#  tensor(0.2767, grad_fn=<MseLossBackward0>),
#  tensor(0.0035, grad_fn=<MseLossBackward0>),
#  tensor(4.3183e-06, grad_fn=<MseLossBackward0>),
#  tensor(7.9588e-06, grad_fn=<MseLossBackward0>),
#  tensor(0.0051, grad_fn=<MseLossBackward0>),
#  tensor(3.0306e-05, grad_fn=<MseLossBackward0>),
#  tensor(0.0001, grad_fn=<MseLossBackward0>)]

# %%
# Convert losses to numpy array for easier manipulation
losses_np = np.array([loss.item() for loss in losses])

# Get indices of n lowest losses
best_indices = np.argsort(losses_np)[:40]

# %%
best_pos_weights = np.stack([pos_weights_matrix[i] for i in best_indices])
best_neg_weights = np.stack([neg_weights_matrix[i] for i in best_indices])

# Concatenate positive and negative weights to form a (50, 40) matrix
combined_weights = np.concatenate((best_pos_weights, best_neg_weights), axis=1)

# Convert the combined weights to a torch tensor
combined_weights_tensor = torch.tensor(combined_weights)

# %%
combined_weights_pinv = torch.pinverse(combined_weights_tensor)

# %%
# Stack the top 50 LDS impulses into a tensor
# Compute impulse responses for each LDS in ldss and stack them into a tensor
impulse_list = []
for new_lds in ldss:
    lds_impulse = torch.zeros(seq_len)
    for i in range(seq_len):
        a_power = new_lds.A ** i
        lds_impulse[i] = torch.sum(new_lds.C[:, 0] * a_power * new_lds.B[0])
    impulse_list.append(lds_impulse)

lds_tensor = torch.stack([impulse_list[i] for i in best_indices])  # Shape: [50, seq_len]

for i in range(20):
    plt.figure(figsize=(15, 5))
    
    # Plot the filter weights
    plt.subplot(1, 2, 1)
    plt.plot(phi[:,i], '-', linewidth=1)
    plt.title(f'Filter {i} Weights')
    plt.xlabel('Time')
    plt.ylabel('Weight')
    
    # Plot the weighted sum of LDS impulses
    plt.subplot(1, 2, 2)
    coefficients = combined_weights_pinv[i]
    weighted_sum = torch.matmul(coefficients, lds_tensor)
    plt.plot(weighted_sum.detach().numpy(), '-', linewidth=1)
    plt.title(f'Filter {i} Weighted Sum')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    
    plt.tight_layout()
    plt.show()
