# %%
#in this notebook, I also attempt to find how each STU filter can be represented as a linear combination of LDSs
#however, to do this we will fit many STUs to LDSs and then use the learned weights to represent the STU as a linear combination of LDSs

# %%
import sys
import os
sys.path.append(os.path.abspath("../../src"))

# %%
import torch
import torch.nn as nn
import torch.nn.functional  as  F
import math
import numpy as np

device = torch.device("cuda"  if torch.cuda.is_available() else "cpu")

# %%
def nearest_power_of_two(x: int, round_up: bool = False) -> int:
    return (
        1 << math.floor(math.log2(x)) if not round_up else 1 << math.ceil(math.log2(x))
    )

def convolve(u: torch.Tensor, v: torch.Tensor, n: int, use_approx: bool = True) -> tuple[torch.Tensor, torch.Tensor]:
    # print(u.shape, v.shape)
    bsz, seq_len, d_in = u.shape

    sgn = torch.full((1, seq_len, 1), 1, device=u.device)
    sgn[:, 1::2] *= -1

    _, K = v.shape
    sgn = sgn.unsqueeze(-1)
    v = v.view(1, -1, K, 1, 1).to(torch.float32) # (bsz, seq_len, K, d_in, stack)
    u = u.view(bsz, -1, 1, d_in).expand(bsz, -1, K, d_in)

    v = torch.fft.rfft(v, n=n, dim=1)
    U = torch.stack([u, u * sgn], dim=-1).to(torch.float32)
    U = torch.fft.rfft(U, n=n, dim=1)
    U_conv = torch.fft.irfft(v * U, n=n, dim=1)[:, :seq_len]
    U_plus, U_minus = torch.unbind(U_conv, dim=-1)
    U_minus = U_minus * sgn

    return U_plus, U_minus

# %%
def get_hankel(seq_len: int, use_hankel_L: bool = False) -> np.ndarray:
    entries = np.arange(1, seq_len + 1, dtype=np.float64)
    i_plus_j = entries[:, None] + entries[None, :]

    if use_hankel_L:
        sgn = (-1.0) ** (i_plus_j - 2.0) + 1.0
        denom = (i_plus_j + 3.0) * (i_plus_j - 1.0) * (i_plus_j + 1.0)
        Z = sgn * (8.0 / denom)
    elif not use_hankel_L:
        Z = 2.0 / (i_plus_j**3 - i_plus_j)
    else:
        raise ValueError("use_hankel_L must be a boolean")

    return Z

def get_spectral_filters(
    seq_len: int,
    K: int,
    use_hankel_L: bool = False,
    device: torch.device = None,
    dtype: torch.dtype = torch.bfloat16,
) -> torch.Tensor:
    # assert torch.cuda.is_available(), "CUDA is required."
    Z = get_hankel(seq_len, use_hankel_L)
    sigma, phi = np.linalg.eigh(Z)
    sigma_k, phi_k = sigma[-K:], phi[:, -K:]
    phi_k *= sigma_k ** 0.25
    filters = torch.from_numpy(phi_k)
    return filters.to(device=device, dtype=dtype)

# %%
from lds_utils import compute_ar_x_preds

# %%
class STU(nn.Module):
    def __init__(self, config, phi) -> None:
        super(STU, self).__init__()
        self.config = config
        self.phi = phi
        self.n = nearest_power_of_two(config['seq_len'] * 2 - 1, round_up=True)
        self.K = config['num_eigh']
        self.d_in = config['d_in']
        self.d_out = config['d_out']
        self.use_hankel_L = config['use_hankel_L']
        self.use_approx = False
        self.k_u = config['k_u']

        self.M = nn.Parameter(torch.randn(self.d_out, self.d_in, self.k_u, dtype=config['torch_dtype']) / self.d_in)
        
        self.M_phi_plus = nn.Parameter(
            torch.randn(self.K, self.d_in, self.d_out, dtype=config['torch_dtype']) / 10
        )

        self.M_phi_minus = nn.Parameter(
            torch.randn(self.K, self.d_in, self.d_out, dtype=config['torch_dtype']) / 10
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:

        # Convolve inputs and filters,
        U_plus, U_minus = convolve(x, self.phi, self.n, False)
        # Then, contract over the K and d_in dimensions

        # print(U_plus.shape, U_minus.shape)
        spectral_plus = torch.tensordot(
            U_plus, self.M_phi_plus, dims=([2, 3], [0, 1])
        )

        spectral_minus = torch.tensordot(
            U_minus, self.M_phi_minus, dims=([2, 3], [0, 1])
        )
            
        output = spectral_plus if self.use_hankel_L else spectral_plus + spectral_minus
        ar = compute_ar_x_preds(self.M, x)
        return output + ar
        
    def loss(self, inputs, targets):
        pred = self.forward(inputs)
        # print(pred, targets)
        loss = F.mse_loss(pred, targets)
        return  loss

# %%
class LDS:
  def __init__(self, A: torch.tensor, B: torch.tensor, C: torch.tensor, D: torch.tensor, h0: torch.tensor):
    self.d_h = A.shape
    _, self.d_u = B.shape
    self.d_o, _ = C.shape
    self.A = A  # hidden state dynamics
    self.B = B  # hidden state dynamics
    self.C = C  # observation projection
    self.D = D  # observation projection
    self.h0 = h0  # initial hidden state
    self.h = h0  # current hidden state
    self.dtype = float

  def step(self, u: torch.tensor) -> torch.tensor:
    assert u.shape == (self.d_u,)
    h_next = self.A * self.h + self.B @ u
    obs = self.C @ h_next + self.D @ u
    self.h = h_next
    assert obs.shape == (self.d_o,)
    return obs

  def reset(self):
    self.h = self.h0
    return self

  def generate_trajectory(self, us: torch.tensor, h0: torch.tensor = None) -> torch.tensor:
    if h0 is not None:
      self.h = h0
    _, d_u = us.shape
    assert d_u == self.d_u, (d_u, self.d_u)
    obs = []
    for u in us:
      obs.append(self.step(u))
    return torch.stack(obs, dim=0)
  
  def impulse(self, seq_len = 1024):
      # Initialize output tensor
      outputs = torch.zeros(seq_len)
      
      # For each position
      for i in range(seq_len):
          # Compute A^i
          a_power = self.A ** i
          
          # Multiply C[:,0] * A^i * B[i]
          outputs[i] = torch.sum(self.C[:,0] * a_power * self.B[0])
          
      return outputs

def random_LDS(d_h: int, d_o: int, d_u: int, lower_bound: float):
  """
  makes a random LDS with hidden state dimension d_h, observation dimension d_o, and control dimension d_u.
  `lower_bound` is a float in [0, 1] specifying the minimum absolute value for entries in A.
  Each entry in A will be in [lower_bound, 1] multiplied by +/-1 with equal probability.
  """
  # Generate random values in [lower_bound, 1]
  A = torch.rand(d_h) * (1 - lower_bound) + lower_bound
  signs = torch.randint(0, 2, (d_h,)) * 2 - 1
  A = A * signs.float()
  
  B = torch.randn(d_h, d_u).to(device)
  C = torch.randn(d_o, d_h).to(device)
  D = torch.zeros(d_o, d_u).to(device)
  h0 = torch.zeros(d_h).to(device)
  return LDS(A.to(device), B, C, D, h0)

# %%
d_h = 1
d_in = 1
d_out =1
lds  =  random_LDS(d_h = d_h, d_o =  d_out, d_u = d_in, lower_bound= 0.9)
print(lds.A)
# Out:
# tensor([-0.9134])

# %%
seq_len = 4096
num_eigh = 30
use_hankel_L  = True
phi= get_spectral_filters(seq_len = seq_len, K = num_eigh,  use_hankel_L= use_hankel_L,
                                device  = device,  dtype = torch.float32)

stu_config = {
    "num_eigh": num_eigh,
    "use_hankel_L": True,
    "torch_dtype": torch.float32,
    "d_in": 1,
    "d_out": 1,
    "seq_len": seq_len,
    "k_u": 3
}

# %%
def train_stu(lds, verbose = True):
    model = STU(stu_config, phi).to(device)
    lr = 1
    optimizer = torch.optim.Adagrad(model.parameters(), lr=lr)

    steps = 1_000 # @param
    model.train()

    bsz = 1

    for step in range(steps):
        inputs = torch.randn(bsz * seq_len, d_in).to(device)
        targets = lds.reset().generate_trajectory(inputs)

        inputs = inputs.reshape(bsz, seq_len, d_in).to(device)
        targets = targets.reshape(bsz, seq_len, d_out).to(device)
        loss = model.loss(inputs, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % 100 == 0 and verbose:
            print(f"Step {step}: Loss = {loss.item()}")

    model.eval()
    return model, loss

stu_model, _ = train_stu(lds)
# Out:
# Step 0: Loss = 7.942370891571045
# Step 100: Loss = 3.640833767803997e-07
# Step 200: Loss = 3.3587485859243316e-07
# Step 300: Loss = 3.35522088334983e-07
# Step 400: Loss = 3.793316807332303e-07
# Step 500: Loss = 3.93648235785804e-07
# Step 600: Loss = 3.291255268322857e-07
# Step 700: Loss = 3.490918629722728e-07
# Step 800: Loss = 3.7831472354810103e-07
# Step 900: Loss = 3.329909645799489e-07

# %%
import matplotlib.pyplot as plt

# Generate random input and get trajectories
test_input = torch.randn(seq_len, d_in).to(device)
test_input = test_input.unsqueeze(0) # Add batch dimension

# Get STU trajectory
with torch.no_grad():
    stu_trajectory = stu_model(test_input).squeeze()

# Get LDS trajectory 
lds_trajectory = lds.reset().generate_trajectory(test_input.squeeze(0)).to(device)

gap = stu_trajectory - lds_trajectory[:, 0]
# Plot both trajectories
plt.figure(figsize=(10, 6))
plt.plot(stu_trajectory.cpu().numpy(), label='STU Model')
plt.plot(lds_trajectory.cpu().numpy(), label='LDS Model', linestyle='--')
plt.plot(gap.cpu().numpy(), label='Gap')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title('Comparison of STU and LDS Trajectories')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Get the STU filters and weights
filters = phi.T  # Shape: [num_filters, seq_len]
pos_weights = stu_model.M_phi_plus[:,0,0] # Shape: [1, num_filters]
neg_weights = stu_model.M_phi_minus[:,0,0] # Shape: [1, num_filters]
# Multiply each filter by its weight and sum
pos_weighted_filters = (filters.T @ pos_weights.T).squeeze()  # Shape: [seq_len]
neg_weighted_filters = (filters.T @ neg_weights.T).squeeze()  # Shape: [seq_len]

weighted_filters = pos_weighted_filters + neg_weighted_filters

# For LDS, compute the impulse response
lds_impulse = torch.zeros(seq_len)
for i in range(seq_len):
    a_power = lds.A ** i
    lds_impulse[i] = torch.sum(lds.C[:,0] * a_power * lds.B[0])

# Plot both
plt.figure(figsize=(10, 6))
plt.plot(weighted_filters.detach().cpu().numpy(), label='STU Combined Filters')
plt.plot(lds_impulse.cpu().numpy(), label='LDS Impulse Response', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title('Comparison of STU Filters and LDS Impulse Response')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import tqdm

ldss = []
pos_weights_matrix = []
neg_weights_matrix = []
autoreg_weights_matrix = []
losses = []
store = []

# %%
for i in tqdm.tqdm(range(100)):
 
    new_lds = random_LDS(d_h = d_h, d_o = d_out, d_u = d_in, lower_bound= 0.8)  # Replace LDS with the actual class constructor if different
    
    # Fit STU to the LDS
    stu, loss = train_stu(new_lds, verbose = False)
    
    # Extract positive and negative weights
    pos_weights = stu.M_phi_plus[:, 0, 0].detach().cpu().numpy()  # Shape: [num_filters]
    neg_weights = stu.M_phi_minus[:, 0, 0].detach().cpu().numpy()  # Shape: [num_filters]
    auto_reg = stu.M.detach().cpu().numpy()
    autoreg_weights_matrix.append(auto_reg)
    
    pos_weights_matrix.append(pos_weights)
    neg_weights_matrix.append(neg_weights)
    losses.append(loss)
    store.append([new_lds, stu])

    ldss.append(new_lds)
# Out:
# 100%|██████████| 100/100 [11:57:08<00:00, 430.28s/it]

# %%
# Reconstruct store from saved arrays
store = []
for i in range(len(ldss)):
    lds = ldss[i]
    
    # Create STU object and populate with saved weights
    stu = STU(stu_config, phi)
    stu.M_phi_plus.data = torch.tensor(pos_weights_matrix[i]).unsqueeze(-1).unsqueeze(-1)
    stu.M_phi_minus.data = torch.tensor(neg_weights_matrix[i]).unsqueeze(-1).unsqueeze(-1) 
    stu.M.data = torch.tensor(autoreg_weights_matrix[i])
    
    store.append((lds, stu))

print(f"Reconstructed {len(store)} LDS-STU pairs")
# Out:
# Reconstructed 100 LDS-STU pairs

# %%
# Load the saved store data
import pickle
import glob

# Get the most recent store file
store_files = glob.glob('stu_lds_store_*.pkl')
latest_store = max(store_files)

# Load the data
with open(latest_store, 'rb') as f:
    store_data = pickle.load(f)

# Reconstruct LDS and STU objects from the saved parameters
store = []
for lds_params, stu_params in store_data:
    # Create LDS with loaded parameters
    
    A = torch.tensor(lds_params['A'])
    B = torch.tensor(lds_params['B']) 
    C = torch.tensor(lds_params['C'])
    D = torch.tensor(lds_params['D'])
    h0 = torch.tensor(lds_params['h0'])

    lds = LDS(A,B,C,D,h0)    

    # Create STU with loaded parameters
    stu = STU(stu_config, phi)
    stu.M_phi_plus.data = torch.tensor(stu_params['M_phi_plus'])
    stu.M_phi_minus.data= torch.tensor(stu_params['M_phi_minus'])
    stu.M.data = torch.tensor(stu_params['M'])

    store.append((lds, stu))

print(f"Loaded store data from {latest_store}")
# Out:
# Saved store data to stu_lds_store_20250223_214652.pkl

# %%
def gen_lds_impulse(lds,autoreg): #need the stu for to add the negative autoregressive component
    lds_impulse = torch.zeros(seq_len)
    for i in range(stu_config["k_u"]):
        lds_impulse[i] = -1 * torch.tensor(autoreg[0][0][i])
    for i in range(seq_len):
        a_power = lds.A ** i
        lds_impulse[i] += torch.sum(lds.C[:, 0] * a_power * lds.B[0]).cpu()
    return lds_impulse

phi_n = phi.data.cpu().numpy()

def gen_stu_impulse(stu):
    alt_sign = lambda x: x * np.array([1, -1] * 2048)
    pos_coef = stu.M_phi_plus.data.cpu().numpy()[:, 0,0]
    neg_coef = stu.M_phi_minus.data.cpu().numpy()[:,0,0]
    impulse = np.sum(phi_n*pos_coef, axis = -1) + alt_sign(np.sum(phi_n*neg_coef, axis = -1))
    return impulse

# %%
# Get impulse responses for both LDS and STU models and store with MSE losses
pairs_with_mse = []

for lds, stu in store:
    lds_impulse = gen_lds_impulse(lds, stu.M.detach().cpu().numpy())
    stu_impulse = gen_stu_impulse(stu)
    
    # Calculate MSE between impulse responses
    mse = F.mse_loss(torch.tensor(lds_impulse)[10:], torch.tensor(stu_impulse)[10:])
    
    # Store pair with its MSE
    pairs_with_mse.append((mse, lds, stu))

# Sort by MSE and take top 40
pairs_with_mse.sort(key=lambda x: x[0])
filtered_store = [(lds, stu) for _, lds, stu in pairs_with_mse[:200]]
# Out:
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/54032057.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mse = F.mse_loss(torch.tensor(lds_impulse)[10:], torch.tensor(stu_impulse)[10:])

# %%
# Create alternating sign pattern of length 1024
alternating_signs = np.array([1, -1] * (seq_len//2))

# Multiply phi_n by alternating signs to get alternated version
phi_n_alternating = phi_n * alternating_signs[:, np.newaxis]
# Concatenate original and alternating versions along second axis
phi_n_combined = np.concatenate([phi_n, phi_n_alternating], axis=1)  # Shape: (1024, 40)

# %%
# For each STU, combine M_phi_plus and M_phi_minus
combined_weights = []
for _, stu in filtered_store:
    # Get M_phi_plus and M_phi_minus from STU model
    M_phi_plus = stu.M_phi_plus.detach().cpu().numpy()[:,0,0]
    M_phi_minus = stu.M_phi_minus.detach().cpu().numpy()[:,0,0]
    
    # Concatenate the weights
    combined = np.concatenate([M_phi_plus, M_phi_minus], axis=0)
    combined_weights.append(combined)

# Stack all combined weights into a single array
combined_weights = np.stack(combined_weights)
combined_weights.shape
# Out:
# (100, 60)

# %%
# Reconstruct STU filters using combined weights and phi_n_combined
reconstructed_filters = np.matmul(phi_n_combined, combined_weights.T)  # Shape: (1024, num_models)

# Get original STU impulse responses for comparison
original_impulses = []
for _, stu in filtered_store:
    impulse = gen_stu_impulse(stu)
    original_impulses.append(impulse)
original_impulses = np.stack(original_impulses).T  # Shape: (1024, num_models)

# Compare reconstructed vs original
# Calculate MSE between each pair of reconstructed and original impulses
mses = []
for i in range(reconstructed_filters.shape[1]):
    mse = F.mse_loss(torch.tensor(reconstructed_filters[:,i]), torch.tensor(original_impulses[:,i]))
    mses.append(mse.item())

max_mse = max(mses)
max_idx = mses.index(max_mse)
print(f"Maximum MSE between any reconstructed and original impulse pair: {max_mse:.2e} (at index {max_idx})")

plt.figure(figsize=(10, 6))
plt.plot(reconstructed_filters[:100,0], label='Reconstructed')
plt.plot(original_impulses[:100,0], '--', label='Original') 
plt.title('Comparing Original vs Reconstructed STU Impulse Response')
plt.legend()
plt.show()
# Out:
# Maximum MSE between any reconstructed and original impulse pair: 1.78e-16 (at index 98)

# %%
# Use pseudoinverse to solve for phi_n_combined
# reconstructed_filters = phi_n_combined @ combined_weights.T
# Therefore: phi_n_combined = reconstructed_filters @ pinv(combined_weights.T)
combined_weights_pinv = np.linalg.pinv(combined_weights.T)
phi_n_approx = np.matmul(torch.tensor(original_impulses), combined_weights_pinv)

# Compare original vs approximated phi_n
plt.figure(figsize=(10, 6))
plt.plot(phi_n_combined[:100,0], label='Original phi')
plt.plot(phi_n_approx[:100,0], '--', label='Approximated phi')
plt.title('Comparing Original vs Approximated Basis Functions')
plt.legend()
plt.show()

# Calculate MSE between original and approximated phi
mse = F.mse_loss(torch.tensor(phi_n_combined), torch.tensor(phi_n_approx))
print(f"MSE between original and approximated phi: {mse:.2e}")
# Out:
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/1789712089.py:5: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   phi_n_approx = np.matmul(torch.tensor(original_impulses), combined_weights_pinv)
# MSE between original and approximated phi: 3.90e-14
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/1789712089.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mse = F.mse_loss(torch.tensor(phi_n_combined), torch.tensor(phi_n_approx))

# %%
# Generate impulse responses for LDS models
lds_impulses = []
for lds, stu in filtered_store:
    impulse = gen_lds_impulse(lds, stu.M.detach().cpu().numpy())
    lds_impulses.append(impulse)
lds_impulses = np.stack(lds_impulses).T  # Shape: (seq_len, num_models)

# %%
# simulating adding 10 autoregressive terms
lds_impulses[:10, :] = original_impulses[:10, :]

# %%
# Compare original STU impulses with LDS impulses
plt.figure(figsize=(10, 6))
plt.plot(original_impulses[:100,31], label='STU Impulse')
plt.plot(lds_impulses[:100,31], '--', label='LDS Impulse')
plt.title('Comparing STU vs LDS Impulse Responses')
plt.legend()
plt.show()

# Calculate MSE between STU and LDS impulses
for i in range(40):
    mse = F.mse_loss(torch.tensor(lds_impulses[:, i]), torch.tensor(original_impulses[:, i]))
    print(f"MSE between STU and LDS impulse {i}: {mse:.2e}")
# Out:
# MSE between STU and LDS impulse 0: 5.15e-08
# MSE between STU and LDS impulse 1: 5.30e-08
# MSE between STU and LDS impulse 2: 5.64e-08
# MSE between STU and LDS impulse 3: 7.82e-08
# MSE between STU and LDS impulse 4: 8.31e-08
# MSE between STU and LDS impulse 5: 9.82e-08
# MSE between STU and LDS impulse 6: 9.86e-08
# MSE between STU and LDS impulse 7: 1.01e-07
# MSE between STU and LDS impulse 8: 1.03e-07
# MSE between STU and LDS impulse 9: 1.15e-07
# MSE between STU and LDS impulse 10: 1.18e-07
# MSE between STU and LDS impulse 11: 1.20e-07
# MSE between STU and LDS impulse 12: 1.21e-07
# MSE between STU and LDS impulse 13: 1.24e-07
# MSE between STU and LDS impulse 14: 1.24e-07
# MSE between STU and LDS impulse 15: 1.33e-07
# MSE between STU and LDS impulse 16: 1.36e-07
# MSE between STU and LDS impulse 17: 1.48e-07
# MSE between STU and LDS impulse 18: 1.50e-07
# MSE between STU and LDS impulse 19: 1.54e-07
# MSE between STU and LDS impulse 20: 1.61e-07
# MSE between STU and LDS impulse 21: 1.64e-07
# MSE between STU and LDS impulse 22: 1.65e-07
# MSE between STU and LDS impulse 23: 1.75e-07
# MSE between STU and LDS impulse 24: 1.81e-07
# MSE between STU and LDS impulse 25: 1.82e-07
# MSE between STU and LDS impulse 26: 1.87e-07
# MSE between STU and LDS impulse 27: 1.87e-07
# MSE between STU and LDS impulse 28: 1.89e-07
# MSE between STU and LDS impulse 29: 1.94e-07
# MSE between STU and LDS impulse 30: 2.01e-07
# MSE between STU and LDS impulse 31: 2.07e-07
# MSE between STU and LDS impulse 32: 2.10e-07
# MSE between STU and LDS impulse 33: 2.14e-07
# MSE between STU and LDS impulse 34: 2.25e-07
# MSE between STU and LDS impulse 35: 2.30e-07
# MSE between STU and LDS impulse 36: 2.39e-07
# MSE between STU and LDS impulse 37: 2.42e-07
# MSE between STU and LDS impulse 38: 2.43e-07
# MSE between STU and LDS impulse 39: 2.51e-07

# %%
combined_weights_pinv
# Out:
# tensor([[ 0.2075, -0.4747, -0.0369,  ..., -0.0061, -0.0063, -0.0101],
#         [ 0.0842,  0.0096,  0.2887,  ...,  0.0391, -0.0112,  0.0671],
#         [-0.0051, -0.1862,  0.0414,  ..., -0.0983, -0.0491, -0.1012],
#         ...,
#         [ 0.1362, -0.3818,  0.4514,  ..., -0.0650, -0.0126, -0.0236],
#         [-0.1938,  0.0740,  0.2510,  ...,  0.0123,  0.0082,  0.0212],
#         [ 0.1806,  0.2807, -0.1271,  ..., -0.0501, -0.0476,  0.0576]],
#        requires_grad=True)

# %%
combined_weights_pinv = np.linalg.pinv(combined_weights.T)
phi_n_approx = np.matmul(torch.tensor(lds_impulses), combined_weights_pinv)

# Compare original vs approximated phi_n
plt.figure(figsize=(10, 6))
plt.plot(phi_n_combined[:100,0], label='Original phi')
plt.plot(phi_n_approx[:100,0], '--', label='Approximated phi')
plt.title('Comparing Original vs Approximated Basis Functions')
plt.legend()
plt.show()

# Calculate MSE between original and approximated phi
mse = F.mse_loss(torch.tensor(phi_n_combined), torch.tensor(phi_n_approx))
print(f"MSE between original and approximated phi: {mse:.2e}")
# Out:
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/2629277523.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   phi_n_approx = np.matmul(torch.tensor(lds_impulses), combined_weights_pinv)
# MSE between original and approximated phi: 1.05e-06
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/2629277523.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mse = F.mse_loss(torch.tensor(phi_n_combined), torch.tensor(phi_n_approx))

# %%
combined_weights_pinv = np.linalg.pinv(combined_weights.T)
combined_weights_pinv = torch.tensor(combined_weights_pinv, requires_grad=True).to(torch.float)
lds_impulses_tensor = torch.tensor(lds_impulses)
phi_n_combined_tensor = torch.tensor(phi_n_combined).to(torch.float)

# Gradient descent to refine the weights
optimizer = torch.optim.Adam([combined_weights_pinv], lr=1e-5)

for i in range(1000000):
    optimizer.zero_grad()
    
    # Forward pass
    phi_n_approx = torch.matmul(lds_impulses_tensor, combined_weights_pinv)
    
    # Calculate loss focusing on first column
    loss = F.mse_loss(phi_n_approx[:,0], phi_n_combined_tensor[:,0])
    
    # Backward pass
    loss.backward()
    optimizer.step()
    
    if i % 100 == 0:
        print(f"Iteration {i}, Loss: {loss.item():.2e}")

# Convert back to numpy for plotting
phi_n_approx = torch.matmul(lds_impulses_tensor, combined_weights_pinv).detach()

# Compare original vs approximated phi_n
plt.figure(figsize=(10, 6))
plt.plot(phi_n_combined[:100,0], label='Original phi')
plt.plot(phi_n_approx[:100,0], '--', label='Approximated phi')
plt.title('Comparing Original vs Approximated Basis Functions')
plt.legend()
plt.show()

# Calculate MSE between original and approximated phi
mse = F.mse_loss(phi_n_combined_tensor, phi_n_approx)
print(f"MSE between original and approximated phi: {mse:.2e}")
# Out:
# Iteration 0, Loss: 6.28e-07
# Iteration 100, Loss: 2.27e-07
# Iteration 200, Loss: 9.25e-08
# Iteration 300, Loss: 5.16e-08
# Iteration 400, Loss: 4.05e-08
# Iteration 500, Loss: 3.65e-08
# Iteration 600, Loss: 3.42e-08
# Iteration 700, Loss: 3.25e-08
# Iteration 800, Loss: 3.11e-08
# Iteration 900, Loss: 2.99e-08
# Iteration 1000, Loss: 2.90e-08
# Iteration 1100, Loss: 2.81e-08
# Iteration 1200, Loss: 2.73e-08
# Iteration 1300, Loss: 2.66e-08
# Iteration 1400, Loss: 2.59e-08
# Iteration 1500, Loss: 2.52e-08
# Iteration 1600, Loss: 2.46e-08
# Iteration 1700, Loss: 2.40e-08
# Iteration 1800, Loss: 2.34e-08
# Iteration 1900, Loss: 2.28e-08
# Iteration 2000, Loss: 2.23e-08
# Iteration 2100, Loss: 2.18e-08
# Iteration 2200, Loss: 2.14e-08
# Iteration 2300, Loss: 2.09e-08
# Iteration 2400, Loss: 2.05e-08
# Iteration 2500, Loss: 2.01e-08
# Iteration 2600, Loss: 1.97e-08
# Iteration 2700, Loss: 1.94e-08
# Iteration 2800, Loss: 1.91e-08
# Iteration 2900, Loss: 1.88e-08
# Iteration 3000, Loss: 1.86e-08
# Iteration 3100, Loss: 1.83e-08
# Iteration 3200, Loss: 1.81e-08
# Iteration 3300, Loss: 1.79e-08
# Iteration 3400, Loss: 1.78e-08
# Iteration 3500, Loss: 1.76e-08
# Iteration 3600, Loss: 1.75e-08
# Iteration 3700, Loss: 1.74e-08
# Iteration 3800, Loss: 1.73e-08
# Iteration 3900, Loss: 1.72e-08
# Iteration 4000, Loss: 1.71e-08
# Iteration 4100, Loss: 1.70e-08
# Iteration 4200, Loss: 1.70e-08
# Iteration 4300, Loss: 1.69e-08
# Iteration 4400, Loss: 1.68e-08
# Iteration 4500, Loss: 1.68e-08
# Iteration 4600, Loss: 1.68e-08
# Iteration 4700, Loss: 1.67e-08
# Iteration 4800, Loss: 1.67e-08
# Iteration 4900, Loss: 1.66e-08
# Iteration 5000, Loss: 1.66e-08
# Iteration 5100, Loss: 1.66e-08
# Iteration 5200, Loss: 1.66e-08
# Iteration 5300, Loss: 1.65e-08
# Iteration 5400, Loss: 1.65e-08
# Iteration 5500, Loss: 1.65e-08
# Iteration 5600, Loss: 1.65e-08
# Iteration 5700, Loss: 1.64e-08
# Iteration 5800, Loss: 1.64e-08
# Iteration 5900, Loss: 1.64e-08
# Iteration 6000, Loss: 1.64e-08
# Iteration 6100, Loss: 1.64e-08
# Iteration 6200, Loss: 1.63e-08
# Iteration 6300, Loss: 1.63e-08
# Iteration 6400, Loss: 1.63e-08
# Iteration 6500, Loss: 1.63e-08
# Iteration 6600, Loss: 1.63e-08
# Iteration 6700, Loss: 1.63e-08
# Iteration 6800, Loss: 1.62e-08
# Iteration 6900, Loss: 1.62e-08
# Iteration 7000, Loss: 1.62e-08
# Iteration 7100, Loss: 1.62e-08
# Iteration 7200, Loss: 1.62e-08
# Iteration 7300, Loss: 1.62e-08
# Iteration 7400, Loss: 1.62e-08
# Iteration 7500, Loss: 1.62e-08
# Iteration 7600, Loss: 1.62e-08
# Iteration 7700, Loss: 1.61e-08
# Iteration 7800, Loss: 1.61e-08
# Iteration 7900, Loss: 1.61e-08
# Iteration 8000, Loss: 1.61e-08
# Iteration 8100, Loss: 1.61e-08
# Iteration 8200, Loss: 1.61e-08
# Iteration 8300, Loss: 1.61e-08
# Iteration 8400, Loss: 1.61e-08
# Iteration 8500, Loss: 1.61e-08
# Iteration 8600, Loss: 1.61e-08
# Iteration 8700, Loss: 1.61e-08
# Iteration 8800, Loss: 1.61e-08
# Iteration 8900, Loss: 1.61e-08
# Iteration 9000, Loss: 1.60e-08
# Iteration 9100, Loss: 1.60e-08
# Iteration 9200, Loss: 1.60e-08
# Iteration 9300, Loss: 1.60e-08
# Iteration 9400, Loss: 1.60e-08
# Iteration 9500, Loss: 1.60e-08
# Iteration 9600, Loss: 1.60e-08
# Iteration 9700, Loss: 1.60e-08
# Iteration 9800, Loss: 1.60e-08
# Iteration 9900, Loss: 1.60e-08
# Iteration 10000, Loss: 1.60e-08
# Iteration 10100, Loss: 1.60e-08
# Iteration 10200, Loss: 1.60e-08
# Iteration 10300, Loss: 1.60e-08
# Iteration 10400, Loss: 1.60e-08
# Iteration 10500, Loss: 1.60e-08
# Iteration 10600, Loss: 1.60e-08
# Iteration 10700, Loss: 1.60e-08
# Iteration 10800, Loss: 1.60e-08
# Iteration 10900, Loss: 1.59e-08
# Iteration 11000, Loss: 1.59e-08
# Iteration 11100, Loss: 1.59e-08
# Iteration 11200, Loss: 1.59e-08
# Iteration 11300, Loss: 1.59e-08
# Iteration 11400, Loss: 1.59e-08
# Iteration 11500, Loss: 1.59e-08
# Iteration 11600, Loss: 1.59e-08
# Iteration 11700, Loss: 1.59e-08
# Iteration 11800, Loss: 1.59e-08
# Iteration 11900, Loss: 1.59e-08
# Iteration 12000, Loss: 1.59e-08
# Iteration 12100, Loss: 1.59e-08
# Iteration 12200, Loss: 1.59e-08
# Iteration 12300, Loss: 1.59e-08
# Iteration 12400, Loss: 1.59e-08
# Iteration 12500, Loss: 1.59e-08
# Iteration 12600, Loss: 1.59e-08
# Iteration 12700, Loss: 1.59e-08
# Iteration 12800, Loss: 1.59e-08
# Iteration 12900, Loss: 1.59e-08
# Iteration 13000, Loss: 1.59e-08
# Iteration 13100, Loss: 1.59e-08
# Iteration 13200, Loss: 1.59e-08
# Iteration 13300, Loss: 1.59e-08
# Iteration 13400, Loss: 1.59e-08
# Iteration 13500, Loss: 1.59e-08
# Iteration 13600, Loss: 1.59e-08
# Iteration 13700, Loss: 1.59e-08
# Iteration 13800, Loss: 1.58e-08
# Iteration 13900, Loss: 1.58e-08
# Iteration 14000, Loss: 1.58e-08
# Iteration 14100, Loss: 1.58e-08
# Iteration 14200, Loss: 1.58e-08
# Iteration 14300, Loss: 1.58e-08
# Iteration 14400, Loss: 1.58e-08
# Iteration 14500, Loss: 1.58e-08
# Iteration 14600, Loss: 1.58e-08
# Iteration 14700, Loss: 1.58e-08
# Iteration 14800, Loss: 1.58e-08
# Iteration 14900, Loss: 1.58e-08
# Iteration 15000, Loss: 1.58e-08
# Iteration 15100, Loss: 1.58e-08
# Iteration 15200, Loss: 1.58e-08
# Iteration 15300, Loss: 1.58e-08
# Iteration 15400, Loss: 1.58e-08
# Iteration 15500, Loss: 1.58e-08
# Iteration 15600, Loss: 1.58e-08
# Iteration 15700, Loss: 1.58e-08
# Iteration 15800, Loss: 1.58e-08
# Iteration 15900, Loss: 1.58e-08
# Iteration 16000, Loss: 1.58e-08
# Iteration 16100, Loss: 1.58e-08
# Iteration 16200, Loss: 1.58e-08
# Iteration 16300, Loss: 1.58e-08
# Iteration 16400, Loss: 1.58e-08
# Iteration 16500, Loss: 1.58e-08
# Iteration 16600, Loss: 1.58e-08
# Iteration 16700, Loss: 1.58e-08
# Iteration 16800, Loss: 1.58e-08
# Iteration 16900, Loss: 1.58e-08
# Iteration 17000, Loss: 1.58e-08
# Iteration 17100, Loss: 1.58e-08
# Iteration 17200, Loss: 1.58e-08
# Iteration 17300, Loss: 1.58e-08
# Iteration 17400, Loss: 1.58e-08
# Iteration 17500, Loss: 1.58e-08
# Iteration 17600, Loss: 1.58e-08
# Iteration 17700, Loss: 1.58e-08
# Iteration 17800, Loss: 1.58e-08
# Iteration 17900, Loss: 1.58e-08
# Iteration 18000, Loss: 1.58e-08
# Iteration 18100, Loss: 1.58e-08
# Iteration 18200, Loss: 1.58e-08
# Iteration 18300, Loss: 1.58e-08
# Iteration 18400, Loss: 1.58e-08
# Iteration 18500, Loss: 1.58e-08
# Iteration 18600, Loss: 1.58e-08
# Iteration 18700, Loss: 1.58e-08
# Iteration 18800, Loss: 1.57e-08
# Iteration 18900, Loss: 1.57e-08
# Iteration 19000, Loss: 1.57e-08
# Iteration 19100, Loss: 1.57e-08
# Iteration 19200, Loss: 1.57e-08
# Iteration 19300, Loss: 1.57e-08
# Iteration 19400, Loss: 1.57e-08
# Iteration 19500, Loss: 1.57e-08
# Iteration 19600, Loss: 1.57e-08
# Iteration 19700, Loss: 1.57e-08
# Iteration 19800, Loss: 1.57e-08
# Iteration 19900, Loss: 1.57e-08
# Iteration 20000, Loss: 1.57e-08
# Iteration 20100, Loss: 1.57e-08
# Iteration 20200, Loss: 1.57e-08
# Iteration 20300, Loss: 1.57e-08
# Iteration 20400, Loss: 1.57e-08
# Iteration 20500, Loss: 1.57e-08
# Iteration 20600, Loss: 1.57e-08
# Iteration 20700, Loss: 1.57e-08
# Iteration 20800, Loss: 1.57e-08
# Iteration 20900, Loss: 1.57e-08
# Iteration 21000, Loss: 1.57e-08
# Iteration 21100, Loss: 1.57e-08
# Iteration 21200, Loss: 1.57e-08
# Iteration 21300, Loss: 1.57e-08
# Iteration 21400, Loss: 1.57e-08
# Iteration 21500, Loss: 1.57e-08
# Iteration 21600, Loss: 1.57e-08
# Iteration 21700, Loss: 1.57e-08
# Iteration 21800, Loss: 1.57e-08
# Iteration 21900, Loss: 1.57e-08
# Iteration 22000, Loss: 1.57e-08
# Iteration 22100, Loss: 1.57e-08
# Iteration 22200, Loss: 1.57e-08
# Iteration 22300, Loss: 1.57e-08
# Iteration 22400, Loss: 1.57e-08
# Iteration 22500, Loss: 1.57e-08
# Iteration 22600, Loss: 1.57e-08
# Iteration 22700, Loss: 1.57e-08
# Iteration 22800, Loss: 1.57e-08
# Iteration 22900, Loss: 1.57e-08
# Iteration 23000, Loss: 1.57e-08
# Iteration 23100, Loss: 1.57e-08
# Iteration 23200, Loss: 1.57e-08
# Iteration 23300, Loss: 1.57e-08
# Iteration 23400, Loss: 1.57e-08
# Iteration 23500, Loss: 1.57e-08
# Iteration 23600, Loss: 1.57e-08
# Iteration 23700, Loss: 1.57e-08
# Iteration 23800, Loss: 1.57e-08
# Iteration 23900, Loss: 1.57e-08
# Iteration 24000, Loss: 1.57e-08
# Iteration 24100, Loss: 1.57e-08
# Iteration 24200, Loss: 1.57e-08
# Iteration 24300, Loss: 1.57e-08
# Iteration 24400, Loss: 1.57e-08
# Iteration 24500, Loss: 1.57e-08
# Iteration 24600, Loss: 1.57e-08
# Iteration 24700, Loss: 1.57e-08
# Iteration 24800, Loss: 1.57e-08
# Iteration 24900, Loss: 1.57e-08
# Iteration 25000, Loss: 1.57e-08
# Iteration 25100, Loss: 1.57e-08
# Iteration 25200, Loss: 1.57e-08
# Iteration 25300, Loss: 1.57e-08
# Iteration 25400, Loss: 1.57e-08
# Iteration 25500, Loss: 1.57e-08
# Iteration 25600, Loss: 1.57e-08
# Iteration 25700, Loss: 1.57e-08
# Iteration 25800, Loss: 1.57e-08
# Iteration 25900, Loss: 1.57e-08
# Iteration 26000, Loss: 1.57e-08
# Iteration 26100, Loss: 1.57e-08
# Iteration 26200, Loss: 1.57e-08
# Iteration 26300, Loss: 1.57e-08
# Iteration 26400, Loss: 1.57e-08
# Iteration 26500, Loss: 1.57e-08
# Iteration 26600, Loss: 1.57e-08
# Iteration 26700, Loss: 1.57e-08
# Iteration 26800, Loss: 1.57e-08
# Iteration 26900, Loss: 1.57e-08
# Iteration 27000, Loss: 1.57e-08
# Iteration 27100, Loss: 1.57e-08
# Iteration 27200, Loss: 1.56e-08
# Iteration 27300, Loss: 1.56e-08
# Iteration 27400, Loss: 1.56e-08
# Iteration 27500, Loss: 1.56e-08
# Iteration 27600, Loss: 1.56e-08
# Iteration 27700, Loss: 1.56e-08
# Iteration 27800, Loss: 1.56e-08
# Iteration 27900, Loss: 1.56e-08
# Iteration 28000, Loss: 1.56e-08
# Iteration 28100, Loss: 1.56e-08
# Iteration 28200, Loss: 1.56e-08
# Iteration 28300, Loss: 1.56e-08
# Iteration 28400, Loss: 1.56e-08
# Iteration 28500, Loss: 1.56e-08
# Iteration 28600, Loss: 1.56e-08
# Iteration 28700, Loss: 1.56e-08
# Iteration 28800, Loss: 1.56e-08
# Iteration 28900, Loss: 1.56e-08
# Iteration 29000, Loss: 1.56e-08
# Iteration 29100, Loss: 1.56e-08
# Iteration 29200, Loss: 1.56e-08
# Iteration 29300, Loss: 1.56e-08
# Iteration 29400, Loss: 1.56e-08
# Iteration 29500, Loss: 1.56e-08
# Iteration 29600, Loss: 1.56e-08
# Iteration 29700, Loss: 1.56e-08
# Iteration 29800, Loss: 1.56e-08
# Iteration 29900, Loss: 1.56e-08
# Iteration 30000, Loss: 1.56e-08
# Iteration 30100, Loss: 1.56e-08
# Iteration 30200, Loss: 1.56e-08
# Iteration 30300, Loss: 1.56e-08
# Iteration 30400, Loss: 1.56e-08
# Iteration 30500, Loss: 1.56e-08
# Iteration 30600, Loss: 1.56e-08
# Iteration 30700, Loss: 1.56e-08
# Iteration 30800, Loss: 1.56e-08
# Iteration 30900, Loss: 1.56e-08
# Iteration 31000, Loss: 1.56e-08
# Iteration 31100, Loss: 1.56e-08
# Iteration 31200, Loss: 1.56e-08
# Iteration 31300, Loss: 1.56e-08
# Iteration 31400, Loss: 1.56e-08
# Iteration 31500, Loss: 1.56e-08
# Iteration 31600, Loss: 1.56e-08
# Iteration 31700, Loss: 1.56e-08
# Iteration 31800, Loss: 1.56e-08
# Iteration 31900, Loss: 1.56e-08
# Iteration 32000, Loss: 1.56e-08
# Iteration 32100, Loss: 1.56e-08
# Iteration 32200, Loss: 1.56e-08
# Iteration 32300, Loss: 1.56e-08
# Iteration 32400, Loss: 1.56e-08
# Iteration 32500, Loss: 1.56e-08
# Iteration 32600, Loss: 1.56e-08
# Iteration 32700, Loss: 1.56e-08
# Iteration 32800, Loss: 1.56e-08
# Iteration 32900, Loss: 1.56e-08
# Iteration 33000, Loss: 1.56e-08
# Iteration 33100, Loss: 1.56e-08
# Iteration 33200, Loss: 1.56e-08
# Iteration 33300, Loss: 1.56e-08
# Iteration 33400, Loss: 1.56e-08
# Iteration 33500, Loss: 1.56e-08
# Iteration 33600, Loss: 1.56e-08
# Iteration 33700, Loss: 1.56e-08
# Iteration 33800, Loss: 1.56e-08
# Iteration 33900, Loss: 1.56e-08
# Iteration 34000, Loss: 1.56e-08
# Iteration 34100, Loss: 1.56e-08
# Iteration 34200, Loss: 1.56e-08
# Iteration 34300, Loss: 1.56e-08
# Iteration 34400, Loss: 1.56e-08
# Iteration 34500, Loss: 1.56e-08
# Iteration 34600, Loss: 1.56e-08
# Iteration 34700, Loss: 1.56e-08
# Iteration 34800, Loss: 1.56e-08
# Iteration 34900, Loss: 1.56e-08
# Iteration 35000, Loss: 1.56e-08
# Iteration 35100, Loss: 1.56e-08
# Iteration 35200, Loss: 1.56e-08
# Iteration 35300, Loss: 1.56e-08
# Iteration 35400, Loss: 1.56e-08
# Iteration 35500, Loss: 1.56e-08
# Iteration 35600, Loss: 1.56e-08
# Iteration 35700, Loss: 1.56e-08
# Iteration 35800, Loss: 1.56e-08
# Iteration 35900, Loss: 1.56e-08
# Iteration 36000, Loss: 1.56e-08
# Iteration 36100, Loss: 1.56e-08
# Iteration 36200, Loss: 1.56e-08
# Iteration 36300, Loss: 1.56e-08
# Iteration 36400, Loss: 1.56e-08
# Iteration 36500, Loss: 1.56e-08
# Iteration 36600, Loss: 1.56e-08
# Iteration 36700, Loss: 1.56e-08
# Iteration 36800, Loss: 1.56e-08
# Iteration 36900, Loss: 1.56e-08
# Iteration 37000, Loss: 1.56e-08
# Iteration 37100, Loss: 1.56e-08
# Iteration 37200, Loss: 1.56e-08
# Iteration 37300, Loss: 1.56e-08
# Iteration 37400, Loss: 1.56e-08
# Iteration 37500, Loss: 1.56e-08
# Iteration 37600, Loss: 1.56e-08
# Iteration 37700, Loss: 1.56e-08
# Iteration 37800, Loss: 1.56e-08
# Iteration 37900, Loss: 1.56e-08
# Iteration 38000, Loss: 1.56e-08
# Iteration 38100, Loss: 1.56e-08
# Iteration 38200, Loss: 1.56e-08
# Iteration 38300, Loss: 1.56e-08
# Iteration 38400, Loss: 1.56e-08
# Iteration 38500, Loss: 1.56e-08
# Iteration 38600, Loss: 1.56e-08
# Iteration 38700, Loss: 1.56e-08
# Iteration 38800, Loss: 1.56e-08
# Iteration 38900, Loss: 1.56e-08
# Iteration 39000, Loss: 1.56e-08
# Iteration 39100, Loss: 1.56e-08
# Iteration 39200, Loss: 1.56e-08
# Iteration 39300, Loss: 1.56e-08
# Iteration 39400, Loss: 1.56e-08
# Iteration 39500, Loss: 1.56e-08
# Iteration 39600, Loss: 1.56e-08
# Iteration 39700, Loss: 1.56e-08
# Iteration 39800, Loss: 1.56e-08
# Iteration 39900, Loss: 1.56e-08
# Iteration 40000, Loss: 1.55e-08
# Iteration 40100, Loss: 1.56e-08
# Iteration 40200, Loss: 1.55e-08
# Iteration 40300, Loss: 1.55e-08
# Iteration 40400, Loss: 1.55e-08
# Iteration 40500, Loss: 1.55e-08
# Iteration 40600, Loss: 1.55e-08
# Iteration 40700, Loss: 1.55e-08
# Iteration 40800, Loss: 1.55e-08
# Iteration 40900, Loss: 1.55e-08
# Iteration 41000, Loss: 1.55e-08
# Iteration 41100, Loss: 1.55e-08
# Iteration 41200, Loss: 1.55e-08
# Iteration 41300, Loss: 1.55e-08
# Iteration 41400, Loss: 1.55e-08
# Iteration 41500, Loss: 1.55e-08
# Iteration 41600, Loss: 1.55e-08
# Iteration 41700, Loss: 1.55e-08
# Iteration 41800, Loss: 1.55e-08
# Iteration 41900, Loss: 1.55e-08
# Iteration 42000, Loss: 1.55e-08
# Iteration 42100, Loss: 1.55e-08
# Iteration 42200, Loss: 1.55e-08
# Iteration 42300, Loss: 1.55e-08
# Iteration 42400, Loss: 1.55e-08
# Iteration 42500, Loss: 1.55e-08
# Iteration 42600, Loss: 1.55e-08
# Iteration 42700, Loss: 1.55e-08
# Iteration 42800, Loss: 1.55e-08
# Iteration 42900, Loss: 1.55e-08
# Iteration 43000, Loss: 1.55e-08
# Iteration 43100, Loss: 1.55e-08
# Iteration 43200, Loss: 1.55e-08
# Iteration 43300, Loss: 1.55e-08
# Iteration 43400, Loss: 1.55e-08
# Iteration 43500, Loss: 1.55e-08
# Iteration 43600, Loss: 1.55e-08
# Iteration 43700, Loss: 1.55e-08
# Iteration 43800, Loss: 1.55e-08
# Iteration 43900, Loss: 1.55e-08
# Iteration 44000, Loss: 1.55e-08
# Iteration 44100, Loss: 1.55e-08
# Iteration 44200, Loss: 1.55e-08
# Iteration 44300, Loss: 1.55e-08
# Iteration 44400, Loss: 1.55e-08
# Iteration 44500, Loss: 1.55e-08
# Iteration 44600, Loss: 1.55e-08
# Iteration 44700, Loss: 1.55e-08
# Iteration 44800, Loss: 1.55e-08
# Iteration 44900, Loss: 1.55e-08
# Iteration 45000, Loss: 1.55e-08
# Iteration 45100, Loss: 1.55e-08
# Iteration 45200, Loss: 1.55e-08
# Iteration 45300, Loss: 1.55e-08
# Iteration 45400, Loss: 1.55e-08
# Iteration 45500, Loss: 1.55e-08
# Iteration 45600, Loss: 1.55e-08
# Iteration 45700, Loss: 1.55e-08
# Iteration 45800, Loss: 1.55e-08
# Iteration 45900, Loss: 1.55e-08
# Iteration 46000, Loss: 1.55e-08
# Iteration 46100, Loss: 1.55e-08
# Iteration 46200, Loss: 1.55e-08
# Iteration 46300, Loss: 1.55e-08
# Iteration 46400, Loss: 1.55e-08
# Iteration 46500, Loss: 1.55e-08
# Iteration 46600, Loss: 1.55e-08
# Iteration 46700, Loss: 1.55e-08
# Iteration 46800, Loss: 1.55e-08
# Iteration 46900, Loss: 1.55e-08
# Iteration 47000, Loss: 1.55e-08
# Iteration 47100, Loss: 1.55e-08
# Iteration 47200, Loss: 1.55e-08
# Iteration 47300, Loss: 1.55e-08
# Iteration 47400, Loss: 1.55e-08
# Iteration 47500, Loss: 1.55e-08
# Iteration 47600, Loss: 1.55e-08
# Iteration 47700, Loss: 1.55e-08
# Iteration 47800, Loss: 1.55e-08
# Iteration 47900, Loss: 1.55e-08
# Iteration 48000, Loss: 1.55e-08
# Iteration 48100, Loss: 1.55e-08
# Iteration 48200, Loss: 1.55e-08
# Iteration 48300, Loss: 1.55e-08
# Iteration 48400, Loss: 1.55e-08
# Iteration 48500, Loss: 1.55e-08
# Iteration 48600, Loss: 1.55e-08
# Iteration 48700, Loss: 1.55e-08
# Iteration 48800, Loss: 1.55e-08
# Iteration 48900, Loss: 1.55e-08
# Iteration 49000, Loss: 1.55e-08
# Iteration 49100, Loss: 1.55e-08
# Iteration 49200, Loss: 1.55e-08
# Iteration 49300, Loss: 1.55e-08
# Iteration 49400, Loss: 1.55e-08
# Iteration 49500, Loss: 1.55e-08
# Iteration 49600, Loss: 1.55e-08
# Iteration 49700, Loss: 1.55e-08
# Iteration 49800, Loss: 1.55e-08
# Iteration 49900, Loss: 1.55e-08
# Iteration 50000, Loss: 1.55e-08
# Iteration 50100, Loss: 1.55e-08
# Iteration 50200, Loss: 1.55e-08
# Iteration 50300, Loss: 1.55e-08
# Iteration 50400, Loss: 1.55e-08
# Iteration 50500, Loss: 1.55e-08
# Iteration 50600, Loss: 1.55e-08
# Iteration 50700, Loss: 1.55e-08
# Iteration 50800, Loss: 1.55e-08
# Iteration 50900, Loss: 1.55e-08
# Iteration 51000, Loss: 1.55e-08
# Iteration 51100, Loss: 1.55e-08
# Iteration 51200, Loss: 1.55e-08
# Iteration 51300, Loss: 1.55e-08
# Iteration 51400, Loss: 1.55e-08
# Iteration 51500, Loss: 1.55e-08
# Iteration 51600, Loss: 1.55e-08
# Iteration 51700, Loss: 1.55e-08
# Iteration 51800, Loss: 1.55e-08
# Iteration 51900, Loss: 1.55e-08
# Iteration 52000, Loss: 1.55e-08
# Iteration 52100, Loss: 1.55e-08
# Iteration 52200, Loss: 1.55e-08
# Iteration 52300, Loss: 1.55e-08
# Iteration 52400, Loss: 1.55e-08
# Iteration 52500, Loss: 1.55e-08
# Iteration 52600, Loss: 1.55e-08
# Iteration 52700, Loss: 1.55e-08
# Iteration 52800, Loss: 1.55e-08
# Iteration 52900, Loss: 1.55e-08
# Iteration 53000, Loss: 1.55e-08
# Iteration 53100, Loss: 1.55e-08
# Iteration 53200, Loss: 1.55e-08
# Iteration 53300, Loss: 1.55e-08
# Iteration 53400, Loss: 1.55e-08
# Iteration 53500, Loss: 1.55e-08
# Iteration 53600, Loss: 1.55e-08
# Iteration 53700, Loss: 1.55e-08
# Iteration 53800, Loss: 1.55e-08
# Iteration 53900, Loss: 1.55e-08
# Iteration 54000, Loss: 1.55e-08
# Iteration 54100, Loss: 1.55e-08
# Iteration 54200, Loss: 1.55e-08
# Iteration 54300, Loss: 1.55e-08
# Iteration 54400, Loss: 1.55e-08
# Iteration 54500, Loss: 1.55e-08
# Iteration 54600, Loss: 1.55e-08
# Iteration 54700, Loss: 1.55e-08
# Iteration 54800, Loss: 1.55e-08
# Iteration 54900, Loss: 1.55e-08
# Iteration 55000, Loss: 1.55e-08
# Iteration 55100, Loss: 1.55e-08
# Iteration 55200, Loss: 1.55e-08
# Iteration 55300, Loss: 1.55e-08
# Iteration 55400, Loss: 1.55e-08
# Iteration 55500, Loss: 1.55e-08
# Iteration 55600, Loss: 1.55e-08
# Iteration 55700, Loss: 1.55e-08
# Iteration 55800, Loss: 1.55e-08
# Iteration 55900, Loss: 1.55e-08
# Iteration 56000, Loss: 1.55e-08
# Iteration 56100, Loss: 1.55e-08
# Iteration 56200, Loss: 1.55e-08
# Iteration 56300, Loss: 1.55e-08
# Iteration 56400, Loss: 1.55e-08
# Iteration 56500, Loss: 1.55e-08
# Iteration 56600, Loss: 1.55e-08
# Iteration 56700, Loss: 1.55e-08
# Iteration 56800, Loss: 1.54e-08
# Iteration 56900, Loss: 1.55e-08
# Iteration 57000, Loss: 1.55e-08
# Iteration 57100, Loss: 1.54e-08
# Iteration 57200, Loss: 1.54e-08
# Iteration 57300, Loss: 1.54e-08
# Iteration 57400, Loss: 1.54e-08
# Iteration 57500, Loss: 1.54e-08
# Iteration 57600, Loss: 1.54e-08
# Iteration 57700, Loss: 1.54e-08
# Iteration 57800, Loss: 1.54e-08
# Iteration 57900, Loss: 1.54e-08
# Iteration 58000, Loss: 1.54e-08
# Iteration 58100, Loss: 1.54e-08
# Iteration 58200, Loss: 1.54e-08
# Iteration 58300, Loss: 1.54e-08
# Iteration 58400, Loss: 1.54e-08
# Iteration 58500, Loss: 1.54e-08
# Iteration 58600, Loss: 1.54e-08
# Iteration 58700, Loss: 1.54e-08
# Iteration 58800, Loss: 1.54e-08
# Iteration 58900, Loss: 1.54e-08
# Iteration 59000, Loss: 1.54e-08
# Iteration 59100, Loss: 1.54e-08
# Iteration 59200, Loss: 1.54e-08
# Iteration 59300, Loss: 1.54e-08
# Iteration 59400, Loss: 1.54e-08
# Iteration 59500, Loss: 1.54e-08
# Iteration 59600, Loss: 1.54e-08
# Iteration 59700, Loss: 1.54e-08
# Iteration 59800, Loss: 1.54e-08
# Iteration 59900, Loss: 1.54e-08
# Iteration 60000, Loss: 1.54e-08
# Iteration 60100, Loss: 1.54e-08
# Iteration 60200, Loss: 1.54e-08
# Iteration 60300, Loss: 1.54e-08
# Iteration 60400, Loss: 1.54e-08
# Iteration 60500, Loss: 1.54e-08
# Iteration 60600, Loss: 1.54e-08
# Iteration 60700, Loss: 1.54e-08
# Iteration 60800, Loss: 1.54e-08
# Iteration 60900, Loss: 1.54e-08
# Iteration 61000, Loss: 1.54e-08
# Iteration 61100, Loss: 1.54e-08
# Iteration 61200, Loss: 1.54e-08
# Iteration 61300, Loss: 1.54e-08
# Iteration 61400, Loss: 1.54e-08
# Iteration 61500, Loss: 1.54e-08
# Iteration 61600, Loss: 1.54e-08
# Iteration 61700, Loss: 1.54e-08
# Iteration 61800, Loss: 1.54e-08
# Iteration 61900, Loss: 1.54e-08
# Iteration 62000, Loss: 1.54e-08
# Iteration 62100, Loss: 1.54e-08
# Iteration 62200, Loss: 1.54e-08
# Iteration 62300, Loss: 1.54e-08
# Iteration 62400, Loss: 1.54e-08
# Iteration 62500, Loss: 1.54e-08
# Iteration 62600, Loss: 1.54e-08
# Iteration 62700, Loss: 1.54e-08
# Iteration 62800, Loss: 1.54e-08
# Iteration 62900, Loss: 1.54e-08
# Iteration 63000, Loss: 1.54e-08
# Iteration 63100, Loss: 1.54e-08
# Iteration 63200, Loss: 1.54e-08
# Iteration 63300, Loss: 1.54e-08
# Iteration 63400, Loss: 1.54e-08
# Iteration 63500, Loss: 1.54e-08
# Iteration 63600, Loss: 1.54e-08
# Iteration 63700, Loss: 1.54e-08
# Iteration 63800, Loss: 1.54e-08
# Iteration 63900, Loss: 1.54e-08
# Iteration 64000, Loss: 1.54e-08
# Iteration 64100, Loss: 1.54e-08
# Iteration 64200, Loss: 1.54e-08
# Iteration 64300, Loss: 1.54e-08
# Iteration 64400, Loss: 1.54e-08
# Iteration 64500, Loss: 1.54e-08
# Iteration 64600, Loss: 1.54e-08
# Iteration 64700, Loss: 1.54e-08
# Iteration 64800, Loss: 1.54e-08
# Iteration 64900, Loss: 1.54e-08
# Iteration 65000, Loss: 1.54e-08
# Iteration 65100, Loss: 1.54e-08
# Iteration 65200, Loss: 1.54e-08
# Iteration 65300, Loss: 1.54e-08
# Iteration 65400, Loss: 1.54e-08
# Iteration 65500, Loss: 1.54e-08
# Iteration 65600, Loss: 1.54e-08
# Iteration 65700, Loss: 1.54e-08
# Iteration 65800, Loss: 1.54e-08
# Iteration 65900, Loss: 1.54e-08
# Iteration 66000, Loss: 1.54e-08
# Iteration 66100, Loss: 1.54e-08
# Iteration 66200, Loss: 1.54e-08
# Iteration 66300, Loss: 1.54e-08
# Iteration 66400, Loss: 1.54e-08
# Iteration 66500, Loss: 1.54e-08
# Iteration 66600, Loss: 1.54e-08
# Iteration 66700, Loss: 1.54e-08
# Iteration 66800, Loss: 1.54e-08
# Iteration 66900, Loss: 1.54e-08
# Iteration 67000, Loss: 1.54e-08
# Iteration 67100, Loss: 1.54e-08
# Iteration 67200, Loss: 1.54e-08
# Iteration 67300, Loss: 1.54e-08
# Iteration 67400, Loss: 1.54e-08
# Iteration 67500, Loss: 1.54e-08
# Iteration 67600, Loss: 1.54e-08
# Iteration 67700, Loss: 1.54e-08
# Iteration 67800, Loss: 1.54e-08
# Iteration 67900, Loss: 1.54e-08
# Iteration 68000, Loss: 1.54e-08
# Iteration 68100, Loss: 1.54e-08
# Iteration 68200, Loss: 1.54e-08
# Iteration 68300, Loss: 1.54e-08
# Iteration 68400, Loss: 1.54e-08
# Iteration 68500, Loss: 1.54e-08
# Iteration 68600, Loss: 1.54e-08
# Iteration 68700, Loss: 1.54e-08
# Iteration 68800, Loss: 1.54e-08
# Iteration 68900, Loss: 1.54e-08
# Iteration 69000, Loss: 1.54e-08
# Iteration 69100, Loss: 1.54e-08
# Iteration 69200, Loss: 1.54e-08
# Iteration 69300, Loss: 1.54e-08
# Iteration 69400, Loss: 1.54e-08
# Iteration 69500, Loss: 1.54e-08
# Iteration 69600, Loss: 1.54e-08
# Iteration 69700, Loss: 1.54e-08
# Iteration 69800, Loss: 1.54e-08
# Iteration 69900, Loss: 1.54e-08
# Iteration 70000, Loss: 1.54e-08
# Iteration 70100, Loss: 1.54e-08
# Iteration 70200, Loss: 1.54e-08
# Iteration 70300, Loss: 1.54e-08
# Iteration 70400, Loss: 1.54e-08
# Iteration 70500, Loss: 1.54e-08
# Iteration 70600, Loss: 1.54e-08
# Iteration 70700, Loss: 1.54e-08
# Iteration 70800, Loss: 1.54e-08
# Iteration 70900, Loss: 1.54e-08
# Iteration 71000, Loss: 1.54e-08
# Iteration 71100, Loss: 1.54e-08
# Iteration 71200, Loss: 1.54e-08
# Iteration 71300, Loss: 1.54e-08
# Iteration 71400, Loss: 1.54e-08
# Iteration 71500, Loss: 1.54e-08
# Iteration 71600, Loss: 1.54e-08
# Iteration 71700, Loss: 1.54e-08
# Iteration 71800, Loss: 1.54e-08
# Iteration 71900, Loss: 1.54e-08
# Iteration 72000, Loss: 1.54e-08
# Iteration 72100, Loss: 1.54e-08
# Iteration 72200, Loss: 1.54e-08
# Iteration 72300, Loss: 1.54e-08
# Iteration 72400, Loss: 1.54e-08
# Iteration 72500, Loss: 1.54e-08
# Iteration 72600, Loss: 1.54e-08
# Iteration 72700, Loss: 1.54e-08
# Iteration 72800, Loss: 1.54e-08
# Iteration 72900, Loss: 1.54e-08
# Iteration 73000, Loss: 1.54e-08
# Iteration 73100, Loss: 1.54e-08
# Iteration 73200, Loss: 1.54e-08
# Iteration 73300, Loss: 1.54e-08
# Iteration 73400, Loss: 1.54e-08
# Iteration 73500, Loss: 1.54e-08
# Iteration 73600, Loss: 1.54e-08
# Iteration 73700, Loss: 1.54e-08
# Iteration 73800, Loss: 1.54e-08
# Iteration 73900, Loss: 1.54e-08
# Iteration 74000, Loss: 1.54e-08
# Iteration 74100, Loss: 1.54e-08
# Iteration 74200, Loss: 1.54e-08
# Iteration 74300, Loss: 1.54e-08
# Iteration 74400, Loss: 1.54e-08
# Iteration 74500, Loss: 1.54e-08
# Iteration 74600, Loss: 1.54e-08
# Iteration 74700, Loss: 1.54e-08
# Iteration 74800, Loss: 1.54e-08
# Iteration 74900, Loss: 1.54e-08
# Iteration 75000, Loss: 1.54e-08
# Iteration 75100, Loss: 1.54e-08
# Iteration 75200, Loss: 1.54e-08
# Iteration 75300, Loss: 1.54e-08
# Iteration 75400, Loss: 1.54e-08
# Iteration 75500, Loss: 1.54e-08
# Iteration 75600, Loss: 1.54e-08
# Iteration 75700, Loss: 1.54e-08
# Iteration 75800, Loss: 1.54e-08
# Iteration 75900, Loss: 1.54e-08
# Iteration 76000, Loss: 1.54e-08
# Iteration 76100, Loss: 1.54e-08
# Iteration 76200, Loss: 1.54e-08
# Iteration 76300, Loss: 1.54e-08
# Iteration 76400, Loss: 1.54e-08
# Iteration 76500, Loss: 1.54e-08
# Iteration 76600, Loss: 1.54e-08
# Iteration 76700, Loss: 1.54e-08
# Iteration 76800, Loss: 1.54e-08
# Iteration 76900, Loss: 1.54e-08
# Iteration 77000, Loss: 1.54e-08
# Iteration 77100, Loss: 1.54e-08
# Iteration 77200, Loss: 1.54e-08
# Iteration 77300, Loss: 1.54e-08
# Iteration 77400, Loss: 1.54e-08
# Iteration 77500, Loss: 1.54e-08
# Iteration 77600, Loss: 1.54e-08
# Iteration 77700, Loss: 1.54e-08
# Iteration 77800, Loss: 1.54e-08
# Iteration 77900, Loss: 1.54e-08
# Iteration 78000, Loss: 1.54e-08
# Iteration 78100, Loss: 1.53e-08
# Iteration 78200, Loss: 1.53e-08
# Iteration 78300, Loss: 1.53e-08
# Iteration 78400, Loss: 1.53e-08
# Iteration 78500, Loss: 1.53e-08
# Iteration 78600, Loss: 1.53e-08
# Iteration 78700, Loss: 1.53e-08
# Iteration 78800, Loss: 1.53e-08
# Iteration 78900, Loss: 1.53e-08
# Iteration 79000, Loss: 1.53e-08
# Iteration 79100, Loss: 1.53e-08
# Iteration 79200, Loss: 1.53e-08
# Iteration 79300, Loss: 1.53e-08
# Iteration 79400, Loss: 1.53e-08
# Iteration 79500, Loss: 1.53e-08
# Iteration 79600, Loss: 1.53e-08
# Iteration 79700, Loss: 1.53e-08
# Iteration 79800, Loss: 1.53e-08
# Iteration 79900, Loss: 1.53e-08
# Iteration 80000, Loss: 1.53e-08
# Iteration 80100, Loss: 1.53e-08
# Iteration 80200, Loss: 1.53e-08
# Iteration 80300, Loss: 1.53e-08
# Iteration 80400, Loss: 1.53e-08
# Iteration 80500, Loss: 1.53e-08
# Iteration 80600, Loss: 1.53e-08
# Iteration 80700, Loss: 1.53e-08
# Iteration 80800, Loss: 1.53e-08
# Iteration 80900, Loss: 1.53e-08
# Iteration 81000, Loss: 1.53e-08
# Iteration 81100, Loss: 1.53e-08
# Iteration 81200, Loss: 1.53e-08
# Iteration 81300, Loss: 1.53e-08
# Iteration 81400, Loss: 1.53e-08
# Iteration 81500, Loss: 1.53e-08
# Iteration 81600, Loss: 1.53e-08
# Iteration 81700, Loss: 1.53e-08
# Iteration 81800, Loss: 1.53e-08
# Iteration 81900, Loss: 1.53e-08
# Iteration 82000, Loss: 1.53e-08
# Iteration 82100, Loss: 1.53e-08
# Iteration 82200, Loss: 1.53e-08
# Iteration 82300, Loss: 1.53e-08
# Iteration 82400, Loss: 1.53e-08
# Iteration 82500, Loss: 1.53e-08
# Iteration 82600, Loss: 1.53e-08
# Iteration 82700, Loss: 1.53e-08
# Iteration 82800, Loss: 1.53e-08
# Iteration 82900, Loss: 1.53e-08
# Iteration 83000, Loss: 1.53e-08
# Iteration 83100, Loss: 1.53e-08
# Iteration 83200, Loss: 1.53e-08
# Iteration 83300, Loss: 1.53e-08
# Iteration 83400, Loss: 1.53e-08
# Iteration 83500, Loss: 1.53e-08
# Iteration 83600, Loss: 1.53e-08
# Iteration 83700, Loss: 1.53e-08
# Iteration 83800, Loss: 1.53e-08
# Iteration 83900, Loss: 1.53e-08
# Iteration 84000, Loss: 1.53e-08
# Iteration 84100, Loss: 1.53e-08
# Iteration 84200, Loss: 1.53e-08
# Iteration 84300, Loss: 1.53e-08
# Iteration 84400, Loss: 1.53e-08
# Iteration 84500, Loss: 1.53e-08
# Iteration 84600, Loss: 1.53e-08
# Iteration 84700, Loss: 1.53e-08
# Iteration 84800, Loss: 1.53e-08
# Iteration 84900, Loss: 1.53e-08
# Iteration 85000, Loss: 1.53e-08
# Iteration 85100, Loss: 1.53e-08
# Iteration 85200, Loss: 1.53e-08
# Iteration 85300, Loss: 1.53e-08
# Iteration 85400, Loss: 1.53e-08
# Iteration 85500, Loss: 1.53e-08
# Iteration 85600, Loss: 1.53e-08
# Iteration 85700, Loss: 1.53e-08
# Iteration 85800, Loss: 1.53e-08
# Iteration 85900, Loss: 1.53e-08
# Iteration 86000, Loss: 1.53e-08
# Iteration 86100, Loss: 1.53e-08
# Iteration 86200, Loss: 1.53e-08
# Iteration 86300, Loss: 1.53e-08
# Iteration 86400, Loss: 1.53e-08
# Iteration 86500, Loss: 1.53e-08
# Iteration 86600, Loss: 1.53e-08
# Iteration 86700, Loss: 1.53e-08
# Iteration 86800, Loss: 1.53e-08
# Iteration 86900, Loss: 1.53e-08
# Iteration 87000, Loss: 1.53e-08
# Iteration 87100, Loss: 1.53e-08
# Iteration 87200, Loss: 1.53e-08
# Iteration 87300, Loss: 1.53e-08
# Iteration 87400, Loss: 1.53e-08
# Iteration 87500, Loss: 1.53e-08
# Iteration 87600, Loss: 1.53e-08
# Iteration 87700, Loss: 1.53e-08
# Iteration 87800, Loss: 1.53e-08
# Iteration 87900, Loss: 1.53e-08
# Iteration 88000, Loss: 1.53e-08
# Iteration 88100, Loss: 1.53e-08
# Iteration 88200, Loss: 1.53e-08
# Iteration 88300, Loss: 1.53e-08
# Iteration 88400, Loss: 1.53e-08
# Iteration 88500, Loss: 1.53e-08
# Iteration 88600, Loss: 1.53e-08
# Iteration 88700, Loss: 1.53e-08
# Iteration 88800, Loss: 1.53e-08
# Iteration 88900, Loss: 1.53e-08
# Iteration 89000, Loss: 1.53e-08
# Iteration 89100, Loss: 1.53e-08
# Iteration 89200, Loss: 1.53e-08
# Iteration 89300, Loss: 1.53e-08
# Iteration 89400, Loss: 1.53e-08
# Iteration 89500, Loss: 1.53e-08
# Iteration 89600, Loss: 1.53e-08
# Iteration 89700, Loss: 1.53e-08
# Iteration 89800, Loss: 1.53e-08
# Iteration 89900, Loss: 1.53e-08
# Iteration 90000, Loss: 1.53e-08
# Iteration 90100, Loss: 1.53e-08
# Iteration 90200, Loss: 1.53e-08
# Iteration 90300, Loss: 1.53e-08
# Iteration 90400, Loss: 1.53e-08
# Iteration 90500, Loss: 1.53e-08
# Iteration 90600, Loss: 1.53e-08
# Iteration 90700, Loss: 1.53e-08
# Iteration 90800, Loss: 1.53e-08
# Iteration 90900, Loss: 1.53e-08
# Iteration 91000, Loss: 1.53e-08
# Iteration 91100, Loss: 1.53e-08
# Iteration 91200, Loss: 1.53e-08
# Iteration 91300, Loss: 1.53e-08
# Iteration 91400, Loss: 1.53e-08
# Iteration 91500, Loss: 1.53e-08
# Iteration 91600, Loss: 1.53e-08
# Iteration 91700, Loss: 1.53e-08
# Iteration 91800, Loss: 1.53e-08
# Iteration 91900, Loss: 1.53e-08
# Iteration 92000, Loss: 1.53e-08
# Iteration 92100, Loss: 1.53e-08
# Iteration 92200, Loss: 1.53e-08
# Iteration 92300, Loss: 1.53e-08
# Iteration 92400, Loss: 1.53e-08
# Iteration 92500, Loss: 1.53e-08
# Iteration 92600, Loss: 1.53e-08
# Iteration 92700, Loss: 1.53e-08
# Iteration 92800, Loss: 1.53e-08
# Iteration 92900, Loss: 1.53e-08
# Iteration 93000, Loss: 1.53e-08
# Iteration 93100, Loss: 1.53e-08
# Iteration 93200, Loss: 1.53e-08
# Iteration 93300, Loss: 1.53e-08
# Iteration 93400, Loss: 1.53e-08
# Iteration 93500, Loss: 1.53e-08
# Iteration 93600, Loss: 1.53e-08
# Iteration 93700, Loss: 1.53e-08
# Iteration 93800, Loss: 1.53e-08
# Iteration 93900, Loss: 1.53e-08
# Iteration 94000, Loss: 1.53e-08
# Iteration 94100, Loss: 1.53e-08
# Iteration 94200, Loss: 1.53e-08
# Iteration 94300, Loss: 1.53e-08
# Iteration 94400, Loss: 1.53e-08
# Iteration 94500, Loss: 1.53e-08
# Iteration 94600, Loss: 1.53e-08
# Iteration 94700, Loss: 1.53e-08
# Iteration 94800, Loss: 1.53e-08
# Iteration 94900, Loss: 1.53e-08
# Iteration 95000, Loss: 1.53e-08
# Iteration 95100, Loss: 1.53e-08
# Iteration 95200, Loss: 1.53e-08
# Iteration 95300, Loss: 1.53e-08
# Iteration 95400, Loss: 1.53e-08
# Iteration 95500, Loss: 1.53e-08
# Iteration 95600, Loss: 1.53e-08
# Iteration 95700, Loss: 1.53e-08
# Iteration 95800, Loss: 1.53e-08
# Iteration 95900, Loss: 1.53e-08
# Iteration 96000, Loss: 1.53e-08
# Iteration 96100, Loss: 1.53e-08
# Iteration 96200, Loss: 1.53e-08
# Iteration 96300, Loss: 1.53e-08
# Iteration 96400, Loss: 1.53e-08
# Iteration 96500, Loss: 1.53e-08
# Iteration 96600, Loss: 1.53e-08
# Iteration 96700, Loss: 1.53e-08
# Iteration 96800, Loss: 1.53e-08
# Iteration 96900, Loss: 1.53e-08
# Iteration 97000, Loss: 1.53e-08
# Iteration 97100, Loss: 1.53e-08
# Iteration 97200, Loss: 1.53e-08
# Iteration 97300, Loss: 1.53e-08
# Iteration 97400, Loss: 1.53e-08
# Iteration 97500, Loss: 1.53e-08
# Iteration 97600, Loss: 1.53e-08
# Iteration 97700, Loss: 1.53e-08
# Iteration 97800, Loss: 1.53e-08
# Iteration 97900, Loss: 1.53e-08
# Iteration 98000, Loss: 1.53e-08
# Iteration 98100, Loss: 1.53e-08
# Iteration 98200, Loss: 1.53e-08
# Iteration 98300, Loss: 1.53e-08
# Iteration 98400, Loss: 1.53e-08
# Iteration 98500, Loss: 1.53e-08
# Iteration 98600, Loss: 1.53e-08
# Iteration 98700, Loss: 1.53e-08
# Iteration 98800, Loss: 1.53e-08
# Iteration 98900, Loss: 1.53e-08
# Iteration 99000, Loss: 1.53e-08
# Iteration 99100, Loss: 1.53e-08
# Iteration 99200, Loss: 1.53e-08
# Iteration 99300, Loss: 1.53e-08
# Iteration 99400, Loss: 1.53e-08
# Iteration 99500, Loss: 1.53e-08
# Iteration 99600, Loss: 1.53e-08
# Iteration 99700, Loss: 1.53e-08
# Iteration 99800, Loss: 1.53e-08
# Iteration 99900, Loss: 1.53e-08
# Iteration 100000, Loss: 1.53e-08
# Iteration 100100, Loss: 1.53e-08
# Iteration 100200, Loss: 1.53e-08
# Iteration 100300, Loss: 1.53e-08
# Iteration 100400, Loss: 1.53e-08
# Iteration 100500, Loss: 1.53e-08
# Iteration 100600, Loss: 1.53e-08
# Iteration 100700, Loss: 1.53e-08
# Iteration 100800, Loss: 1.53e-08
# Iteration 100900, Loss: 1.53e-08
# Iteration 101000, Loss: 1.53e-08
# Iteration 101100, Loss: 1.53e-08
# Iteration 101200, Loss: 1.53e-08
# Iteration 101300, Loss: 1.53e-08
# Iteration 101400, Loss: 1.53e-08
# Iteration 101500, Loss: 1.53e-08
# Iteration 101600, Loss: 1.53e-08
# Iteration 101700, Loss: 1.53e-08
# Iteration 101800, Loss: 1.53e-08
# Iteration 101900, Loss: 1.53e-08
# Iteration 102000, Loss: 1.53e-08
# Iteration 102100, Loss: 1.53e-08
# Iteration 102200, Loss: 1.53e-08
# Iteration 102300, Loss: 1.53e-08
# Iteration 102400, Loss: 1.53e-08
# Iteration 102500, Loss: 1.53e-08
# Iteration 102600, Loss: 1.53e-08
# Iteration 102700, Loss: 1.53e-08
# Iteration 102800, Loss: 1.53e-08
# Iteration 102900, Loss: 1.52e-08
# Iteration 103000, Loss: 1.52e-08
# Iteration 103100, Loss: 1.52e-08
# Iteration 103200, Loss: 1.52e-08
# Iteration 103300, Loss: 1.52e-08
# Iteration 103400, Loss: 1.52e-08
# Iteration 103500, Loss: 1.52e-08
# Iteration 103600, Loss: 1.52e-08
# Iteration 103700, Loss: 1.52e-08
# Iteration 103800, Loss: 1.52e-08
# Iteration 103900, Loss: 1.52e-08
# Iteration 104000, Loss: 1.52e-08
# Iteration 104100, Loss: 1.52e-08
# Iteration 104200, Loss: 1.52e-08
# Iteration 104300, Loss: 1.52e-08
# Iteration 104400, Loss: 1.52e-08
# Iteration 104500, Loss: 1.52e-08
# Iteration 104600, Loss: 1.52e-08
# Iteration 104700, Loss: 1.52e-08
# Iteration 104800, Loss: 1.52e-08
# Iteration 104900, Loss: 1.52e-08
# Iteration 105000, Loss: 1.52e-08
# Iteration 105100, Loss: 1.52e-08
# Iteration 105200, Loss: 1.52e-08
# Iteration 105300, Loss: 1.52e-08
# Iteration 105400, Loss: 1.52e-08
# Iteration 105500, Loss: 1.52e-08
# Iteration 105600, Loss: 1.52e-08
# Iteration 105700, Loss: 1.52e-08
# Iteration 105800, Loss: 1.52e-08
# Iteration 105900, Loss: 1.52e-08
# Iteration 106000, Loss: 1.52e-08
# Iteration 106100, Loss: 1.52e-08
# Iteration 106200, Loss: 1.52e-08
# Iteration 106300, Loss: 1.52e-08
# Iteration 106400, Loss: 1.52e-08
# Iteration 106500, Loss: 1.52e-08
# Iteration 106600, Loss: 1.52e-08
# Iteration 106700, Loss: 1.52e-08
# Iteration 106800, Loss: 1.52e-08
# Iteration 106900, Loss: 1.52e-08
# Iteration 107000, Loss: 1.52e-08
# Iteration 107100, Loss: 1.52e-08
# Iteration 107200, Loss: 1.52e-08
# Iteration 107300, Loss: 1.52e-08
# Iteration 107400, Loss: 1.52e-08
# Iteration 107500, Loss: 1.52e-08
# Iteration 107600, Loss: 1.52e-08
# Iteration 107700, Loss: 1.52e-08
# Iteration 107800, Loss: 1.52e-08
# Iteration 107900, Loss: 1.52e-08
# Iteration 108000, Loss: 1.52e-08
# Iteration 108100, Loss: 1.52e-08
# Iteration 108200, Loss: 1.52e-08
# Iteration 108300, Loss: 1.52e-08
# Iteration 108400, Loss: 1.52e-08
# Iteration 108500, Loss: 1.52e-08
# Iteration 108600, Loss: 1.52e-08
# Iteration 108700, Loss: 1.52e-08
# Iteration 108800, Loss: 1.52e-08
# Iteration 108900, Loss: 1.52e-08
# Iteration 109000, Loss: 1.52e-08
# Iteration 109100, Loss: 1.52e-08
# Iteration 109200, Loss: 1.52e-08
# Iteration 109300, Loss: 1.52e-08
# Iteration 109400, Loss: 1.52e-08
# Iteration 109500, Loss: 1.52e-08
# Iteration 109600, Loss: 1.52e-08
# Iteration 109700, Loss: 1.52e-08
# Iteration 109800, Loss: 1.52e-08
# Iteration 109900, Loss: 1.52e-08
# Iteration 110000, Loss: 1.52e-08
# Iteration 110100, Loss: 1.52e-08
# Iteration 110200, Loss: 1.52e-08
# Iteration 110300, Loss: 1.52e-08
# Iteration 110400, Loss: 1.52e-08
# Iteration 110500, Loss: 1.52e-08
# Iteration 110600, Loss: 1.52e-08
# Iteration 110700, Loss: 1.52e-08
# Iteration 110800, Loss: 1.52e-08
# Iteration 110900, Loss: 1.52e-08
# Iteration 111000, Loss: 1.52e-08
# Iteration 111100, Loss: 1.52e-08
# Iteration 111200, Loss: 1.52e-08
# Iteration 111300, Loss: 1.52e-08
# Iteration 111400, Loss: 1.52e-08
# Iteration 111500, Loss: 1.52e-08
# Iteration 111600, Loss: 1.52e-08
# Iteration 111700, Loss: 1.52e-08
# Iteration 111800, Loss: 1.52e-08
# Iteration 111900, Loss: 1.52e-08
# Iteration 112000, Loss: 1.52e-08
# Iteration 112100, Loss: 1.52e-08
# Iteration 112200, Loss: 1.52e-08
# Iteration 112300, Loss: 1.52e-08
# Iteration 112400, Loss: 1.52e-08
# Iteration 112500, Loss: 1.52e-08
# Iteration 112600, Loss: 1.52e-08
# Iteration 112700, Loss: 1.52e-08
# Iteration 112800, Loss: 1.52e-08
# Iteration 112900, Loss: 1.52e-08
# Iteration 113000, Loss: 1.52e-08
# Iteration 113100, Loss: 1.52e-08
# Iteration 113200, Loss: 1.52e-08
# Iteration 113300, Loss: 1.52e-08
# Iteration 113400, Loss: 1.52e-08
# Iteration 113500, Loss: 1.52e-08
# Iteration 113600, Loss: 1.52e-08
# Iteration 113700, Loss: 1.52e-08
# Iteration 113800, Loss: 1.52e-08
# Iteration 113900, Loss: 1.52e-08
# Iteration 114000, Loss: 1.52e-08
# Iteration 114100, Loss: 1.52e-08
# Iteration 114200, Loss: 1.52e-08
# Iteration 114300, Loss: 1.52e-08
# Iteration 114400, Loss: 1.52e-08
# Iteration 114500, Loss: 1.52e-08
# Iteration 114600, Loss: 1.52e-08
# Iteration 114700, Loss: 1.52e-08
# Iteration 114800, Loss: 1.52e-08
# Iteration 114900, Loss: 1.52e-08
# Iteration 115000, Loss: 1.52e-08
# Iteration 115100, Loss: 1.52e-08
# Iteration 115200, Loss: 1.52e-08
# Iteration 115300, Loss: 1.52e-08
# Iteration 115400, Loss: 1.52e-08
# Iteration 115500, Loss: 1.52e-08
# Iteration 115600, Loss: 1.52e-08
# Iteration 115700, Loss: 1.52e-08
# Iteration 115800, Loss: 1.52e-08
# Iteration 115900, Loss: 1.52e-08
# Iteration 116000, Loss: 1.52e-08
# Iteration 116100, Loss: 1.52e-08
# Iteration 116200, Loss: 1.52e-08
# Iteration 116300, Loss: 1.52e-08
# Iteration 116400, Loss: 1.52e-08
# Iteration 116500, Loss: 1.52e-08
# Iteration 116600, Loss: 1.52e-08
# Iteration 116700, Loss: 1.52e-08
# Iteration 116800, Loss: 1.52e-08
# Iteration 116900, Loss: 1.52e-08
# Iteration 117000, Loss: 1.52e-08
# Iteration 117100, Loss: 1.52e-08
# Iteration 117200, Loss: 1.52e-08
# Iteration 117300, Loss: 1.52e-08
# Iteration 117400, Loss: 1.52e-08
# Iteration 117500, Loss: 1.52e-08
# Iteration 117600, Loss: 1.52e-08
# Iteration 117700, Loss: 1.52e-08
# Iteration 117800, Loss: 1.52e-08
# Iteration 117900, Loss: 1.52e-08
# Iteration 118000, Loss: 1.52e-08
# Iteration 118100, Loss: 1.52e-08
# Iteration 118200, Loss: 1.52e-08
# Iteration 118300, Loss: 1.52e-08
# Iteration 118400, Loss: 1.52e-08
# Iteration 118500, Loss: 1.52e-08
# Iteration 118600, Loss: 1.52e-08
# Iteration 118700, Loss: 1.52e-08
# Iteration 118800, Loss: 1.52e-08
# Iteration 118900, Loss: 1.52e-08
# Iteration 119000, Loss: 1.52e-08
# Iteration 119100, Loss: 1.52e-08
# Iteration 119200, Loss: 1.52e-08
# Iteration 119300, Loss: 1.52e-08
# Iteration 119400, Loss: 1.52e-08
# Iteration 119500, Loss: 1.52e-08
# Iteration 119600, Loss: 1.52e-08
# Iteration 119700, Loss: 1.52e-08
# Iteration 119800, Loss: 1.52e-08
# Iteration 119900, Loss: 1.52e-08
# Iteration 120000, Loss: 1.52e-08
# Iteration 120100, Loss: 1.52e-08
# Iteration 120200, Loss: 1.52e-08
# Iteration 120300, Loss: 1.52e-08
# Iteration 120400, Loss: 1.52e-08
# Iteration 120500, Loss: 1.52e-08
# Iteration 120600, Loss: 1.52e-08
# Iteration 120700, Loss: 1.52e-08
# Iteration 120800, Loss: 1.52e-08
# Iteration 120900, Loss: 1.52e-08
# Iteration 121000, Loss: 1.52e-08
# Iteration 121100, Loss: 1.52e-08
# Iteration 121200, Loss: 1.52e-08
# Iteration 121300, Loss: 1.52e-08
# Iteration 121400, Loss: 1.52e-08
# Iteration 121500, Loss: 1.52e-08
# Iteration 121600, Loss: 1.52e-08
# Iteration 121700, Loss: 1.52e-08
# Iteration 121800, Loss: 1.52e-08
# Iteration 121900, Loss: 1.52e-08
# Iteration 122000, Loss: 1.52e-08
# Iteration 122100, Loss: 1.52e-08
# Iteration 122200, Loss: 1.52e-08
# Iteration 122300, Loss: 1.52e-08
# Iteration 122400, Loss: 1.52e-08
# Iteration 122500, Loss: 1.52e-08
# Iteration 122600, Loss: 1.52e-08
# Iteration 122700, Loss: 1.52e-08
# Iteration 122800, Loss: 1.52e-08
# Iteration 122900, Loss: 1.52e-08
# Iteration 123000, Loss: 1.52e-08
# Iteration 123100, Loss: 1.52e-08
# Iteration 123200, Loss: 1.52e-08
# Iteration 123300, Loss: 1.52e-08
# Iteration 123400, Loss: 1.52e-08
# Iteration 123500, Loss: 1.52e-08
# Iteration 123600, Loss: 1.52e-08
# Iteration 123700, Loss: 1.52e-08
# Iteration 123800, Loss: 1.52e-08
# Iteration 123900, Loss: 1.52e-08
# Iteration 124000, Loss: 1.52e-08
# Iteration 124100, Loss: 1.52e-08
# Iteration 124200, Loss: 1.52e-08
# Iteration 124300, Loss: 1.52e-08
# Iteration 124400, Loss: 1.52e-08
# Iteration 124500, Loss: 1.52e-08
# Iteration 124600, Loss: 1.52e-08
# Iteration 124700, Loss: 1.52e-08
# Iteration 124800, Loss: 1.52e-08
# Iteration 124900, Loss: 1.52e-08
# Iteration 125000, Loss: 1.52e-08
# Iteration 125100, Loss: 1.52e-08
# Iteration 125200, Loss: 1.52e-08
# Iteration 125300, Loss: 1.52e-08
# Iteration 125400, Loss: 1.52e-08
# Iteration 125500, Loss: 1.52e-08
# Iteration 125600, Loss: 1.52e-08
# Iteration 125700, Loss: 1.52e-08
# Iteration 125800, Loss: 1.52e-08
# Iteration 125900, Loss: 1.52e-08
# Iteration 126000, Loss: 1.52e-08
# Iteration 126100, Loss: 1.52e-08
# Iteration 126200, Loss: 1.52e-08
# Iteration 126300, Loss: 1.52e-08
# Iteration 126400, Loss: 1.52e-08
# Iteration 126500, Loss: 1.52e-08
# Iteration 126600, Loss: 1.52e-08
# Iteration 126700, Loss: 1.52e-08
# Iteration 126800, Loss: 1.52e-08
# Iteration 126900, Loss: 1.52e-08
# Iteration 127000, Loss: 1.52e-08
# Iteration 127100, Loss: 1.52e-08
# Iteration 127200, Loss: 1.52e-08
# Iteration 127300, Loss: 1.52e-08
# Iteration 127400, Loss: 1.52e-08
# Iteration 127500, Loss: 1.52e-08
# Iteration 127600, Loss: 1.52e-08
# Iteration 127700, Loss: 1.52e-08
# Iteration 127800, Loss: 1.52e-08
# Iteration 127900, Loss: 1.52e-08
# Iteration 128000, Loss: 1.52e-08
# Iteration 128100, Loss: 1.52e-08
# Iteration 128200, Loss: 1.52e-08
# Iteration 128300, Loss: 1.52e-08
# Iteration 128400, Loss: 1.52e-08
# Iteration 128500, Loss: 1.52e-08
# Iteration 128600, Loss: 1.52e-08
# Iteration 128700, Loss: 1.52e-08
# Iteration 128800, Loss: 1.52e-08
# Iteration 128900, Loss: 1.52e-08
# Iteration 129000, Loss: 1.52e-08
# Iteration 129100, Loss: 1.52e-08
# Iteration 129200, Loss: 1.52e-08
# Iteration 129300, Loss: 1.52e-08
# Iteration 129400, Loss: 1.52e-08
# Iteration 129500, Loss: 1.52e-08
# Iteration 129600, Loss: 1.52e-08
# Iteration 129700, Loss: 1.52e-08
# Iteration 129800, Loss: 1.52e-08
# Iteration 129900, Loss: 1.52e-08
# Iteration 130000, Loss: 1.52e-08
# Iteration 130100, Loss: 1.52e-08
# Iteration 130200, Loss: 1.52e-08
# Iteration 130300, Loss: 1.52e-08
# Iteration 130400, Loss: 1.52e-08
# Iteration 130500, Loss: 1.52e-08
# Iteration 130600, Loss: 1.52e-08
# Iteration 130700, Loss: 1.52e-08
# Iteration 130800, Loss: 1.52e-08
# Iteration 130900, Loss: 1.52e-08
# Iteration 131000, Loss: 1.51e-08
# Iteration 131100, Loss: 1.51e-08
# Iteration 131200, Loss: 1.51e-08
# Iteration 131300, Loss: 1.51e-08
# Iteration 131400, Loss: 1.51e-08
# Iteration 131500, Loss: 1.51e-08
# Iteration 131600, Loss: 1.51e-08
# Iteration 131700, Loss: 1.51e-08
# Iteration 131800, Loss: 1.51e-08
# Iteration 131900, Loss: 1.51e-08
# Iteration 132000, Loss: 1.51e-08
# Iteration 132100, Loss: 1.51e-08
# Iteration 132200, Loss: 1.51e-08
# Iteration 132300, Loss: 1.51e-08
# Iteration 132400, Loss: 1.51e-08
# Iteration 132500, Loss: 1.51e-08
# Iteration 132600, Loss: 1.51e-08
# Iteration 132700, Loss: 1.51e-08
# Iteration 132800, Loss: 1.51e-08
# Iteration 132900, Loss: 1.51e-08
# Iteration 133000, Loss: 1.51e-08
# Iteration 133100, Loss: 1.51e-08
# Iteration 133200, Loss: 1.51e-08
# Iteration 133300, Loss: 1.51e-08
# Iteration 133400, Loss: 1.51e-08
# Iteration 133500, Loss: 1.51e-08
# Iteration 133600, Loss: 1.51e-08
# Iteration 133700, Loss: 1.51e-08
# Iteration 133800, Loss: 1.51e-08
# Iteration 133900, Loss: 1.51e-08
# Iteration 134000, Loss: 1.51e-08
# Iteration 134100, Loss: 1.51e-08
# Iteration 134200, Loss: 1.51e-08
# Iteration 134300, Loss: 1.51e-08
# Iteration 134400, Loss: 1.51e-08
# Iteration 134500, Loss: 1.51e-08
# Iteration 134600, Loss: 1.51e-08
# Iteration 134700, Loss: 1.51e-08
# Iteration 134800, Loss: 1.51e-08
# Iteration 134900, Loss: 1.51e-08
# Iteration 135000, Loss: 1.51e-08
# Iteration 135100, Loss: 1.51e-08
# Iteration 135200, Loss: 1.51e-08
# Iteration 135300, Loss: 1.51e-08
# Iteration 135400, Loss: 1.51e-08
# Iteration 135500, Loss: 1.51e-08
# Iteration 135600, Loss: 1.51e-08
# Iteration 135700, Loss: 1.51e-08
# Iteration 135800, Loss: 1.51e-08
# Iteration 135900, Loss: 1.51e-08
# Iteration 136000, Loss: 1.51e-08
# Iteration 136100, Loss: 1.51e-08
# Iteration 136200, Loss: 1.51e-08
# Iteration 136300, Loss: 1.51e-08
# Iteration 136400, Loss: 1.51e-08
# Iteration 136500, Loss: 1.51e-08
# Iteration 136600, Loss: 1.51e-08
# Iteration 136700, Loss: 1.51e-08
# Iteration 136800, Loss: 1.51e-08
# Iteration 136900, Loss: 1.51e-08
# Iteration 137000, Loss: 1.51e-08
# Iteration 137100, Loss: 1.51e-08
# Iteration 137200, Loss: 1.51e-08
# Iteration 137300, Loss: 1.51e-08
# Iteration 137400, Loss: 1.51e-08
# Iteration 137500, Loss: 1.51e-08
# Iteration 137600, Loss: 1.51e-08
# Iteration 137700, Loss: 1.51e-08
# Iteration 137800, Loss: 1.51e-08
# Iteration 137900, Loss: 1.51e-08
# Iteration 138000, Loss: 1.51e-08
# Iteration 138100, Loss: 1.51e-08
# Iteration 138200, Loss: 1.51e-08
# Iteration 138300, Loss: 1.51e-08
# Iteration 138400, Loss: 1.51e-08
# Iteration 138500, Loss: 1.51e-08
# Iteration 138600, Loss: 1.51e-08
# Iteration 138700, Loss: 1.51e-08
# Iteration 138800, Loss: 1.51e-08
# Iteration 138900, Loss: 1.51e-08
# Iteration 139000, Loss: 1.51e-08
# Iteration 139100, Loss: 1.51e-08
# Iteration 139200, Loss: 1.51e-08
# Iteration 139300, Loss: 1.51e-08
# Iteration 139400, Loss: 1.51e-08
# Iteration 139500, Loss: 1.51e-08
# Iteration 139600, Loss: 1.51e-08
# Iteration 139700, Loss: 1.51e-08
# Iteration 139800, Loss: 1.51e-08
# Iteration 139900, Loss: 1.51e-08
# Iteration 140000, Loss: 1.51e-08
# Iteration 140100, Loss: 1.51e-08
# Iteration 140200, Loss: 1.51e-08
# Iteration 140300, Loss: 1.51e-08
# Iteration 140400, Loss: 1.51e-08
# Iteration 140500, Loss: 1.51e-08
# Iteration 140600, Loss: 1.51e-08
# Iteration 140700, Loss: 1.51e-08
# Iteration 140800, Loss: 1.51e-08
# Iteration 140900, Loss: 1.51e-08
# Iteration 141000, Loss: 1.51e-08
# Iteration 141100, Loss: 1.51e-08
# Iteration 141200, Loss: 1.51e-08
# Iteration 141300, Loss: 1.51e-08
# Iteration 141400, Loss: 1.51e-08
# Iteration 141500, Loss: 1.51e-08
# Iteration 141600, Loss: 1.51e-08
# Iteration 141700, Loss: 1.51e-08
# Iteration 141800, Loss: 1.51e-08
# Iteration 141900, Loss: 1.51e-08
# Iteration 142000, Loss: 1.51e-08
# Iteration 142100, Loss: 1.51e-08
# Iteration 142200, Loss: 1.51e-08
# Iteration 142300, Loss: 1.51e-08
# Iteration 142400, Loss: 1.51e-08
# Iteration 142500, Loss: 1.51e-08
# Iteration 142600, Loss: 1.51e-08
# Iteration 142700, Loss: 1.51e-08
# Iteration 142800, Loss: 1.51e-08
# Iteration 142900, Loss: 1.51e-08
# Iteration 143000, Loss: 1.51e-08
# Iteration 143100, Loss: 1.51e-08
# Iteration 143200, Loss: 1.51e-08
# Iteration 143300, Loss: 1.51e-08
# Iteration 143400, Loss: 1.51e-08
# Iteration 143500, Loss: 1.51e-08
# Iteration 143600, Loss: 1.51e-08
# Iteration 143700, Loss: 1.51e-08
# Iteration 143800, Loss: 1.51e-08
# Iteration 143900, Loss: 1.51e-08
# Iteration 144000, Loss: 1.51e-08
# Iteration 144100, Loss: 1.51e-08
# Iteration 144200, Loss: 1.51e-08
# Iteration 144300, Loss: 1.51e-08
# Iteration 144400, Loss: 1.51e-08
# Iteration 144500, Loss: 1.51e-08
# Iteration 144600, Loss: 1.51e-08
# Iteration 144700, Loss: 1.51e-08
# Iteration 144800, Loss: 1.51e-08
# Iteration 144900, Loss: 1.51e-08
# Iteration 145000, Loss: 1.51e-08
# Iteration 145100, Loss: 1.51e-08
# Iteration 145200, Loss: 1.51e-08
# Iteration 145300, Loss: 1.51e-08
# Iteration 145400, Loss: 1.51e-08
# Iteration 145500, Loss: 1.51e-08
# Iteration 145600, Loss: 1.51e-08
# Iteration 145700, Loss: 1.51e-08
# Iteration 145800, Loss: 1.51e-08
# Iteration 145900, Loss: 1.51e-08
# Iteration 146000, Loss: 1.51e-08
# Iteration 146100, Loss: 1.51e-08
# Iteration 146200, Loss: 1.51e-08
# Iteration 146300, Loss: 1.51e-08
# Iteration 146400, Loss: 1.51e-08
# Iteration 146500, Loss: 1.51e-08
# Iteration 146600, Loss: 1.51e-08
# Iteration 146700, Loss: 1.51e-08
# Iteration 146800, Loss: 1.51e-08
# Iteration 146900, Loss: 1.51e-08
# Iteration 147000, Loss: 1.51e-08
# Iteration 147100, Loss: 1.51e-08
# Iteration 147200, Loss: 1.51e-08
# Iteration 147300, Loss: 1.51e-08
# Iteration 147400, Loss: 1.51e-08
# Iteration 147500, Loss: 1.51e-08
# Iteration 147600, Loss: 1.51e-08
# Iteration 147700, Loss: 1.51e-08
# Iteration 147800, Loss: 1.51e-08
# Iteration 147900, Loss: 1.51e-08
# Iteration 148000, Loss: 1.51e-08
# Iteration 148100, Loss: 1.51e-08
# Iteration 148200, Loss: 1.51e-08
# Iteration 148300, Loss: 1.51e-08
# Iteration 148400, Loss: 1.51e-08
# Iteration 148500, Loss: 1.51e-08
# Iteration 148600, Loss: 1.51e-08
# Iteration 148700, Loss: 1.51e-08
# ...
# Iteration 951700, Loss: 1.34e-08
# Iteration 951800, Loss: 1.34e-08
# Iteration 951900, Loss: 1.34e-08
# Iteration 952000, Loss: 1.34e-08
# Iteration 952100, Loss: 1.34e-08
# Iteration 952200, Loss: 1.34e-08
# Iteration 952300, Loss: 1.34e-08
# Iteration 952400, Loss: 1.34e-08
# Iteration 952500, Loss: 1.34e-08
# Iteration 952600, Loss: 1.34e-08
# Iteration 952700, Loss: 1.34e-08
# Iteration 952800, Loss: 1.34e-08
# Iteration 952900, Loss: 1.34e-08
# Iteration 953000, Loss: 1.34e-08
# Iteration 953100, Loss: 1.34e-08
# Iteration 953200, Loss: 1.34e-08
# Iteration 953300, Loss: 1.34e-08
# Iteration 953400, Loss: 1.34e-08
# Iteration 953500, Loss: 1.34e-08
# Iteration 953600, Loss: 1.34e-08
# Iteration 953700, Loss: 1.34e-08
# Iteration 953800, Loss: 1.34e-08
# Iteration 953900, Loss: 1.34e-08
# Iteration 954000, Loss: 1.34e-08
# Iteration 954100, Loss: 1.34e-08
# Iteration 954200, Loss: 1.34e-08
# Iteration 954300, Loss: 1.34e-08
# Iteration 954400, Loss: 1.34e-08
# Iteration 954500, Loss: 1.34e-08
# Iteration 954600, Loss: 1.34e-08
# Iteration 954700, Loss: 1.34e-08
# Iteration 954800, Loss: 1.34e-08
# Iteration 954900, Loss: 1.34e-08
# Iteration 955000, Loss: 1.34e-08
# Iteration 955100, Loss: 1.34e-08
# Iteration 955200, Loss: 1.34e-08
# Iteration 955300, Loss: 1.34e-08
# Iteration 955400, Loss: 1.34e-08
# Iteration 955500, Loss: 1.34e-08
# Iteration 955600, Loss: 1.34e-08
# Iteration 955700, Loss: 1.34e-08
# Iteration 955800, Loss: 1.34e-08
# Iteration 955900, Loss: 1.34e-08
# Iteration 956000, Loss: 1.34e-08
# Iteration 956100, Loss: 1.34e-08
# Iteration 956200, Loss: 1.34e-08
# Iteration 956300, Loss: 1.34e-08
# Iteration 956400, Loss: 1.34e-08
# Iteration 956500, Loss: 1.34e-08
# Iteration 956600, Loss: 1.34e-08
# Iteration 956700, Loss: 1.34e-08
# Iteration 956800, Loss: 1.34e-08
# Iteration 956900, Loss: 1.34e-08
# Iteration 957000, Loss: 1.34e-08
# Iteration 957100, Loss: 1.34e-08
# Iteration 957200, Loss: 1.34e-08
# Iteration 957300, Loss: 1.34e-08
# Iteration 957400, Loss: 1.34e-08
# Iteration 957500, Loss: 1.34e-08
# Iteration 957600, Loss: 1.34e-08
# Iteration 957700, Loss: 1.34e-08
# Iteration 957800, Loss: 1.34e-08
# Iteration 957900, Loss: 1.34e-08
# Iteration 958000, Loss: 1.34e-08
# Iteration 958100, Loss: 1.34e-08
# Iteration 958200, Loss: 1.34e-08
# Iteration 958300, Loss: 1.34e-08
# Iteration 958400, Loss: 1.34e-08
# Iteration 958500, Loss: 1.34e-08
# Iteration 958600, Loss: 1.34e-08
# Iteration 958700, Loss: 1.34e-08
# Iteration 958800, Loss: 1.34e-08
# Iteration 958900, Loss: 1.34e-08
# Iteration 959000, Loss: 1.34e-08
# Iteration 959100, Loss: 1.34e-08
# Iteration 959200, Loss: 1.34e-08
# Iteration 959300, Loss: 1.34e-08
# Iteration 959400, Loss: 1.34e-08
# Iteration 959500, Loss: 1.34e-08
# Iteration 959600, Loss: 1.34e-08
# Iteration 959700, Loss: 1.34e-08
# Iteration 959800, Loss: 1.34e-08
# Iteration 959900, Loss: 1.34e-08
# Iteration 960000, Loss: 1.34e-08
# Iteration 960100, Loss: 1.34e-08
# Iteration 960200, Loss: 1.34e-08
# Iteration 960300, Loss: 1.34e-08
# Iteration 960400, Loss: 1.34e-08
# Iteration 960500, Loss: 1.34e-08
# Iteration 960600, Loss: 1.34e-08
# Iteration 960700, Loss: 1.34e-08
# Iteration 960800, Loss: 1.34e-08
# Iteration 960900, Loss: 1.34e-08
# Iteration 961000, Loss: 1.34e-08
# Iteration 961100, Loss: 1.34e-08
# Iteration 961200, Loss: 1.34e-08
# Iteration 961300, Loss: 1.34e-08
# Iteration 961400, Loss: 1.34e-08
# Iteration 961500, Loss: 1.34e-08
# Iteration 961600, Loss: 1.34e-08
# Iteration 961700, Loss: 1.34e-08
# Iteration 961800, Loss: 1.34e-08
# Iteration 961900, Loss: 1.34e-08
# Iteration 962000, Loss: 1.34e-08
# Iteration 962100, Loss: 1.34e-08
# Iteration 962200, Loss: 1.34e-08
# Iteration 962300, Loss: 1.34e-08
# Iteration 962400, Loss: 1.34e-08
# Iteration 962500, Loss: 1.34e-08
# Iteration 962600, Loss: 1.34e-08
# Iteration 962700, Loss: 1.34e-08
# Iteration 962800, Loss: 1.34e-08
# Iteration 962900, Loss: 1.34e-08
# Iteration 963000, Loss: 1.34e-08
# Iteration 963100, Loss: 1.34e-08
# Iteration 963200, Loss: 1.34e-08
# Iteration 963300, Loss: 1.34e-08
# Iteration 963400, Loss: 1.34e-08
# Iteration 963500, Loss: 1.34e-08
# Iteration 963600, Loss: 1.34e-08
# Iteration 963700, Loss: 1.34e-08
# Iteration 963800, Loss: 1.34e-08
# Iteration 963900, Loss: 1.34e-08
# Iteration 964000, Loss: 1.34e-08
# Iteration 964100, Loss: 1.34e-08
# Iteration 964200, Loss: 1.34e-08
# Iteration 964300, Loss: 1.34e-08
# Iteration 964400, Loss: 1.34e-08
# Iteration 964500, Loss: 1.34e-08
# Iteration 964600, Loss: 1.34e-08
# Iteration 964700, Loss: 1.34e-08
# Iteration 964800, Loss: 1.34e-08
# Iteration 964900, Loss: 1.34e-08
# Iteration 965000, Loss: 1.34e-08
# Iteration 965100, Loss: 1.34e-08
# Iteration 965200, Loss: 1.34e-08
# Iteration 965300, Loss: 1.34e-08
# Iteration 965400, Loss: 1.34e-08
# Iteration 965500, Loss: 1.34e-08
# Iteration 965600, Loss: 1.34e-08
# Iteration 965700, Loss: 1.34e-08
# Iteration 965800, Loss: 1.34e-08
# Iteration 965900, Loss: 1.34e-08
# Iteration 966000, Loss: 1.34e-08
# Iteration 966100, Loss: 1.34e-08
# Iteration 966200, Loss: 1.34e-08
# Iteration 966300, Loss: 1.34e-08
# Iteration 966400, Loss: 1.34e-08
# Iteration 966500, Loss: 1.34e-08
# Iteration 966600, Loss: 1.34e-08
# Iteration 966700, Loss: 1.34e-08
# Iteration 966800, Loss: 1.34e-08
# Iteration 966900, Loss: 1.34e-08
# Iteration 967000, Loss: 1.34e-08
# Iteration 967100, Loss: 1.34e-08
# Iteration 967200, Loss: 1.34e-08
# Iteration 967300, Loss: 1.34e-08
# Iteration 967400, Loss: 1.34e-08
# Iteration 967500, Loss: 1.34e-08
# Iteration 967600, Loss: 1.34e-08
# Iteration 967700, Loss: 1.34e-08
# Iteration 967800, Loss: 1.34e-08
# Iteration 967900, Loss: 1.34e-08
# Iteration 968000, Loss: 1.34e-08
# Iteration 968100, Loss: 1.34e-08
# Iteration 968200, Loss: 1.34e-08
# Iteration 968300, Loss: 1.34e-08
# Iteration 968400, Loss: 1.34e-08
# Iteration 968500, Loss: 1.34e-08
# Iteration 968600, Loss: 1.34e-08
# Iteration 968700, Loss: 1.34e-08
# Iteration 968800, Loss: 1.34e-08
# Iteration 968900, Loss: 1.34e-08
# Iteration 969000, Loss: 1.34e-08
# Iteration 969100, Loss: 1.34e-08
# Iteration 969200, Loss: 1.34e-08
# Iteration 969300, Loss: 1.34e-08
# Iteration 969400, Loss: 1.34e-08
# Iteration 969500, Loss: 1.34e-08
# Iteration 969600, Loss: 1.34e-08
# Iteration 969700, Loss: 1.34e-08
# Iteration 969800, Loss: 1.34e-08
# Iteration 969900, Loss: 1.34e-08
# Iteration 970000, Loss: 1.34e-08
# Iteration 970100, Loss: 1.34e-08
# Iteration 970200, Loss: 1.34e-08
# Iteration 970300, Loss: 1.34e-08
# Iteration 970400, Loss: 1.34e-08
# Iteration 970500, Loss: 1.34e-08
# Iteration 970600, Loss: 1.34e-08
# Iteration 970700, Loss: 1.34e-08
# Iteration 970800, Loss: 1.34e-08
# Iteration 970900, Loss: 1.34e-08
# Iteration 971000, Loss: 1.34e-08
# Iteration 971100, Loss: 1.34e-08
# Iteration 971200, Loss: 1.34e-08
# Iteration 971300, Loss: 1.34e-08
# Iteration 971400, Loss: 1.34e-08
# Iteration 971500, Loss: 1.34e-08
# Iteration 971600, Loss: 1.34e-08
# Iteration 971700, Loss: 1.34e-08
# Iteration 971800, Loss: 1.34e-08
# Iteration 971900, Loss: 1.34e-08
# Iteration 972000, Loss: 1.34e-08
# Iteration 972100, Loss: 1.34e-08
# Iteration 972200, Loss: 1.34e-08
# Iteration 972300, Loss: 1.34e-08
# Iteration 972400, Loss: 1.34e-08
# Iteration 972500, Loss: 1.34e-08
# Iteration 972600, Loss: 1.34e-08
# Iteration 972700, Loss: 1.34e-08
# Iteration 972800, Loss: 1.34e-08
# Iteration 972900, Loss: 1.34e-08
# Iteration 973000, Loss: 1.34e-08
# Iteration 973100, Loss: 1.34e-08
# Iteration 973200, Loss: 1.34e-08
# Iteration 973300, Loss: 1.34e-08
# Iteration 973400, Loss: 1.34e-08
# Iteration 973500, Loss: 1.34e-08
# Iteration 973600, Loss: 1.34e-08
# Iteration 973700, Loss: 1.34e-08
# Iteration 973800, Loss: 1.34e-08
# Iteration 973900, Loss: 1.34e-08
# Iteration 974000, Loss: 1.34e-08
# Iteration 974100, Loss: 1.34e-08
# Iteration 974200, Loss: 1.34e-08
# Iteration 974300, Loss: 1.34e-08
# Iteration 974400, Loss: 1.34e-08
# Iteration 974500, Loss: 1.34e-08
# Iteration 974600, Loss: 1.34e-08
# Iteration 974700, Loss: 1.34e-08
# Iteration 974800, Loss: 1.34e-08
# Iteration 974900, Loss: 1.34e-08
# Iteration 975000, Loss: 1.34e-08
# Iteration 975100, Loss: 1.34e-08
# Iteration 975200, Loss: 1.34e-08
# Iteration 975300, Loss: 1.34e-08
# Iteration 975400, Loss: 1.34e-08
# Iteration 975500, Loss: 1.34e-08
# Iteration 975600, Loss: 1.34e-08
# Iteration 975700, Loss: 1.34e-08
# Iteration 975800, Loss: 1.34e-08
# Iteration 975900, Loss: 1.34e-08
# Iteration 976000, Loss: 1.34e-08
# Iteration 976100, Loss: 1.34e-08
# Iteration 976200, Loss: 1.34e-08
# Iteration 976300, Loss: 1.34e-08
# Iteration 976400, Loss: 1.34e-08
# Iteration 976500, Loss: 1.34e-08
# Iteration 976600, Loss: 1.34e-08
# Iteration 976700, Loss: 1.34e-08
# Iteration 976800, Loss: 1.34e-08
# Iteration 976900, Loss: 1.34e-08
# Iteration 977000, Loss: 1.34e-08
# Iteration 977100, Loss: 1.34e-08
# Iteration 977200, Loss: 1.34e-08
# Iteration 977300, Loss: 1.34e-08
# Iteration 977400, Loss: 1.34e-08
# Iteration 977500, Loss: 1.34e-08
# Iteration 977600, Loss: 1.34e-08
# Iteration 977700, Loss: 1.34e-08
# Iteration 977800, Loss: 1.34e-08
# Iteration 977900, Loss: 1.34e-08
# Iteration 978000, Loss: 1.34e-08
# Iteration 978100, Loss: 1.34e-08
# Iteration 978200, Loss: 1.34e-08
# Iteration 978300, Loss: 1.34e-08
# Iteration 978400, Loss: 1.34e-08
# Iteration 978500, Loss: 1.34e-08
# Iteration 978600, Loss: 1.34e-08
# Iteration 978700, Loss: 1.34e-08
# Iteration 978800, Loss: 1.34e-08
# Iteration 978900, Loss: 1.34e-08
# Iteration 979000, Loss: 1.34e-08
# Iteration 979100, Loss: 1.34e-08
# Iteration 979200, Loss: 1.34e-08
# Iteration 979300, Loss: 1.34e-08
# Iteration 979400, Loss: 1.34e-08
# Iteration 979500, Loss: 1.34e-08
# Iteration 979600, Loss: 1.34e-08
# Iteration 979700, Loss: 1.34e-08
# Iteration 979800, Loss: 1.34e-08
# Iteration 979900, Loss: 1.34e-08
# Iteration 980000, Loss: 1.34e-08
# Iteration 980100, Loss: 1.34e-08
# Iteration 980200, Loss: 1.34e-08
# Iteration 980300, Loss: 1.34e-08
# Iteration 980400, Loss: 1.34e-08
# Iteration 980500, Loss: 1.34e-08
# Iteration 980600, Loss: 1.34e-08
# Iteration 980700, Loss: 1.34e-08
# Iteration 980800, Loss: 1.34e-08
# Iteration 980900, Loss: 1.34e-08
# Iteration 981000, Loss: 1.34e-08
# Iteration 981100, Loss: 1.34e-08
# Iteration 981200, Loss: 1.34e-08
# Iteration 981300, Loss: 1.34e-08
# Iteration 981400, Loss: 1.34e-08
# Iteration 981500, Loss: 1.34e-08
# Iteration 981600, Loss: 1.34e-08
# Iteration 981700, Loss: 1.34e-08
# Iteration 981800, Loss: 1.34e-08
# Iteration 981900, Loss: 1.34e-08
# Iteration 982000, Loss: 1.34e-08
# Iteration 982100, Loss: 1.34e-08
# Iteration 982200, Loss: 1.34e-08
# Iteration 982300, Loss: 1.34e-08
# Iteration 982400, Loss: 1.34e-08
# Iteration 982500, Loss: 1.34e-08
# Iteration 982600, Loss: 1.34e-08
# Iteration 982700, Loss: 1.34e-08
# Iteration 982800, Loss: 1.34e-08
# Iteration 982900, Loss: 1.34e-08
# Iteration 983000, Loss: 1.34e-08
# Iteration 983100, Loss: 1.34e-08
# Iteration 983200, Loss: 1.34e-08
# Iteration 983300, Loss: 1.34e-08
# Iteration 983400, Loss: 1.34e-08
# Iteration 983500, Loss: 1.34e-08
# Iteration 983600, Loss: 1.34e-08
# Iteration 983700, Loss: 1.34e-08
# Iteration 983800, Loss: 1.34e-08
# Iteration 983900, Loss: 1.34e-08
# Iteration 984000, Loss: 1.34e-08
# Iteration 984100, Loss: 1.34e-08
# Iteration 984200, Loss: 1.34e-08
# Iteration 984300, Loss: 1.34e-08
# Iteration 984400, Loss: 1.34e-08
# Iteration 984500, Loss: 1.34e-08
# Iteration 984600, Loss: 1.34e-08
# Iteration 984700, Loss: 1.34e-08
# Iteration 984800, Loss: 1.34e-08
# Iteration 984900, Loss: 1.34e-08
# Iteration 985000, Loss: 1.34e-08
# Iteration 985100, Loss: 1.34e-08
# Iteration 985200, Loss: 1.34e-08
# Iteration 985300, Loss: 1.34e-08
# Iteration 985400, Loss: 1.34e-08
# Iteration 985500, Loss: 1.34e-08
# Iteration 985600, Loss: 1.34e-08
# Iteration 985700, Loss: 1.34e-08
# Iteration 985800, Loss: 1.34e-08
# Iteration 985900, Loss: 1.34e-08
# Iteration 986000, Loss: 1.34e-08
# Iteration 986100, Loss: 1.34e-08
# Iteration 986200, Loss: 1.34e-08
# Iteration 986300, Loss: 1.34e-08
# Iteration 986400, Loss: 1.34e-08
# Iteration 986500, Loss: 1.34e-08
# Iteration 986600, Loss: 1.34e-08
# Iteration 986700, Loss: 1.34e-08
# Iteration 986800, Loss: 1.34e-08
# Iteration 986900, Loss: 1.34e-08
# Iteration 987000, Loss: 1.34e-08
# Iteration 987100, Loss: 1.34e-08
# Iteration 987200, Loss: 1.34e-08
# Iteration 987300, Loss: 1.34e-08
# Iteration 987400, Loss: 1.34e-08
# Iteration 987500, Loss: 1.34e-08
# Iteration 987600, Loss: 1.34e-08
# Iteration 987700, Loss: 1.34e-08
# Iteration 987800, Loss: 1.34e-08
# Iteration 987900, Loss: 1.34e-08
# Iteration 988000, Loss: 1.34e-08
# Iteration 988100, Loss: 1.34e-08
# Iteration 988200, Loss: 1.34e-08
# Iteration 988300, Loss: 1.34e-08
# Iteration 988400, Loss: 1.34e-08
# Iteration 988500, Loss: 1.34e-08
# Iteration 988600, Loss: 1.34e-08
# Iteration 988700, Loss: 1.34e-08
# Iteration 988800, Loss: 1.34e-08
# Iteration 988900, Loss: 1.34e-08
# Iteration 989000, Loss: 1.34e-08
# Iteration 989100, Loss: 1.34e-08
# Iteration 989200, Loss: 1.34e-08
# Iteration 989300, Loss: 1.34e-08
# Iteration 989400, Loss: 1.34e-08
# Iteration 989500, Loss: 1.34e-08
# Iteration 989600, Loss: 1.34e-08
# Iteration 989700, Loss: 1.34e-08
# Iteration 989800, Loss: 1.34e-08
# Iteration 989900, Loss: 1.34e-08
# Iteration 990000, Loss: 1.34e-08
# Iteration 990100, Loss: 1.34e-08
# Iteration 990200, Loss: 1.34e-08
# Iteration 990300, Loss: 1.34e-08
# Iteration 990400, Loss: 1.34e-08
# Iteration 990500, Loss: 1.34e-08
# Iteration 990600, Loss: 1.34e-08
# Iteration 990700, Loss: 1.34e-08
# Iteration 990800, Loss: 1.34e-08
# Iteration 990900, Loss: 1.34e-08
# Iteration 991000, Loss: 1.34e-08
# Iteration 991100, Loss: 1.34e-08
# Iteration 991200, Loss: 1.34e-08
# Iteration 991300, Loss: 1.34e-08
# Iteration 991400, Loss: 1.34e-08
# Iteration 991500, Loss: 1.34e-08
# Iteration 991600, Loss: 1.34e-08
# Iteration 991700, Loss: 1.34e-08
# Iteration 991800, Loss: 1.34e-08
# Iteration 991900, Loss: 1.34e-08
# Iteration 992000, Loss: 1.34e-08
# Iteration 992100, Loss: 1.34e-08
# Iteration 992200, Loss: 1.34e-08
# Iteration 992300, Loss: 1.34e-08
# Iteration 992400, Loss: 1.34e-08
# Iteration 992500, Loss: 1.34e-08
# Iteration 992600, Loss: 1.34e-08
# Iteration 992700, Loss: 1.34e-08
# Iteration 992800, Loss: 1.34e-08
# Iteration 992900, Loss: 1.34e-08
# Iteration 993000, Loss: 1.34e-08
# Iteration 993100, Loss: 1.33e-08
# Iteration 993200, Loss: 1.33e-08
# Iteration 993300, Loss: 1.33e-08
# Iteration 993400, Loss: 1.33e-08
# Iteration 993500, Loss: 1.33e-08
# Iteration 993600, Loss: 1.33e-08
# Iteration 993700, Loss: 1.33e-08
# Iteration 993800, Loss: 1.34e-08
# Iteration 993900, Loss: 1.33e-08
# Iteration 994000, Loss: 1.33e-08
# Iteration 994100, Loss: 1.33e-08
# Iteration 994200, Loss: 1.33e-08
# Iteration 994300, Loss: 1.33e-08
# Iteration 994400, Loss: 1.33e-08
# Iteration 994500, Loss: 1.33e-08
# Iteration 994600, Loss: 1.33e-08
# Iteration 994700, Loss: 1.33e-08
# Iteration 994800, Loss: 1.33e-08
# Iteration 994900, Loss: 1.33e-08
# Iteration 995000, Loss: 1.33e-08
# Iteration 995100, Loss: 1.33e-08
# Iteration 995200, Loss: 1.33e-08
# Iteration 995300, Loss: 1.33e-08
# Iteration 995400, Loss: 1.33e-08
# Iteration 995500, Loss: 1.33e-08
# Iteration 995600, Loss: 1.33e-08
# Iteration 995700, Loss: 1.33e-08
# Iteration 995800, Loss: 1.33e-08
# Iteration 995900, Loss: 1.33e-08
# Iteration 996000, Loss: 1.33e-08
# Iteration 996100, Loss: 1.33e-08
# Iteration 996200, Loss: 1.33e-08
# Iteration 996300, Loss: 1.33e-08
# Iteration 996400, Loss: 1.33e-08
# Iteration 996500, Loss: 1.33e-08
# Iteration 996600, Loss: 1.33e-08
# Iteration 996700, Loss: 1.33e-08
# Iteration 996800, Loss: 1.33e-08
# Iteration 996900, Loss: 1.33e-08
# Iteration 997000, Loss: 1.33e-08
# Iteration 997100, Loss: 1.33e-08
# Iteration 997200, Loss: 1.33e-08
# Iteration 997300, Loss: 1.33e-08
# Iteration 997400, Loss: 1.33e-08
# Iteration 997500, Loss: 1.33e-08
# Iteration 997600, Loss: 1.33e-08
# Iteration 997700, Loss: 1.33e-08
# Iteration 997800, Loss: 1.33e-08
# Iteration 997900, Loss: 1.33e-08
# Iteration 998000, Loss: 1.33e-08
# Iteration 998100, Loss: 1.33e-08
# Iteration 998200, Loss: 1.33e-08
# Iteration 998300, Loss: 1.33e-08
# Iteration 998400, Loss: 1.33e-08
# Iteration 998500, Loss: 1.33e-08
# Iteration 998600, Loss: 1.33e-08
# Iteration 998700, Loss: 1.33e-08
# Iteration 998800, Loss: 1.33e-08
# Iteration 998900, Loss: 1.33e-08
# Iteration 999000, Loss: 1.33e-08
# Iteration 999100, Loss: 1.33e-08
# Iteration 999200, Loss: 1.33e-08
# Iteration 999300, Loss: 1.33e-08
# Iteration 999400, Loss: 1.33e-08
# Iteration 999500, Loss: 1.33e-08
# Iteration 999600, Loss: 1.33e-08
# Iteration 999700, Loss: 1.33e-08
# Iteration 999800, Loss: 1.33e-08
# Iteration 999900, Loss: 1.33e-08
# MSE between original and approximated phi: 1.04e-06

# %%
# Convert back to numpy for plotting
phi_n_approx = torch.matmul(lds_impulses_tensor, combined_weights_pinv).detach()

# Compare original vs approximated phi_n
plt.figure(figsize=(10, 6))
plt.plot(phi_n_combined[:1000,0], label='Original phi')
plt.plot(phi_n_approx[:1000,0], '--', label='Approximated phi')
plt.title('Comparing Original vs Approximated Basis Functions')
plt.legend()
plt.show()

# Calculate MSE between original and approximated phi
mse = F.mse_loss(phi_n_combined_tensor, phi_n_approx)
print(f"MSE between original and approximated phi: {mse:.2e}")
# Out:
# MSE between original and approximated phi: 1.04e-06
