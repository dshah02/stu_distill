# %%
#in this notebook, I also attempt to find how each STU filter can be represented as a linear combination of LDSs
#however, to do this we will fit many STUs to LDSs and then use the learned weights to represent the STU as a linear combination of LDSs

# %%
import sys
import os
sys.path.append(os.path.abspath("../../src"))

# %%
import torch
import torch.nn as nn
import torch.nn.functional  as  F
import math
import numpy as np

device = torch.device("cuda"  if torch.cuda.is_available() else "cpu")

# %%
def nearest_power_of_two(x: int, round_up: bool = False) -> int:
    return (
        1 << math.floor(math.log2(x)) if not round_up else 1 << math.ceil(math.log2(x))
    )

def convolve(u: torch.Tensor, v: torch.Tensor, n: int, use_approx: bool = True) -> tuple[torch.Tensor, torch.Tensor]:
    # print(u.shape, v.shape)
    bsz, seq_len, d_in = u.shape

    sgn = torch.full((1, seq_len, 1), 1, device=u.device)
    sgn[:, 1::2] *= -1

    _, K = v.shape
    sgn = sgn.unsqueeze(-1)
    v = v.view(1, -1, K, 1, 1).to(torch.float32) # (bsz, seq_len, K, d_in, stack)
    u = u.view(bsz, -1, 1, d_in).expand(bsz, -1, K, d_in)

    v = torch.fft.rfft(v, n=n, dim=1)
    U = torch.stack([u, u * sgn], dim=-1).to(torch.float32)
    U = torch.fft.rfft(U, n=n, dim=1)
    U_conv = torch.fft.irfft(v * U, n=n, dim=1)[:, :seq_len]
    U_plus, U_minus = torch.unbind(U_conv, dim=-1)
    U_minus = U_minus * sgn

    return U_plus, U_minus

# %%
def get_hankel(seq_len: int, use_hankel_L: bool = False) -> np.ndarray:
    entries = np.arange(1, seq_len + 1, dtype=np.float64)
    i_plus_j = entries[:, None] + entries[None, :]

    if use_hankel_L:
        sgn = (-1.0) ** (i_plus_j - 2.0) + 1.0
        denom = (i_plus_j + 3.0) * (i_plus_j - 1.0) * (i_plus_j + 1.0)
        Z = sgn * (8.0 / denom)
    elif not use_hankel_L:
        Z = 2.0 / (i_plus_j**3 - i_plus_j)
    else:
        raise ValueError("use_hankel_L must be a boolean")

    return Z

def get_spectral_filters(
    seq_len: int,
    K: int,
    use_hankel_L: bool = False,
    device: torch.device = None,
    dtype: torch.dtype = torch.bfloat16,
) -> torch.Tensor:
    # assert torch.cuda.is_available(), "CUDA is required."
    Z = get_hankel(seq_len, use_hankel_L)
    sigma, phi = np.linalg.eigh(Z)
    sigma_k, phi_k = sigma[-K:], phi[:, -K:]
    phi_k *= sigma_k ** 0.25
    filters = torch.from_numpy(phi_k)
    return filters.to(device=device, dtype=dtype)

# %%
from lds_utils import compute_ar_x_preds

# %%
class STU(nn.Module):
    def __init__(self, config, phi) -> None:
        super(STU, self).__init__()
        self.config = config
        self.phi = phi
        self.n = nearest_power_of_two(config['seq_len'] * 2 - 1, round_up=True)
        self.K = config['num_eigh']
        self.d_in = config['d_in']
        self.d_out = config['d_out']
        self.use_hankel_L = config['use_hankel_L']
        self.use_approx = False
        self.k_u = config['k_u']

        self.M = nn.Parameter(torch.randn(self.d_out, self.d_in, self.k_u, dtype=config['torch_dtype']) / self.d_in)
        
        self.M_phi_plus = nn.Parameter(
            torch.randn(self.K, self.d_in, self.d_out, dtype=config['torch_dtype']) / 10
        )

        self.M_phi_minus = nn.Parameter(
            torch.randn(self.K, self.d_in, self.d_out, dtype=config['torch_dtype']) / 10
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:

        # Convolve inputs and filters,
        U_plus, U_minus = convolve(x, self.phi, self.n, False)
        # Then, contract over the K and d_in dimensions

        # print(U_plus.shape, U_minus.shape)
        spectral_plus = torch.tensordot(
            U_plus, self.M_phi_plus, dims=([2, 3], [0, 1])
        )

        spectral_minus = torch.tensordot(
            U_minus, self.M_phi_minus, dims=([2, 3], [0, 1])
        )
            
        output = spectral_plus if self.use_hankel_L else spectral_plus + spectral_minus
        ar = compute_ar_x_preds(self.M, x)
        return output + ar
        
    def loss(self, inputs, targets):
        pred = self.forward(inputs)
        # print(pred, targets)
        loss = F.mse_loss(pred, targets)
        return  loss

# %%
class LDS:
  def __init__(self, A: torch.tensor, B: torch.tensor, C: torch.tensor, D: torch.tensor, h0: torch.tensor):
    self.d_h = A.shape
    _, self.d_u = B.shape
    self.d_o, _ = C.shape
    self.A = A  # hidden state dynamics
    self.B = B  # hidden state dynamics
    self.C = C  # observation projection
    self.D = D  # observation projection
    self.h0 = h0  # initial hidden state
    self.h = h0  # current hidden state
    self.dtype = float

  def step(self, u: torch.tensor) -> torch.tensor:
    assert u.shape == (self.d_u,)
    h_next = self.A * self.h + self.B @ u
    obs = self.C @ h_next + self.D @ u
    self.h = h_next
    assert obs.shape == (self.d_o,)
    return obs

  def reset(self):
    self.h = self.h0
    return self

  def generate_trajectory(self, us: torch.tensor, h0: torch.tensor = None) -> torch.tensor:
    if h0 is not None:
      self.h = h0
    _, d_u = us.shape
    assert d_u == self.d_u, (d_u, self.d_u)
    obs = []
    for u in us:
      obs.append(self.step(u))
    return torch.stack(obs, dim=0)
  
  def impulse(self, seq_len = 1024):
      # Initialize output tensor
      outputs = torch.zeros(seq_len)
      
      # For each position
      for i in range(seq_len):
          # Compute A^i
          a_power = self.A ** i
          
          # Multiply C[:,0] * A^i * B[i]
          outputs[i] = torch.sum(self.C[:,0] * a_power * self.B[0])
          
      return outputs

def random_LDS(d_h: int, d_o: int, d_u: int, lower_bound: float):
  """
  makes a random LDS with hidden state dimension d_h, observation dimension d_o, and control dimension d_u.
  `lower_bound` is a float in [0, 1] specifying the minimum absolute value for entries in A.
  Each entry in A will be in [lower_bound, 1] multiplied by +/-1 with equal probability.
  """
  # Generate random values in [lower_bound, 1]
  A = torch.rand(d_h) * (1 - lower_bound) + lower_bound
  signs = torch.randint(0, 2, (d_h,)) * 2 - 1
  A = A * signs.float()
  
  B = torch.randn(d_h, d_u).to(device)
  C = torch.randn(d_o, d_h).to(device)
  D = torch.zeros(d_o, d_u).to(device)
  h0 = torch.zeros(d_h).to(device)
  return LDS(A.to(device), B, C, D, h0)

# %%
d_h = 1
d_in = 1
d_out =1
lds  =  random_LDS(d_h = d_h, d_o =  d_out, d_u = d_in, lower_bound= 0.9)
print(lds.A)
# Out:
# tensor([-0.9134])

# %%
seq_len = 1024
num_eigh = 20
use_hankel_L  = True
phi= get_spectral_filters(seq_len = seq_len, K = num_eigh,  use_hankel_L= use_hankel_L,
                                device  = device,  dtype = torch.float32)

stu_config = {
    "num_eigh": num_eigh,
    "use_hankel_L": True,
    "torch_dtype": torch.float32,
    "d_in": 1,
    "d_out": 1,
    "seq_len": seq_len,
    "k_u": 3
}

# %%
def train_stu(lds, verbose = True):
    model = STU(stu_config, phi).to(device)
    lr = 1
    optimizer = torch.optim.Adagrad(model.parameters(), lr=lr)

    steps = 1_000 # @param
    model.train()

    bsz = 1

    for step in range(steps):
        inputs = torch.randn(bsz * seq_len, d_in).to(device)
        targets = lds.reset().generate_trajectory(inputs)

        inputs = inputs.reshape(bsz, seq_len, d_in).to(device)
        targets = targets.reshape(bsz, seq_len, d_out).to(device)
        loss = model.loss(inputs, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % 100 == 0 and verbose:
            print(f"Step {step}: Loss = {loss.item()}")

    model.eval()
    return model, loss

stu_model, _ = train_stu(lds)
# Out:
# Step 0: Loss = 7.942370891571045
# Step 100: Loss = 3.640833767803997e-07
# Step 200: Loss = 3.3587485859243316e-07
# Step 300: Loss = 3.35522088334983e-07
# Step 400: Loss = 3.793316807332303e-07
# Step 500: Loss = 3.93648235785804e-07
# Step 600: Loss = 3.291255268322857e-07
# Step 700: Loss = 3.490918629722728e-07
# Step 800: Loss = 3.7831472354810103e-07
# Step 900: Loss = 3.329909645799489e-07

# %%
import matplotlib.pyplot as plt

# Generate random input and get trajectories
test_input = torch.randn(seq_len, d_in).to(device)
test_input = test_input.unsqueeze(0) # Add batch dimension

# Get STU trajectory
with torch.no_grad():
    stu_trajectory = stu_model(test_input).squeeze()

# Get LDS trajectory 
lds_trajectory = lds.reset().generate_trajectory(test_input.squeeze(0)).to(device)

gap = stu_trajectory - lds_trajectory[:, 0]
# Plot both trajectories
plt.figure(figsize=(10, 6))
plt.plot(stu_trajectory.cpu().numpy(), label='STU Model')
plt.plot(lds_trajectory.cpu().numpy(), label='LDS Model', linestyle='--')
plt.plot(gap.cpu().numpy(), label='Gap')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title('Comparison of STU and LDS Trajectories')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Get the STU filters and weights
filters = phi.T  # Shape: [num_filters, seq_len]
pos_weights = stu_model.M_phi_plus[:,0,0] # Shape: [1, num_filters]
neg_weights = stu_model.M_phi_minus[:,0,0] # Shape: [1, num_filters]
# Multiply each filter by its weight and sum
pos_weighted_filters = (filters.T @ pos_weights.T).squeeze()  # Shape: [seq_len]
neg_weighted_filters = (filters.T @ neg_weights.T).squeeze()  # Shape: [seq_len]

weighted_filters = pos_weighted_filters + neg_weighted_filters

# For LDS, compute the impulse response
lds_impulse = torch.zeros(seq_len)
for i in range(seq_len):
    a_power = lds.A ** i
    lds_impulse[i] = torch.sum(lds.C[:,0] * a_power * lds.B[0])

# Plot both
plt.figure(figsize=(10, 6))
plt.plot(weighted_filters.detach().cpu().numpy(), label='STU Combined Filters')
plt.plot(lds_impulse.cpu().numpy(), label='LDS Impulse Response', linestyle='--')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.title('Comparison of STU Filters and LDS Impulse Response')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import tqdm

ldss = []
pos_weights_matrix = []
neg_weights_matrix = []
autoreg_weights_matrix = []
losses = []
store = []

# %%
for i in tqdm.tqdm(range(100)):
 
    new_lds = random_LDS(d_h = d_h, d_o = d_out, d_u = d_in, lower_bound= 0.8)  # Replace LDS with the actual class constructor if different
    
    # Fit STU to the LDS
    stu, loss = train_stu(new_lds, verbose = False)
    
    # Extract positive and negative weights
    pos_weights = stu.M_phi_plus[:, 0, 0].detach().cpu().numpy()  # Shape: [num_filters]
    neg_weights = stu.M_phi_minus[:, 0, 0].detach().cpu().numpy()  # Shape: [num_filters]
    auto_reg = stu.M.detach().cpu().numpy()
    autoreg_weights_matrix.append(auto_reg)
    
    pos_weights_matrix.append(pos_weights)
    neg_weights_matrix.append(neg_weights)
    losses.append(loss)
    store.append([new_lds, stu])

    ldss.append(new_lds)
# Out:
# 100%|██████████| 100/100 [11:57:08<00:00, 430.28s/it]

# %%
# Load the saved store data
import pickle
import glob

# Get the most recent store file
store_files = glob.glob('stu_lds_store_20250221*.pkl')
latest_store = max(store_files)

# Load the data
with open(latest_store, 'rb') as f:
    store_data = pickle.load(f)

# Reconstruct LDS and STU objects from the saved parameters
store = []
for lds_params, stu_params in store_data:
    # Create LDS with loaded parameters
    
    A = torch.tensor(lds_params['A'])
    B = torch.tensor(lds_params['B']) 
    C = torch.tensor(lds_params['C'])
    # D = torch.tensor(lds_params['D'])
    h0 = torch.tensor(lds_params['h0'])

    lds = LDS(A,B,C,D,h0)    

    # Create STU with loaded parameters
    stu = STU(stu_config, phi)
    stu.M_phi_plus.data = torch.tensor(stu_params['M_phi_plus'])
    stu.M_phi_minus.data= torch.tensor(stu_params['M_phi_minus'])
    stu.M.data = torch.tensor(stu_params['M'])

    store.append((lds, stu))

print(f"Loaded store data from {latest_store}")
# Out:
# Loaded store data from stu_lds_store_20250221_213044.pkl

# %%
def gen_lds_impulse(lds,autoreg): #need the stu for to add the negative autoregressive component
    lds_impulse = torch.zeros(seq_len)
    for i in range(stu_config["k_u"]):
        lds_impulse[i] = -1 * torch.tensor(autoreg[0][0][i])
    for i in range(seq_len):
        a_power = lds.A ** i
        lds_impulse[i] += torch.sum(lds.C[:, 0] * a_power * lds.B[0]).cpu()
    return lds_impulse

phi_n = phi.data.cpu().numpy()

def gen_stu_impulse(stu):
    alt_sign = lambda x: x * np.array([1, -1] * (seq_len//2))
    pos_coef = stu.M_phi_plus.data.cpu().numpy()[:, 0,0]
    neg_coef = stu.M_phi_minus.data.cpu().numpy()[:,0,0]
    impulse = np.sum(phi_n*pos_coef, axis = -1) + alt_sign(np.sum(phi_n*neg_coef, axis = -1))
    return impulse

# %%
# Get impulse responses for both LDS and STU models and store with MSE losses
pairs_with_mse = []

for lds, stu in store:
    lds_impulse = gen_lds_impulse(lds, stu.M.detach().cpu().numpy())
    stu_impulse = gen_stu_impulse(stu)
    
    # Calculate MSE between impulse responses
    mse = F.mse_loss(torch.tensor(lds_impulse)[10:], torch.tensor(stu_impulse)[10:])
    
    # Store pair with its MSE
    pairs_with_mse.append((mse, lds, stu))

# Sort by MSE and take top 40
pairs_with_mse.sort(key=lambda x: x[0])
filtered_store = [(lds, stu) for _, lds, stu in pairs_with_mse[:200]]
# Out:
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/54032057.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mse = F.mse_loss(torch.tensor(lds_impulse)[10:], torch.tensor(stu_impulse)[10:])

# %%
# Create alternating sign pattern of length 1024
alternating_signs = np.array([1, -1] * (seq_len//2))

# Multiply phi_n by alternating signs to get alternated version
phi_n_alternating = phi_n * alternating_signs[:, np.newaxis]
# Concatenate original and alternating versions along second axis
phi_n_combined = np.concatenate([phi_n, phi_n_alternating], axis=1)  # Shape: (1024, 40)

# %%
# For each STU, combine M_phi_plus and M_phi_minus
combined_weights = []
for _, stu in filtered_store:
    # Get M_phi_plus and M_phi_minus from STU model
    M_phi_plus = stu.M_phi_plus.detach().cpu().numpy()[:,0,0]
    M_phi_minus = stu.M_phi_minus.detach().cpu().numpy()[:,0,0]
    
    # Concatenate the weights
    combined = np.concatenate([M_phi_plus, M_phi_minus], axis=0)
    combined_weights.append(combined)

# Stack all combined weights into a single array
combined_weights = np.stack(combined_weights)
combined_weights.shape
# Out:
# (200, 40)

# %%
# Reconstruct STU filters using combined weights and phi_n_combined
reconstructed_filters = np.matmul(phi_n_combined, combined_weights.T)  # Shape: (1024, num_models)

# Get original STU impulse responses for comparison
original_impulses = []
for _, stu in filtered_store:
    impulse = gen_stu_impulse(stu)
    original_impulses.append(impulse)
original_impulses = np.stack(original_impulses).T  # Shape: (1024, num_models)

# Compare reconstructed vs original
# Calculate MSE between each pair of reconstructed and original impulses
mses = []
for i in range(reconstructed_filters.shape[1]):
    mse = F.mse_loss(torch.tensor(reconstructed_filters[:,i]), torch.tensor(original_impulses[:,i]))
    mses.append(mse.item())

max_mse = max(mses)
max_idx = mses.index(max_mse)
print(f"Maximum MSE between any reconstructed and original impulse pair: {max_mse:.2e} (at index {max_idx})")

plt.figure(figsize=(10, 6))
plt.plot(reconstructed_filters[:100,0], label='Reconstructed')
plt.plot(original_impulses[:100,0], '--', label='Original') 
plt.title('Comparing Original vs Reconstructed STU Impulse Response')
plt.legend()
plt.show()
# Out:
# Maximum MSE between any reconstructed and original impulse pair: 3.12e-16 (at index 79)

# %%
# Use pseudoinverse to solve for phi_n_combined
# reconstructed_filters = phi_n_combined @ combined_weights.T
# Therefore: phi_n_combined = reconstructed_filters @ pinv(combined_weights.T)
combined_weights_pinv = np.linalg.pinv(combined_weights.T)
phi_n_approx = np.matmul(torch.tensor(original_impulses), combined_weights_pinv)

# Compare original vs approximated phi_n
plt.figure(figsize=(10, 6))
plt.plot(phi_n_combined[:100,0], label='Original phi')
plt.plot(phi_n_approx[:100,0], '--', label='Approximated phi')
plt.title('Comparing Original vs Approximated Basis Functions')
plt.legend()
plt.show()

# Calculate MSE between original and approximated phi
mse = F.mse_loss(torch.tensor(phi_n_combined), torch.tensor(phi_n_approx))
print(f"MSE between original and approximated phi: {mse:.2e}")
# Out:
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/1789712089.py:5: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   phi_n_approx = np.matmul(torch.tensor(original_impulses), combined_weights_pinv)
# MSE between original and approximated phi: 3.90e-14
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/1789712089.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mse = F.mse_loss(torch.tensor(phi_n_combined), torch.tensor(phi_n_approx))

# %%
# Generate impulse responses for LDS models
lds_impulses = []
for lds, stu in filtered_store:
    impulse = gen_lds_impulse(lds, stu.M.detach().cpu().numpy())
    lds_impulses.append(impulse)
lds_impulses = np.stack(lds_impulses).T  # Shape: (seq_len, num_models)

# %%
# simulating adding 10 autoregressive terms
lds_impulses[:10, :] = original_impulses[:10, :]

# %%
# Compare original STU impulses with LDS impulses
plt.figure(figsize=(10, 6))
plt.plot(original_impulses[:100,31], label='STU Impulse')
plt.plot(lds_impulses[:100,31], '--', label='LDS Impulse')
plt.title('Comparing STU vs LDS Impulse Responses')
plt.legend()
plt.show()

# Calculate MSE between STU and LDS impulses
for i in range(40):
    mse = F.mse_loss(torch.tensor(lds_impulses[:, i]), torch.tensor(original_impulses[:, i]))
    print(f"MSE between STU and LDS impulse {i}: {mse:.2e}")
# Out:
# MSE between STU and LDS impulse 0: 2.41e-07
# MSE between STU and LDS impulse 1: 3.30e-07
# MSE between STU and LDS impulse 2: 3.34e-07
# MSE between STU and LDS impulse 3: 3.59e-07
# MSE between STU and LDS impulse 4: 4.02e-07
# MSE between STU and LDS impulse 5: 4.02e-07
# MSE between STU and LDS impulse 6: 4.16e-07
# MSE between STU and LDS impulse 7: 4.27e-07
# MSE between STU and LDS impulse 8: 4.27e-07
# MSE between STU and LDS impulse 9: 4.29e-07
# MSE between STU and LDS impulse 10: 4.52e-07
# MSE between STU and LDS impulse 11: 5.03e-07
# MSE between STU and LDS impulse 12: 5.04e-07
# MSE between STU and LDS impulse 13: 5.09e-07
# MSE between STU and LDS impulse 14: 5.40e-07
# MSE between STU and LDS impulse 15: 5.41e-07
# MSE between STU and LDS impulse 16: 5.49e-07
# MSE between STU and LDS impulse 17: 5.59e-07
# MSE between STU and LDS impulse 18: 5.91e-07
# MSE between STU and LDS impulse 19: 6.01e-07
# MSE between STU and LDS impulse 20: 6.07e-07
# MSE between STU and LDS impulse 21: 6.08e-07
# MSE between STU and LDS impulse 22: 6.16e-07
# MSE between STU and LDS impulse 23: 6.27e-07
# MSE between STU and LDS impulse 24: 6.30e-07
# MSE between STU and LDS impulse 25: 6.36e-07
# MSE between STU and LDS impulse 26: 6.66e-07
# MSE between STU and LDS impulse 27: 6.71e-07
# MSE between STU and LDS impulse 28: 6.73e-07
# MSE between STU and LDS impulse 29: 6.85e-07
# MSE between STU and LDS impulse 30: 6.87e-07
# MSE between STU and LDS impulse 31: 6.89e-07
# MSE between STU and LDS impulse 32: 6.97e-07
# MSE between STU and LDS impulse 33: 6.97e-07
# MSE between STU and LDS impulse 34: 7.00e-07
# MSE between STU and LDS impulse 35: 7.02e-07
# MSE between STU and LDS impulse 36: 7.11e-07
# MSE between STU and LDS impulse 37: 7.13e-07
# MSE between STU and LDS impulse 38: 7.26e-07
# MSE between STU and LDS impulse 39: 7.27e-07

# %%
combined_weights_pinv
# Out:
# array([[-0.10291825, -0.47473985, -0.03692134, ..., -0.00610533,
#         -0.00633237, -0.01014481],
#        [-0.09574682,  0.0095944 ,  0.28872222, ...,  0.03913923,
#         -0.01116522,  0.06707414],
#        [ 0.12692484, -0.18615276,  0.04137774, ..., -0.0983032 ,
#         -0.04910852, -0.10121937],
#        ...,
#        [-0.09755644, -0.38175115,  0.45138425, ..., -0.06497262,
#         -0.01256189, -0.02363953],
#        [-0.0996928 ,  0.07396061,  0.25098136, ...,  0.01230924,
#          0.00822431,  0.0212073 ],
#        [ 0.02100625,  0.2806677 , -0.12713566, ..., -0.05006972,
#         -0.04759369,  0.05760705]], shape=(200, 40), dtype=float32)

# %%
combined_weights_pinv = np.linalg.pinv(combined_weights.T)
phi_n_approx = np.matmul(torch.tensor(lds_impulses), combined_weights_pinv)

# Compare original vs approximated phi_n
plt.figure(figsize=(10, 6))
plt.plot(phi_n_combined[:100,0], label='Original phi')
plt.plot(phi_n_approx[:100,0], '--', label='Approximated phi')
plt.title('Comparing Original vs Approximated Basis Functions')
plt.legend()
plt.show()

# Calculate MSE between original and approximated phi
mse = F.mse_loss(torch.tensor(phi_n_combined), torch.tensor(phi_n_approx))
print(f"MSE between original and approximated phi: {mse:.2e}")
# Out:
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/2629277523.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   phi_n_approx = np.matmul(torch.tensor(lds_impulses), combined_weights_pinv)
# MSE between original and approximated phi: 2.26e-05
# /var/folders/42/5cczn_jx4454n6fvhcg5qbjw0000gn/T/ipykernel_33858/2629277523.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mse = F.mse_loss(torch.tensor(phi_n_combined), torch.tensor(phi_n_approx))

# %%
combined_weights_pinv = np.linalg.pinv(combined_weights.T)
combined_weights_pinv = torch.tensor(combined_weights_pinv, requires_grad=True).to(torch.float)
lds_impulses_tensor = torch.tensor(lds_impulses)
phi_n_combined_tensor = torch.tensor(phi_n_combined).to(torch.float)

# Gradient descent to refine the weights
optimizer = torch.optim.Adam([combined_weights_pinv], lr=1e-5)

for i in range(5000000):
    optimizer.zero_grad()
    
    # Forward pass
    phi_n_approx = torch.matmul(lds_impulses_tensor, combined_weights_pinv)
    
    # Calculate loss focusing on first column
    loss = F.mse_loss(phi_n_approx[:,0], phi_n_combined_tensor[:,0])
    
    # Backward pass
    loss.backward()
    optimizer.step()
    
    if i % 5000 == 0:
        print(f"Iteration {i}, Loss: {loss.item():.2e}")

# Convert back to numpy for plotting
phi_n_approx = torch.matmul(lds_impulses_tensor, combined_weights_pinv).detach()

# Compare original vs approximated phi_n
plt.figure(figsize=(10, 6))
plt.plot(phi_n_combined[:100,0], label='Original phi')
plt.plot(phi_n_approx[:100,0], '--', label='Approximated phi')
plt.title('Comparing Original vs Approximated Basis Functions')
plt.legend()
plt.show()

# Calculate MSE between original and approximated phi
mse = F.mse_loss(phi_n_combined_tensor, phi_n_approx)
print(f"MSE between original and approximated phi: {mse:.2e}")
# Out:
# Iteration 0, Loss: 2.11e-06
# Iteration 5000, Loss: 1.38e-06
# Iteration 10000, Loss: 1.03e-06
# Iteration 15000, Loss: 8.42e-07
# Iteration 20000, Loss: 7.25e-07
# Iteration 25000, Loss: 6.37e-07
# Iteration 30000, Loss: 5.64e-07
# Iteration 35000, Loss: 5.00e-07
# Iteration 40000, Loss: 4.45e-07
# Iteration 45000, Loss: 3.98e-07
# Iteration 50000, Loss: 3.57e-07
# Iteration 55000, Loss: 3.23e-07
# Iteration 60000, Loss: 2.94e-07
# Iteration 65000, Loss: 2.70e-07
# Iteration 70000, Loss: 2.51e-07
# Iteration 75000, Loss: 2.36e-07
# Iteration 80000, Loss: 2.23e-07
# Iteration 85000, Loss: 2.14e-07
# Iteration 90000, Loss: 2.06e-07
# Iteration 95000, Loss: 1.99e-07
# Iteration 100000, Loss: 1.93e-07
# Iteration 105000, Loss: 1.88e-07
# Iteration 110000, Loss: 1.84e-07
# Iteration 115000, Loss: 1.80e-07
# Iteration 120000, Loss: 1.76e-07
# Iteration 125000, Loss: 1.72e-07
# Iteration 130000, Loss: 1.69e-07
# Iteration 135000, Loss: 1.65e-07
# Iteration 140000, Loss: 1.62e-07
# Iteration 145000, Loss: 1.59e-07
# Iteration 150000, Loss: 1.57e-07
# Iteration 155000, Loss: 1.54e-07
# Iteration 160000, Loss: 1.51e-07
# Iteration 165000, Loss: 1.49e-07
# Iteration 170000, Loss: 1.47e-07
# Iteration 175000, Loss: 1.44e-07
# Iteration 180000, Loss: 1.42e-07
# Iteration 185000, Loss: 1.40e-07
# Iteration 190000, Loss: 1.38e-07
# Iteration 195000, Loss: 1.36e-07
# Iteration 200000, Loss: 1.34e-07
# Iteration 205000, Loss: 1.32e-07
# Iteration 210000, Loss: 1.31e-07
# Iteration 215000, Loss: 1.29e-07
# Iteration 220000, Loss: 1.27e-07
# Iteration 225000, Loss: 1.26e-07
# Iteration 230000, Loss: 1.24e-07
# Iteration 235000, Loss: 1.22e-07
# Iteration 240000, Loss: 1.21e-07
# Iteration 245000, Loss: 1.19e-07
# Iteration 250000, Loss: 1.18e-07
# Iteration 255000, Loss: 1.17e-07
# Iteration 260000, Loss: 1.15e-07
# Iteration 265000, Loss: 1.14e-07
# Iteration 270000, Loss: 1.13e-07
# Iteration 275000, Loss: 1.11e-07
# Iteration 280000, Loss: 1.10e-07
# Iteration 285000, Loss: 1.09e-07
# Iteration 290000, Loss: 1.08e-07
# Iteration 295000, Loss: 1.07e-07
# Iteration 300000, Loss: 1.06e-07
# Iteration 305000, Loss: 1.04e-07
# Iteration 310000, Loss: 1.03e-07
# Iteration 315000, Loss: 1.02e-07
# Iteration 320000, Loss: 1.01e-07
# Iteration 325000, Loss: 1.00e-07
# Iteration 330000, Loss: 9.93e-08
# Iteration 335000, Loss: 9.83e-08
# Iteration 340000, Loss: 9.74e-08
# Iteration 345000, Loss: 9.65e-08
# Iteration 350000, Loss: 9.56e-08
# Iteration 355000, Loss: 9.47e-08
# Iteration 360000, Loss: 9.38e-08
# Iteration 365000, Loss: 9.30e-08
# Iteration 370000, Loss: 9.22e-08
# Iteration 375000, Loss: 9.14e-08
# Iteration 380000, Loss: 9.06e-08
# Iteration 385000, Loss: 8.98e-08
# Iteration 390000, Loss: 8.91e-08
# Iteration 395000, Loss: 8.83e-08
# Iteration 400000, Loss: 8.76e-08
# Iteration 405000, Loss: 8.69e-08
# Iteration 410000, Loss: 8.62e-08
# Iteration 415000, Loss: 8.55e-08
# Iteration 420000, Loss: 8.48e-08
# Iteration 425000, Loss: 8.42e-08
# Iteration 430000, Loss: 8.36e-08
# Iteration 435000, Loss: 8.29e-08
# Iteration 440000, Loss: 8.23e-08
# Iteration 445000, Loss: 8.17e-08
# Iteration 450000, Loss: 8.11e-08
# Iteration 455000, Loss: 8.05e-08
# Iteration 460000, Loss: 8.00e-08
# Iteration 465000, Loss: 7.94e-08
# Iteration 470000, Loss: 7.89e-08
# Iteration 475000, Loss: 7.83e-08
# Iteration 480000, Loss: 7.78e-08
# Iteration 485000, Loss: 7.73e-08
# Iteration 490000, Loss: 7.68e-08
# Iteration 495000, Loss: 7.63e-08
# Iteration 500000, Loss: 7.59e-08
# Iteration 505000, Loss: 7.54e-08
# Iteration 510000, Loss: 7.49e-08
# Iteration 515000, Loss: 7.44e-08
# Iteration 520000, Loss: 7.40e-08
# Iteration 525000, Loss: 7.36e-08
# Iteration 530000, Loss: 7.31e-08
# Iteration 535000, Loss: 7.27e-08
# Iteration 540000, Loss: 7.23e-08
# Iteration 545000, Loss: 7.19e-08
# Iteration 550000, Loss: 7.15e-08
# Iteration 555000, Loss: 7.11e-08
# Iteration 560000, Loss: 7.07e-08
# Iteration 565000, Loss: 7.04e-08
# Iteration 570000, Loss: 7.00e-08
# Iteration 575000, Loss: 6.96e-08
# Iteration 580000, Loss: 6.93e-08
# Iteration 585000, Loss: 6.89e-08
# Iteration 590000, Loss: 6.86e-08
# Iteration 595000, Loss: 6.83e-08
# Iteration 600000, Loss: 6.79e-08
# Iteration 605000, Loss: 6.76e-08
# Iteration 610000, Loss: 6.73e-08
# Iteration 615000, Loss: 6.70e-08
# Iteration 620000, Loss: 6.67e-08
# Iteration 625000, Loss: 6.64e-08
# Iteration 630000, Loss: 6.61e-08
# Iteration 635000, Loss: 6.60e-08
# Iteration 640000, Loss: 6.55e-08
# Iteration 645000, Loss: 6.53e-08
# Iteration 650000, Loss: 6.50e-08
# Iteration 655000, Loss: 6.47e-08
# Iteration 660000, Loss: 6.45e-08
# Iteration 665000, Loss: 6.42e-08
# Iteration 670000, Loss: 6.39e-08
# Iteration 675000, Loss: 6.37e-08
# Iteration 680000, Loss: 6.35e-08
# Iteration 685000, Loss: 6.32e-08
# Iteration 690000, Loss: 6.30e-08
# Iteration 695000, Loss: 6.27e-08
# Iteration 700000, Loss: 6.25e-08
# Iteration 705000, Loss: 6.23e-08
# Iteration 710000, Loss: 6.21e-08
# Iteration 715000, Loss: 6.19e-08
# Iteration 720000, Loss: 6.17e-08
# Iteration 725000, Loss: 6.15e-08
# Iteration 730000, Loss: 6.13e-08
# Iteration 735000, Loss: 6.10e-08
# Iteration 740000, Loss: 6.08e-08
# Iteration 745000, Loss: 6.07e-08
# Iteration 750000, Loss: 6.05e-08
# Iteration 755000, Loss: 6.03e-08
# Iteration 760000, Loss: 6.01e-08
# Iteration 765000, Loss: 5.99e-08
# Iteration 770000, Loss: 5.97e-08
# Iteration 775000, Loss: 5.96e-08
# Iteration 780000, Loss: 5.94e-08
# Iteration 785000, Loss: 5.93e-08
# Iteration 790000, Loss: 5.91e-08
# Iteration 795000, Loss: 5.89e-08
# Iteration 800000, Loss: 5.87e-08
# Iteration 805000, Loss: 5.86e-08
# Iteration 810000, Loss: 5.84e-08
# Iteration 815000, Loss: 5.83e-08
# Iteration 820000, Loss: 5.82e-08
# Iteration 825000, Loss: 5.80e-08
# Iteration 830000, Loss: 5.78e-08
# Iteration 835000, Loss: 5.77e-08
# Iteration 840000, Loss: 5.75e-08
# Iteration 845000, Loss: 5.74e-08
# Iteration 850000, Loss: 5.73e-08
# Iteration 855000, Loss: 5.71e-08
# Iteration 860000, Loss: 5.70e-08
# Iteration 865000, Loss: 5.69e-08
# Iteration 870000, Loss: 5.67e-08
# Iteration 875000, Loss: 5.66e-08
# Iteration 880000, Loss: 5.65e-08
# Iteration 885000, Loss: 5.64e-08
# Iteration 890000, Loss: 5.63e-08
# Iteration 895000, Loss: 5.62e-08
# Iteration 900000, Loss: 5.60e-08
# Iteration 905000, Loss: 5.59e-08
# Iteration 910000, Loss: 5.58e-08
# Iteration 915000, Loss: 5.57e-08
# Iteration 920000, Loss: 5.56e-08
# Iteration 925000, Loss: 5.55e-08
# Iteration 930000, Loss: 5.54e-08
# Iteration 935000, Loss: 5.53e-08
# Iteration 940000, Loss: 5.51e-08
# Iteration 945000, Loss: 5.51e-08
# Iteration 950000, Loss: 5.50e-08
# Iteration 955000, Loss: 5.49e-08
# Iteration 960000, Loss: 5.48e-08
# Iteration 965000, Loss: 5.47e-08
# Iteration 970000, Loss: 5.46e-08
# Iteration 975000, Loss: 5.45e-08
# Iteration 980000, Loss: 5.44e-08
# Iteration 985000, Loss: 5.43e-08
# Iteration 990000, Loss: 5.42e-08
# Iteration 995000, Loss: 5.41e-08
# Iteration 1000000, Loss: 5.40e-08
# Iteration 1005000, Loss: 5.39e-08
# Iteration 1010000, Loss: 5.39e-08
# Iteration 1015000, Loss: 5.38e-08
# Iteration 1020000, Loss: 5.37e-08
# Iteration 1025000, Loss: 5.36e-08
# Iteration 1030000, Loss: 5.35e-08
# Iteration 1035000, Loss: 5.35e-08
# Iteration 1040000, Loss: 5.34e-08
# Iteration 1045000, Loss: 5.33e-08
# Iteration 1050000, Loss: 5.32e-08
# Iteration 1055000, Loss: 5.32e-08
# Iteration 1060000, Loss: 5.31e-08
# Iteration 1065000, Loss: 5.30e-08
# Iteration 1070000, Loss: 5.30e-08
# Iteration 1075000, Loss: 5.29e-08
# Iteration 1080000, Loss: 5.28e-08
# Iteration 1085000, Loss: 5.27e-08
# Iteration 1090000, Loss: 5.27e-08
# Iteration 1095000, Loss: 5.26e-08
# Iteration 1100000, Loss: 5.25e-08
# Iteration 1105000, Loss: 5.25e-08
# Iteration 1110000, Loss: 5.24e-08
# Iteration 1115000, Loss: 5.24e-08
# Iteration 1120000, Loss: 5.23e-08
# Iteration 1125000, Loss: 5.22e-08
# Iteration 1130000, Loss: 5.22e-08
# Iteration 1135000, Loss: 5.21e-08
# Iteration 1140000, Loss: 5.21e-08
# Iteration 1145000, Loss: 5.20e-08
# Iteration 1150000, Loss: 5.19e-08
# Iteration 1155000, Loss: 5.19e-08
# Iteration 1160000, Loss: 5.18e-08
# Iteration 1165000, Loss: 5.18e-08
# Iteration 1170000, Loss: 5.17e-08
# Iteration 1175000, Loss: 5.17e-08
# Iteration 1180000, Loss: 5.16e-08
# Iteration 1185000, Loss: 5.16e-08
# Iteration 1190000, Loss: 5.15e-08
# Iteration 1195000, Loss: 5.15e-08
# Iteration 1200000, Loss: 5.14e-08
# Iteration 1205000, Loss: 5.14e-08
# Iteration 1210000, Loss: 5.13e-08
# Iteration 1215000, Loss: 5.13e-08
# Iteration 1220000, Loss: 5.12e-08
# Iteration 1225000, Loss: 5.12e-08
# Iteration 1230000, Loss: 5.11e-08
# Iteration 1235000, Loss: 5.11e-08
# Iteration 1240000, Loss: 5.10e-08
# Iteration 1245000, Loss: 5.10e-08
# Iteration 1250000, Loss: 5.09e-08
# Iteration 1255000, Loss: 5.09e-08
# Iteration 1260000, Loss: 5.08e-08
# Iteration 1265000, Loss: 5.08e-08
# Iteration 1270000, Loss: 5.08e-08
# Iteration 1275000, Loss: 5.07e-08
# Iteration 1280000, Loss: 5.07e-08
# Iteration 1285000, Loss: 5.06e-08
# Iteration 1290000, Loss: 5.06e-08
# Iteration 1295000, Loss: 5.05e-08
# Iteration 1300000, Loss: 5.05e-08
# Iteration 1305000, Loss: 5.05e-08
# Iteration 1310000, Loss: 5.04e-08
# Iteration 1315000, Loss: 5.04e-08
# Iteration 1320000, Loss: 5.04e-08
# Iteration 1325000, Loss: 5.03e-08
# Iteration 1330000, Loss: 5.03e-08
# Iteration 1335000, Loss: 5.02e-08
# Iteration 1340000, Loss: 5.02e-08
# Iteration 1345000, Loss: 5.02e-08
# Iteration 1350000, Loss: 5.01e-08
# Iteration 1355000, Loss: 5.01e-08
# Iteration 1360000, Loss: 5.01e-08
# Iteration 1365000, Loss: 5.00e-08
# Iteration 1370000, Loss: 5.00e-08
# Iteration 1375000, Loss: 5.00e-08
# Iteration 1380000, Loss: 4.99e-08
# Iteration 1385000, Loss: 4.99e-08
# Iteration 1390000, Loss: 4.99e-08
# Iteration 1395000, Loss: 4.98e-08
# Iteration 1400000, Loss: 4.98e-08
# Iteration 1405000, Loss: 4.98e-08
# Iteration 1410000, Loss: 4.97e-08
# Iteration 1415000, Loss: 4.97e-08
# Iteration 1420000, Loss: 4.97e-08
# Iteration 1425000, Loss: 4.96e-08
# Iteration 1430000, Loss: 4.96e-08
# Iteration 1435000, Loss: 4.96e-08
# Iteration 1440000, Loss: 4.95e-08
# Iteration 1445000, Loss: 4.95e-08
# Iteration 1450000, Loss: 4.95e-08
# Iteration 1455000, Loss: 4.94e-08
# Iteration 1460000, Loss: 4.94e-08
# Iteration 1465000, Loss: 4.94e-08
# Iteration 1470000, Loss: 4.94e-08
# Iteration 1475000, Loss: 4.93e-08
# Iteration 1480000, Loss: 4.93e-08
# Iteration 1485000, Loss: 4.93e-08
# Iteration 1490000, Loss: 4.93e-08
# Iteration 1495000, Loss: 4.92e-08
# Iteration 1500000, Loss: 4.92e-08
# Iteration 1505000, Loss: 4.92e-08
# Iteration 1510000, Loss: 4.91e-08
# Iteration 1515000, Loss: 4.91e-08
# Iteration 1520000, Loss: 4.91e-08
# Iteration 1525000, Loss: 4.91e-08
# Iteration 1530000, Loss: 4.90e-08
# Iteration 1535000, Loss: 4.90e-08
# Iteration 1540000, Loss: 4.90e-08
# Iteration 1545000, Loss: 4.90e-08
# Iteration 1550000, Loss: 4.89e-08
# Iteration 1555000, Loss: 4.89e-08
# Iteration 1560000, Loss: 4.89e-08
# Iteration 1565000, Loss: 4.89e-08
# Iteration 1570000, Loss: 4.88e-08
# Iteration 1575000, Loss: 4.88e-08
# Iteration 1580000, Loss: 4.88e-08
# Iteration 1585000, Loss: 4.88e-08
# Iteration 1590000, Loss: 4.88e-08
# Iteration 1595000, Loss: 4.87e-08
# Iteration 1600000, Loss: 4.87e-08
# Iteration 1605000, Loss: 4.87e-08
# Iteration 1610000, Loss: 4.87e-08
# Iteration 1615000, Loss: 4.86e-08
# Iteration 1620000, Loss: 4.86e-08
# Iteration 1625000, Loss: 4.86e-08
# Iteration 1630000, Loss: 4.86e-08
# Iteration 1635000, Loss: 4.85e-08
# Iteration 1640000, Loss: 4.86e-08
# Iteration 1645000, Loss: 4.85e-08
# Iteration 1650000, Loss: 4.85e-08
# Iteration 1655000, Loss: 4.85e-08
# Iteration 1660000, Loss: 4.84e-08
# Iteration 1665000, Loss: 4.84e-08
# Iteration 1670000, Loss: 4.84e-08
# Iteration 1675000, Loss: 4.84e-08
# Iteration 1680000, Loss: 4.84e-08
# Iteration 1685000, Loss: 4.83e-08
# Iteration 1690000, Loss: 4.83e-08
# Iteration 1695000, Loss: 4.83e-08
# Iteration 1700000, Loss: 4.83e-08
# Iteration 1705000, Loss: 4.83e-08
# Iteration 1710000, Loss: 4.83e-08
# Iteration 1715000, Loss: 4.82e-08
# Iteration 1720000, Loss: 4.82e-08
# Iteration 1725000, Loss: 4.82e-08
# Iteration 1730000, Loss: 4.82e-08
# Iteration 1735000, Loss: 4.81e-08
# Iteration 1740000, Loss: 4.81e-08
# Iteration 1745000, Loss: 4.81e-08
# Iteration 1750000, Loss: 4.81e-08
# Iteration 1755000, Loss: 4.81e-08
# Iteration 1760000, Loss: 4.80e-08
# Iteration 1765000, Loss: 4.80e-08
# Iteration 1770000, Loss: 4.80e-08
# Iteration 1775000, Loss: 4.80e-08
# Iteration 1780000, Loss: 4.80e-08
# Iteration 1785000, Loss: 4.80e-08
# Iteration 1790000, Loss: 4.79e-08
# Iteration 1795000, Loss: 4.79e-08
# Iteration 1800000, Loss: 4.79e-08
# Iteration 1805000, Loss: 4.79e-08
# Iteration 1810000, Loss: 4.79e-08
# Iteration 1815000, Loss: 4.78e-08
# Iteration 1820000, Loss: 4.78e-08
# Iteration 1825000, Loss: 4.78e-08
# Iteration 1830000, Loss: 4.78e-08
# Iteration 1835000, Loss: 4.78e-08
# Iteration 1840000, Loss: 4.78e-08
# Iteration 1845000, Loss: 4.77e-08
# Iteration 1850000, Loss: 4.77e-08
# Iteration 1855000, Loss: 4.77e-08
# Iteration 1860000, Loss: 4.77e-08
# Iteration 1865000, Loss: 4.77e-08
# Iteration 1870000, Loss: 4.77e-08
# Iteration 1875000, Loss: 4.76e-08
# Iteration 1880000, Loss: 4.76e-08
# Iteration 1885000, Loss: 4.76e-08
# Iteration 1890000, Loss: 4.76e-08
# Iteration 1895000, Loss: 4.76e-08
# Iteration 1900000, Loss: 4.76e-08
# Iteration 1905000, Loss: 4.75e-08
# Iteration 1910000, Loss: 4.75e-08
# Iteration 1915000, Loss: 4.75e-08
# Iteration 1920000, Loss: 4.75e-08
# Iteration 1925000, Loss: 4.75e-08
# Iteration 1930000, Loss: 4.75e-08
# Iteration 1935000, Loss: 4.74e-08
# Iteration 1940000, Loss: 4.74e-08
# Iteration 1945000, Loss: 4.74e-08
# Iteration 1950000, Loss: 4.75e-08
# Iteration 1955000, Loss: 4.74e-08
# Iteration 1960000, Loss: 4.74e-08
# Iteration 1965000, Loss: 4.74e-08
# Iteration 1970000, Loss: 4.73e-08
# Iteration 1975000, Loss: 4.73e-08
# Iteration 1980000, Loss: 4.73e-08
# Iteration 1985000, Loss: 4.73e-08
# Iteration 1990000, Loss: 4.73e-08
# Iteration 1995000, Loss: 4.73e-08
# Iteration 2000000, Loss: 4.73e-08
# Iteration 2005000, Loss: 4.72e-08
# Iteration 2010000, Loss: 4.72e-08
# Iteration 2015000, Loss: 4.72e-08
# Iteration 2020000, Loss: 4.72e-08
# Iteration 2025000, Loss: 4.72e-08
# Iteration 2030000, Loss: 4.72e-08
# Iteration 2035000, Loss: 4.71e-08
# Iteration 2040000, Loss: 4.71e-08
# Iteration 2045000, Loss: 4.71e-08
# Iteration 2050000, Loss: 4.71e-08
# Iteration 2055000, Loss: 4.71e-08
# Iteration 2060000, Loss: 4.71e-08
# Iteration 2065000, Loss: 4.71e-08
# Iteration 2070000, Loss: 4.70e-08
# Iteration 2075000, Loss: 4.70e-08
# Iteration 2080000, Loss: 4.70e-08
# Iteration 2085000, Loss: 4.70e-08
# Iteration 2090000, Loss: 4.70e-08
# Iteration 2095000, Loss: 4.70e-08
# Iteration 2100000, Loss: 4.70e-08
# Iteration 2105000, Loss: 4.69e-08
# Iteration 2110000, Loss: 4.70e-08
# Iteration 2115000, Loss: 4.69e-08
# Iteration 2120000, Loss: 4.69e-08
# Iteration 2125000, Loss: 4.69e-08
# Iteration 2130000, Loss: 4.69e-08
# Iteration 2135000, Loss: 4.69e-08
# Iteration 2140000, Loss: 4.69e-08
# Iteration 2145000, Loss: 4.68e-08
# Iteration 2150000, Loss: 4.68e-08
# Iteration 2155000, Loss: 4.68e-08
# Iteration 2160000, Loss: 4.68e-08
# Iteration 2165000, Loss: 4.68e-08
# Iteration 2170000, Loss: 4.68e-08
# Iteration 2175000, Loss: 4.68e-08
# Iteration 2180000, Loss: 4.68e-08
# Iteration 2185000, Loss: 4.67e-08
# Iteration 2190000, Loss: 4.67e-08
# Iteration 2195000, Loss: 4.67e-08
# Iteration 2200000, Loss: 4.67e-08
# Iteration 2205000, Loss: 4.67e-08
# Iteration 2210000, Loss: 4.67e-08
# Iteration 2215000, Loss: 4.67e-08
# Iteration 2220000, Loss: 4.67e-08
# Iteration 2225000, Loss: 4.66e-08
# Iteration 2230000, Loss: 4.67e-08
# Iteration 2235000, Loss: 4.66e-08
# Iteration 2240000, Loss: 4.66e-08
# Iteration 2245000, Loss: 4.66e-08
# Iteration 2250000, Loss: 4.66e-08
# Iteration 2255000, Loss: 4.66e-08
# Iteration 2260000, Loss: 4.66e-08
# Iteration 2265000, Loss: 4.65e-08
# Iteration 2270000, Loss: 4.65e-08
# Iteration 2275000, Loss: 4.65e-08
# Iteration 2280000, Loss: 4.65e-08
# Iteration 2285000, Loss: 4.65e-08
# Iteration 2290000, Loss: 4.65e-08
# Iteration 2295000, Loss: 4.65e-08
# Iteration 2300000, Loss: 4.64e-08
# Iteration 2305000, Loss: 4.65e-08
# Iteration 2310000, Loss: 4.64e-08
# Iteration 2315000, Loss: 4.64e-08
# Iteration 2320000, Loss: 4.64e-08
# Iteration 2325000, Loss: 4.64e-08
# Iteration 2330000, Loss: 4.64e-08
# Iteration 2335000, Loss: 4.64e-08
# Iteration 2340000, Loss: 4.64e-08
# Iteration 2345000, Loss: 4.63e-08
# Iteration 2350000, Loss: 4.63e-08
# Iteration 2355000, Loss: 4.63e-08
# Iteration 2360000, Loss: 4.63e-08
# Iteration 2365000, Loss: 4.63e-08
# Iteration 2370000, Loss: 4.63e-08
# Iteration 2375000, Loss: 4.63e-08
# Iteration 2380000, Loss: 4.63e-08
# Iteration 2385000, Loss: 4.62e-08
# Iteration 2390000, Loss: 4.62e-08
# Iteration 2395000, Loss: 4.62e-08
# Iteration 2400000, Loss: 4.62e-08
# Iteration 2405000, Loss: 4.62e-08
# Iteration 2410000, Loss: 4.62e-08
# Iteration 2415000, Loss: 4.62e-08
# Iteration 2420000, Loss: 4.62e-08
# Iteration 2425000, Loss: 4.62e-08
# Iteration 2430000, Loss: 4.62e-08
# Iteration 2435000, Loss: 4.61e-08
# Iteration 2440000, Loss: 4.61e-08
# Iteration 2445000, Loss: 4.61e-08
# Iteration 2450000, Loss: 4.61e-08
# Iteration 2455000, Loss: 4.61e-08
# Iteration 2460000, Loss: 4.61e-08
# Iteration 2465000, Loss: 4.61e-08
# Iteration 2470000, Loss: 4.61e-08
# Iteration 2475000, Loss: 4.60e-08
# Iteration 2480000, Loss: 4.60e-08
# Iteration 2485000, Loss: 4.60e-08
# Iteration 2490000, Loss: 4.60e-08
# Iteration 2495000, Loss: 4.60e-08
# Iteration 2500000, Loss: 4.60e-08
# Iteration 2505000, Loss: 4.60e-08
# Iteration 2510000, Loss: 4.60e-08
# Iteration 2515000, Loss: 4.59e-08
# Iteration 2520000, Loss: 4.59e-08
# Iteration 2525000, Loss: 4.59e-08
# Iteration 2530000, Loss: 4.59e-08
# Iteration 2535000, Loss: 4.59e-08
# Iteration 2540000, Loss: 4.59e-08
# Iteration 2545000, Loss: 4.59e-08
# Iteration 2550000, Loss: 4.59e-08
# Iteration 2555000, Loss: 4.59e-08
# Iteration 2560000, Loss: 4.59e-08
# Iteration 2565000, Loss: 4.58e-08
# Iteration 2570000, Loss: 4.59e-08
# Iteration 2575000, Loss: 4.58e-08
# Iteration 2580000, Loss: 4.58e-08
# Iteration 2585000, Loss: 4.58e-08
# Iteration 2590000, Loss: 4.58e-08
# Iteration 2595000, Loss: 4.58e-08
# Iteration 2600000, Loss: 4.58e-08
# Iteration 2605000, Loss: 4.57e-08
# Iteration 2610000, Loss: 4.57e-08
# Iteration 2615000, Loss: 4.57e-08
# Iteration 2620000, Loss: 4.57e-08
# Iteration 2625000, Loss: 4.57e-08
# Iteration 2630000, Loss: 4.57e-08
# Iteration 2635000, Loss: 4.57e-08
# Iteration 2640000, Loss: 4.57e-08
# Iteration 2645000, Loss: 4.57e-08
# Iteration 2650000, Loss: 4.57e-08
# Iteration 2655000, Loss: 4.56e-08
# Iteration 2660000, Loss: 4.56e-08
# Iteration 2665000, Loss: 4.56e-08
# Iteration 2670000, Loss: 4.56e-08
# Iteration 2675000, Loss: 4.56e-08
# Iteration 2680000, Loss: 4.56e-08
# Iteration 2685000, Loss: 4.56e-08
# Iteration 2690000, Loss: 4.56e-08
# Iteration 2695000, Loss: 4.56e-08
# Iteration 2700000, Loss: 4.56e-08
# Iteration 2705000, Loss: 4.55e-08
# Iteration 2710000, Loss: 4.55e-08
# Iteration 2715000, Loss: 4.55e-08
# Iteration 2720000, Loss: 4.55e-08
# Iteration 2725000, Loss: 4.55e-08
# Iteration 2730000, Loss: 4.55e-08
# Iteration 2735000, Loss: 4.55e-08
# Iteration 2740000, Loss: 4.55e-08
# Iteration 2745000, Loss: 4.55e-08
# Iteration 2750000, Loss: 4.54e-08
# Iteration 2755000, Loss: 4.54e-08
# Iteration 2760000, Loss: 4.54e-08
# Iteration 2765000, Loss: 4.54e-08
# Iteration 2770000, Loss: 4.54e-08
# Iteration 2775000, Loss: 4.54e-08
# Iteration 2780000, Loss: 4.54e-08
# Iteration 2785000, Loss: 4.54e-08
# Iteration 2790000, Loss: 4.54e-08
# Iteration 2795000, Loss: 4.54e-08
# Iteration 2800000, Loss: 4.53e-08
# Iteration 2805000, Loss: 4.53e-08
# Iteration 2810000, Loss: 4.53e-08
# Iteration 2815000, Loss: 4.53e-08
# Iteration 2820000, Loss: 4.53e-08
# Iteration 2825000, Loss: 4.53e-08
# Iteration 2830000, Loss: 4.53e-08
# Iteration 2835000, Loss: 4.53e-08
# Iteration 2840000, Loss: 4.53e-08
# Iteration 2845000, Loss: 4.52e-08
# Iteration 2850000, Loss: 4.53e-08
# Iteration 2855000, Loss: 4.52e-08
# Iteration 2860000, Loss: 4.52e-08
# Iteration 2865000, Loss: 4.52e-08
# Iteration 2870000, Loss: 4.52e-08
# Iteration 2875000, Loss: 4.52e-08
# Iteration 2880000, Loss: 4.52e-08
# Iteration 2885000, Loss: 4.52e-08
# Iteration 2890000, Loss: 4.52e-08
# Iteration 2895000, Loss: 4.52e-08
# Iteration 2900000, Loss: 4.52e-08
# Iteration 2905000, Loss: 4.51e-08
# Iteration 2910000, Loss: 4.51e-08
# Iteration 2915000, Loss: 4.51e-08
# Iteration 2920000, Loss: 4.51e-08
# Iteration 2925000, Loss: 4.51e-08
# Iteration 2930000, Loss: 4.51e-08
# Iteration 2935000, Loss: 4.51e-08
# Iteration 2940000, Loss: 4.51e-08
# Iteration 2945000, Loss: 4.51e-08
# Iteration 2950000, Loss: 4.50e-08
# Iteration 2955000, Loss: 4.50e-08
# Iteration 2960000, Loss: 4.50e-08
# Iteration 2965000, Loss: 4.50e-08
# Iteration 2970000, Loss: 4.50e-08
# Iteration 2975000, Loss: 4.50e-08
# Iteration 2980000, Loss: 4.50e-08
# Iteration 2985000, Loss: 4.50e-08
# Iteration 2990000, Loss: 4.50e-08
# Iteration 2995000, Loss: 4.50e-08
# Iteration 3000000, Loss: 4.50e-08
# Iteration 3005000, Loss: 4.49e-08
# Iteration 3010000, Loss: 4.49e-08
# Iteration 3015000, Loss: 4.49e-08
# Iteration 3020000, Loss: 4.49e-08
# Iteration 3025000, Loss: 4.49e-08
# Iteration 3030000, Loss: 4.49e-08
# Iteration 3035000, Loss: 4.49e-08
# Iteration 3040000, Loss: 4.49e-08
# Iteration 3045000, Loss: 4.49e-08
# Iteration 3050000, Loss: 4.48e-08
# Iteration 3055000, Loss: 4.48e-08
# Iteration 3060000, Loss: 4.48e-08
# Iteration 3065000, Loss: 4.48e-08
# Iteration 3070000, Loss: 4.48e-08
# Iteration 3075000, Loss: 4.49e-08
# Iteration 3080000, Loss: 4.48e-08
# Iteration 3085000, Loss: 4.48e-08
# Iteration 3090000, Loss: 4.48e-08
# Iteration 3095000, Loss: 4.48e-08
# Iteration 3100000, Loss: 4.48e-08
# Iteration 3105000, Loss: 4.48e-08
# Iteration 3110000, Loss: 4.47e-08
# Iteration 3115000, Loss: 4.47e-08
# Iteration 3120000, Loss: 4.47e-08
# Iteration 3125000, Loss: 4.47e-08
# Iteration 3130000, Loss: 4.47e-08
# Iteration 3135000, Loss: 4.47e-08
# Iteration 3140000, Loss: 4.47e-08
# Iteration 3145000, Loss: 4.47e-08
# Iteration 3150000, Loss: 4.47e-08
# Iteration 3155000, Loss: 4.46e-08
# Iteration 3160000, Loss: 4.46e-08
# Iteration 3165000, Loss: 4.46e-08
# Iteration 3170000, Loss: 4.46e-08
# Iteration 3175000, Loss: 4.46e-08
# Iteration 3180000, Loss: 4.46e-08
# Iteration 3185000, Loss: 4.46e-08
# Iteration 3190000, Loss: 4.46e-08
# Iteration 3195000, Loss: 4.46e-08
# Iteration 3200000, Loss: 4.46e-08
# Iteration 3205000, Loss: 4.45e-08
# Iteration 3210000, Loss: 4.45e-08
# Iteration 3215000, Loss: 4.45e-08
# Iteration 3220000, Loss: 4.45e-08
# Iteration 3225000, Loss: 4.45e-08
# Iteration 3230000, Loss: 4.45e-08
# Iteration 3235000, Loss: 4.45e-08
# Iteration 3240000, Loss: 4.45e-08
# Iteration 3245000, Loss: 4.45e-08
# Iteration 3250000, Loss: 4.45e-08
# Iteration 3255000, Loss: 4.45e-08
# Iteration 3260000, Loss: 4.45e-08
# Iteration 3265000, Loss: 4.44e-08
# Iteration 3270000, Loss: 4.45e-08
# Iteration 3275000, Loss: 4.44e-08
# Iteration 3280000, Loss: 4.44e-08
# Iteration 3285000, Loss: 4.44e-08
# Iteration 3290000, Loss: 4.45e-08
# Iteration 3295000, Loss: 4.44e-08
# Iteration 3300000, Loss: 4.44e-08
# Iteration 3305000, Loss: 4.44e-08
# Iteration 3310000, Loss: 4.44e-08
# Iteration 3315000, Loss: 4.44e-08
# Iteration 3320000, Loss: 4.43e-08
# Iteration 3325000, Loss: 4.43e-08
# Iteration 3330000, Loss: 4.43e-08
# Iteration 3335000, Loss: 4.43e-08
# Iteration 3340000, Loss: 4.43e-08
# Iteration 3345000, Loss: 4.43e-08
# Iteration 3350000, Loss: 4.43e-08
# Iteration 3355000, Loss: 4.43e-08
# Iteration 3360000, Loss: 4.43e-08
# Iteration 3365000, Loss: 4.43e-08
# Iteration 3370000, Loss: 4.43e-08
# Iteration 3375000, Loss: 4.42e-08
# Iteration 3380000, Loss: 4.42e-08
# Iteration 3385000, Loss: 4.42e-08
# Iteration 3390000, Loss: 4.42e-08
# Iteration 3395000, Loss: 4.42e-08
# Iteration 3400000, Loss: 4.42e-08
# Iteration 3405000, Loss: 4.42e-08
# Iteration 3410000, Loss: 4.42e-08
# Iteration 3415000, Loss: 4.42e-08
# Iteration 3420000, Loss: 4.42e-08
# Iteration 3425000, Loss: 4.42e-08
# Iteration 3430000, Loss: 4.41e-08
# Iteration 3435000, Loss: 4.41e-08
# Iteration 3440000, Loss: 4.41e-08
# Iteration 3445000, Loss: 4.41e-08
# Iteration 3450000, Loss: 4.41e-08
# Iteration 3455000, Loss: 4.41e-08
# Iteration 3460000, Loss: 4.41e-08
# Iteration 3465000, Loss: 4.41e-08
# Iteration 3470000, Loss: 4.41e-08
# Iteration 3475000, Loss: 4.41e-08
# Iteration 3480000, Loss: 4.41e-08
# Iteration 3485000, Loss: 4.41e-08
# Iteration 3490000, Loss: 4.40e-08
# Iteration 3495000, Loss: 4.41e-08
# Iteration 3500000, Loss: 4.40e-08
# Iteration 3505000, Loss: 4.40e-08
# Iteration 3510000, Loss: 4.40e-08
# Iteration 3515000, Loss: 4.40e-08
# Iteration 3520000, Loss: 4.40e-08
# Iteration 3525000, Loss: 4.40e-08
# Iteration 3530000, Loss: 4.40e-08
# Iteration 3535000, Loss: 4.40e-08
# Iteration 3540000, Loss: 4.40e-08
# Iteration 3545000, Loss: 4.39e-08
# Iteration 3550000, Loss: 4.39e-08
# Iteration 3555000, Loss: 4.39e-08
# Iteration 3560000, Loss: 4.39e-08
# Iteration 3565000, Loss: 4.39e-08
# Iteration 3570000, Loss: 4.39e-08
# Iteration 3575000, Loss: 4.39e-08
# Iteration 3580000, Loss: 4.39e-08
# Iteration 3585000, Loss: 4.39e-08
# Iteration 3590000, Loss: 4.39e-08
# Iteration 3595000, Loss: 4.39e-08
# Iteration 3600000, Loss: 4.39e-08
# Iteration 3605000, Loss: 4.38e-08
# Iteration 3610000, Loss: 4.38e-08
# Iteration 3615000, Loss: 4.38e-08
# Iteration 3620000, Loss: 4.38e-08
# Iteration 3625000, Loss: 4.38e-08
# Iteration 3630000, Loss: 4.38e-08
# Iteration 3635000, Loss: 4.38e-08
# Iteration 3640000, Loss: 4.38e-08
# Iteration 3645000, Loss: 4.38e-08
# Iteration 3650000, Loss: 4.38e-08
# Iteration 3655000, Loss: 4.38e-08
# Iteration 3660000, Loss: 4.38e-08
# Iteration 3665000, Loss: 4.37e-08
# Iteration 3670000, Loss: 4.37e-08
# Iteration 3675000, Loss: 4.38e-08
# Iteration 3680000, Loss: 4.37e-08
# Iteration 3685000, Loss: 4.37e-08
# Iteration 3690000, Loss: 4.37e-08
# Iteration 3695000, Loss: 4.37e-08
# Iteration 3700000, Loss: 4.37e-08
# Iteration 3705000, Loss: 4.37e-08
# Iteration 3710000, Loss: 4.37e-08
# Iteration 3715000, Loss: 4.37e-08
# Iteration 3720000, Loss: 4.37e-08
# Iteration 3725000, Loss: 4.37e-08
# Iteration 3730000, Loss: 4.36e-08
# Iteration 3735000, Loss: 4.36e-08
# Iteration 3740000, Loss: 4.36e-08
# Iteration 3745000, Loss: 4.36e-08
# Iteration 3750000, Loss: 4.36e-08
# Iteration 3755000, Loss: 4.36e-08
# Iteration 3760000, Loss: 4.36e-08
# Iteration 3765000, Loss: 4.36e-08
# Iteration 3770000, Loss: 4.36e-08
# Iteration 3775000, Loss: 4.36e-08
# Iteration 3780000, Loss: 4.35e-08
# Iteration 3785000, Loss: 4.35e-08
# Iteration 3790000, Loss: 4.35e-08
# Iteration 3795000, Loss: 4.35e-08
# Iteration 3800000, Loss: 4.35e-08
# Iteration 3805000, Loss: 4.35e-08
# Iteration 3810000, Loss: 4.35e-08
# Iteration 3815000, Loss: 4.35e-08
# Iteration 3820000, Loss: 4.35e-08
# Iteration 3825000, Loss: 4.35e-08
# Iteration 3830000, Loss: 4.35e-08
# Iteration 3835000, Loss: 4.35e-08
# Iteration 3840000, Loss: 4.35e-08
# Iteration 3845000, Loss: 4.34e-08
# Iteration 3850000, Loss: 4.34e-08
# Iteration 3855000, Loss: 4.34e-08
# Iteration 3860000, Loss: 4.34e-08
# Iteration 3865000, Loss: 4.34e-08
# Iteration 3870000, Loss: 4.34e-08
# Iteration 3875000, Loss: 4.34e-08
# Iteration 3880000, Loss: 4.34e-08
# Iteration 3885000, Loss: 4.34e-08
# Iteration 3890000, Loss: 4.34e-08
# Iteration 3895000, Loss: 4.34e-08
# Iteration 3900000, Loss: 4.34e-08
# Iteration 3905000, Loss: 4.33e-08
# Iteration 3910000, Loss: 4.34e-08
# Iteration 3915000, Loss: 4.33e-08
# Iteration 3920000, Loss: 4.33e-08
# Iteration 3925000, Loss: 4.33e-08
# Iteration 3930000, Loss: 4.33e-08
# Iteration 3935000, Loss: 4.33e-08
# Iteration 3940000, Loss: 4.33e-08
# Iteration 3945000, Loss: 4.33e-08
# Iteration 3950000, Loss: 4.33e-08
# Iteration 3955000, Loss: 4.33e-08
# Iteration 3960000, Loss: 4.33e-08
# Iteration 3965000, Loss: 4.33e-08
# Iteration 3970000, Loss: 4.32e-08
# Iteration 3975000, Loss: 4.32e-08
# Iteration 3980000, Loss: 4.32e-08
# Iteration 3985000, Loss: 4.32e-08
# Iteration 3990000, Loss: 4.32e-08
# Iteration 3995000, Loss: 4.32e-08
# Iteration 4000000, Loss: 4.32e-08
# Iteration 4005000, Loss: 4.32e-08
# Iteration 4010000, Loss: 4.32e-08
# Iteration 4015000, Loss: 4.32e-08
# Iteration 4020000, Loss: 4.32e-08
# Iteration 4025000, Loss: 4.32e-08
# Iteration 4030000, Loss: 4.32e-08
# Iteration 4035000, Loss: 4.32e-08
# Iteration 4040000, Loss: 4.31e-08
# Iteration 4045000, Loss: 4.31e-08
# Iteration 4050000, Loss: 4.31e-08
# Iteration 4055000, Loss: 4.31e-08
# Iteration 4060000, Loss: 4.31e-08
# Iteration 4065000, Loss: 4.31e-08
# Iteration 4070000, Loss: 4.31e-08
# Iteration 4075000, Loss: 4.31e-08
# Iteration 4080000, Loss: 4.31e-08
# Iteration 4085000, Loss: 4.31e-08
# Iteration 4090000, Loss: 4.31e-08
# Iteration 4095000, Loss: 4.31e-08
# Iteration 4100000, Loss: 4.31e-08
# Iteration 4105000, Loss: 4.30e-08
# Iteration 4110000, Loss: 4.30e-08
# Iteration 4115000, Loss: 4.30e-08
# Iteration 4120000, Loss: 4.30e-08
# Iteration 4125000, Loss: 4.30e-08
# Iteration 4130000, Loss: 4.30e-08
# Iteration 4135000, Loss: 4.30e-08
# Iteration 4140000, Loss: 4.30e-08
# Iteration 4145000, Loss: 4.30e-08
# Iteration 4150000, Loss: 4.30e-08
# Iteration 4155000, Loss: 4.30e-08
# Iteration 4160000, Loss: 4.30e-08
# Iteration 4165000, Loss: 4.29e-08
# Iteration 4170000, Loss: 4.29e-08
# Iteration 4175000, Loss: 4.29e-08
# Iteration 4180000, Loss: 4.29e-08
# Iteration 4185000, Loss: 4.29e-08
# Iteration 4190000, Loss: 4.29e-08
# Iteration 4195000, Loss: 4.29e-08
# Iteration 4200000, Loss: 4.29e-08
# Iteration 4205000, Loss: 4.29e-08
# Iteration 4210000, Loss: 4.29e-08
# Iteration 4215000, Loss: 4.29e-08
# Iteration 4220000, Loss: 4.29e-08
# Iteration 4225000, Loss: 4.28e-08
# Iteration 4230000, Loss: 4.28e-08
# Iteration 4235000, Loss: 4.28e-08
# Iteration 4240000, Loss: 4.28e-08
# Iteration 4245000, Loss: 4.28e-08
# Iteration 4250000, Loss: 4.28e-08
# Iteration 4255000, Loss: 4.28e-08
# Iteration 4260000, Loss: 4.28e-08
# Iteration 4265000, Loss: 4.28e-08
# Iteration 4270000, Loss: 4.28e-08
# Iteration 4275000, Loss: 4.28e-08
# Iteration 4280000, Loss: 4.28e-08
# Iteration 4285000, Loss: 4.28e-08
# Iteration 4290000, Loss: 4.28e-08
# Iteration 4295000, Loss: 4.28e-08
# Iteration 4300000, Loss: 4.27e-08
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[255], line 19
#      16 loss = F.mse_loss(phi_n_approx[:,0], phi_n_combined_tensor[:,0])
#      18 # Backward pass
# ---> 19 loss.backward()
#      20 optimizer.step()
#      22 if i % 5000 == 0:
#
# File /opt/homebrew/anaconda3/envs/flashstu/lib/python3.12/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/homebrew/anaconda3/envs/flashstu/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/homebrew/anaconda3/envs/flashstu/lib/python3.12/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Convert back to numpy for plotting
phi_n_approx = torch.matmul(lds_impulses_tensor, combined_weights_pinv).detach()

# Compare original vs approximated phi_n
plt.figure(figsize=(10, 6))
plt.plot(phi_n_combined[:1000,0], label='Original phi')
plt.plot(phi_n_approx[:1000,0], '--', label='Approximated phi')
plt.title('Comparing Original vs Approximated Basis Functions')
plt.legend()
plt.show()

# Calculate MSE between original and approximated phi
mse = F.mse_loss(phi_n_combined_tensor, phi_n_approx)
print(f"MSE between original and approximated phi: {mse:.2e}")
# Out:
# MSE between original and approximated phi: 2.25e-05

# %%
lds.A
# Out:
# tensor([0.9504])

# %%
# Save the learned filter (first basis function)
recon_phi_0 = phi_n_approx[:,0].detach().numpy()
np.save('recon_phi_0.npy', recon_phi_0)

# Save the LDS parameters
for i, (lds, stu) in enumerate(filtered_store):
    # Save individual LDS parameters
    np.savez(f'recon_lds_{i}.npz',
             A=lds.A.detach().numpy(),
             B=lds.B.detach().numpy(), 
             C=lds.C.detach().numpy(),
             D=lds.D.detach().numpy(),
             h0=lds.h0.detach().numpy())

# Save the reconstruction weights
np.save('recon_combined_weights_pinv.npy', combined_weights_pinv.detach().numpy())

print("Saved reconstruction data:")
print(f"Filter shape: {recon_phi_0.shape}")
print(f"Number of LDS models saved: {len(filtered_store)}")
print(f"Combined weights shape: {combined_weights_pinv.shape}")
# Out:
# Saved reconstruction data:
# Filter shape: (1024,)
# Number of LDS models saved: 200
# Combined weights shape: torch.Size([200, 40])
